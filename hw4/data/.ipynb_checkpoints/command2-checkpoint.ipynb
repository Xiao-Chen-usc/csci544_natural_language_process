# %%
import time
import torch
from torch import nn
#from torch.optim import Adam
from torch.optim import SGD
from torchtext.data import Field, BucketIterator
import copy
from torch.nn.utils.rnn import pack_padded_sequence

# %%
import csv
import pandas as pd

import numpy as np

# %%
glove_vocab = {}
with open('glove.6B.100d','r') as f:        
    for line in f:   
        tmp = line.split()
        word = tmp[0]
        v = [x for x in tmp[1:]]
        glove_vocab[word] = v

# %%
def data_to_stream(data):
    data_stream = []
    i = 0 
    for index, word, tag in data:
        if index == 1:
            temp = []
            temp.append([index,str(word).lower(), tag])
            
        else:
            temp.append([index ,str(word).lower(),tag ])
            
        if ( (i+1 < len(data)) and data[i+1][0] == 1 ) or (i == len(data)-1):
            data_stream.append(temp)
        
        i += 1
            
    return data_stream

# %%
def x_y(indexical_train):
    x = []
    y = []
    for sentence in indexical_train:
        temp_x = []
        temp_y = []
        for word in sentence:
            temp_x.append(word[1])
            temp_y.append(word[2])
        x.append(temp_x)
        y.append(temp_y)
    return x,y

# %%
train_file = pd.read_csv('train', quoting=csv.QUOTE_NONE,sep=" ", names= ['index', 'word', 'tag'])

train_array = train_file.to_numpy()

train_stream = data_to_stream(train_array)

train_word,train_tag = x_y(train_stream)

# %%
train_stream
# Out:
# [[[1, 'eu', 'B-ORG'],
#   [2, 'rejects', 'O'],
#   [3, 'german', 'B-MISC'],
#   [4, 'call', 'O'],
#   [5, 'to', 'O'],
#   [6, 'boycott', 'O'],
#   [7, 'british', 'B-MISC'],
#   [8, 'lamb', 'O'],
#   [9, '.', 'O']],
#  [[1, 'peter', 'B-PER'], [2, 'blackburn', 'I-PER']],
#  [[1, 'brussels', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'european', 'B-ORG'],
#   [3, 'commission', 'I-ORG'],
#   [4, 'said', 'O'],
#   [5, 'on', 'O'],
#   [6, 'thursday', 'O'],
#   [7, 'it', 'O'],
#   [8, 'disagreed', 'O'],
#   [9, 'with', 'O'],
#   [10, 'german', 'B-MISC'],
#   [11, 'advice', 'O'],
#   [12, 'to', 'O'],
#   [13, 'consumers', 'O'],
#   [14, 'to', 'O'],
#   [15, 'shun', 'O'],
#   [16, 'british', 'B-MISC'],
#   [17, 'lamb', 'O'],
#   [18, 'until', 'O'],
#   [19, 'scientists', 'O'],
#   [20, 'determine', 'O'],
#   [21, 'whether', 'O'],
#   [22, 'mad', 'O'],
#   [23, 'cow', 'O'],
#   [24, 'disease', 'O'],
#   [25, 'can', 'O'],
#   [26, 'be', 'O'],
#   [27, 'transmitted', 'O'],
#   [28, 'to', 'O'],
#   [29, 'sheep', 'O'],
#   [30, '.', 'O']],
#  [[1, 'germany', 'B-LOC'],
#   [2, "'s", 'O'],
#   [3, 'representative', 'O'],
#   [4, 'to', 'O'],
#   [5, 'the', 'O'],
#   [6, 'european', 'B-ORG'],
#   [7, 'union', 'I-ORG'],
#   [8, "'s", 'O'],
#   [9, 'veterinary', 'O'],
#   [10, 'committee', 'O'],
#   [11, 'werner', 'B-PER'],
#   [12, 'zwingmann', 'I-PER'],
#   [13, 'said', 'O'],
#   [14, 'on', 'O'],
#   [15, 'wednesday', 'O'],
#   [16, 'consumers', 'O'],
#   [17, 'should', 'O'],
#   [18, 'buy', 'O'],
#   [19, 'sheepmeat', 'O'],
#   [20, 'from', 'O'],
#   [21, 'countries', 'O'],
#   [22, 'other', 'O'],
#   [23, 'than', 'O'],
#   [24, 'britain', 'B-LOC'],
#   [25, 'until', 'O'],
#   [26, 'the', 'O'],
#   [27, 'scientific', 'O'],
#   [28, 'advice', 'O'],
#   [29, 'was', 'O'],
#   [30, 'clearer', 'O'],
#   [31, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'we', 'O'],
#   [3, 'do', 'O'],
#   [4, "n't", 'O'],
#   [5, 'support', 'O'],
#   [6, 'any', 'O'],
#   [7, 'such', 'O'],
#   [8, 'recommendation', 'O'],
#   [9, 'because', 'O'],
#   [10, 'we', 'O'],
#   [11, 'do', 'O'],
#   [12, "n't", 'O'],
#   [13, 'see', 'O'],
#   [14, 'any', 'O'],
#   [15, 'grounds', 'O'],
#   [16, 'for', 'O'],
#   [17, 'it', 'O'],
#   [18, ',', 'O'],
#   [19, '"', 'O'],
#   [20, 'the', 'O'],
#   [21, 'commission', 'B-ORG'],
#   [22, "'s", 'O'],
#   [23, 'chief', 'O'],
#   [24, 'spokesman', 'O'],
#   [25, 'nikolaus', 'B-PER'],
#   [26, 'van', 'I-PER'],
#   [27, 'der', 'I-PER'],
#   [28, 'pas', 'I-PER'],
#   [29, 'told', 'O'],
#   [30, 'a', 'O'],
#   [31, 'news', 'O'],
#   [32, 'briefing', 'O'],
#   [33, '.', 'O']],
#  [[1, 'he', 'O'],
#   [2, 'said', 'O'],
#   [3, 'further', 'O'],
#   [4, 'scientific', 'O'],
#   [5, 'study', 'O'],
#   [6, 'was', 'O'],
#   [7, 'required', 'O'],
#   [8, 'and', 'O'],
#   [9, 'if', 'O'],
#   [10, 'it', 'O'],
#   [11, 'was', 'O'],
#   [12, 'found', 'O'],
#   [13, 'that', 'O'],
#   [14, 'action', 'O'],
#   [15, 'was', 'O'],
#   [16, 'needed', 'O'],
#   [17, 'it', 'O'],
#   [18, 'should', 'O'],
#   [19, 'be', 'O'],
#   [20, 'taken', 'O'],
#   [21, 'by', 'O'],
#   [22, 'the', 'O'],
#   [23, 'european', 'B-ORG'],
#   [24, 'union', 'I-ORG'],
#   [25, '.', 'O']],
#  [[1, 'he', 'O'],
#   [2, 'said', 'O'],
#   [3, 'a', 'O'],
#   [4, 'proposal', 'O'],
#   [5, 'last', 'O'],
#   [6, 'month', 'O'],
#   [7, 'by', 'O'],
#   [8, 'eu', 'B-ORG'],
#   [9, 'farm', 'O'],
#   [10, 'commissioner', 'O'],
#   [11, 'franz', 'B-PER'],
#   [12, 'fischler', 'I-PER'],
#   [13, 'to', 'O'],
#   [14, 'ban', 'O'],
#   [15, 'sheep', 'O'],
#   [16, 'brains', 'O'],
#   [17, ',', 'O'],
#   [18, 'spleens', 'O'],
#   [19, 'and', 'O'],
#   [20, 'spinal', 'O'],
#   [21, 'cords', 'O'],
#   [22, 'from', 'O'],
#   [23, 'the', 'O'],
#   [24, 'human', 'O'],
#   [25, 'and', 'O'],
#   [26, 'animal', 'O'],
#   [27, 'food', 'O'],
#   [28, 'chains', 'O'],
#   [29, 'was', 'O'],
#   [30, 'a', 'O'],
#   [31, 'highly', 'O'],
#   [32, 'specific', 'O'],
#   [33, 'and', 'O'],
#   [34, 'precautionary', 'O'],
#   [35, 'move', 'O'],
#   [36, 'to', 'O'],
#   [37, 'protect', 'O'],
#   [38, 'human', 'O'],
#   [39, 'health', 'O'],
#   [40, '.', 'O']],
#  [[1, 'fischler', 'B-PER'],
#   [2, 'proposed', 'O'],
#   [3, 'eu-wide', 'B-MISC'],
#   [4, 'measures', 'O'],
#   [5, 'after', 'O'],
#   [6, 'reports', 'O'],
#   [7, 'from', 'O'],
#   [8, 'britain', 'B-LOC'],
#   [9, 'and', 'O'],
#   [10, 'france', 'B-LOC'],
#   [11, 'that', 'O'],
#   [12, 'under', 'O'],
#   [13, 'laboratory', 'O'],
#   [14, 'conditions', 'O'],
#   [15, 'sheep', 'O'],
#   [16, 'could', 'O'],
#   [17, 'contract', 'O'],
#   [18, 'bovine', 'B-MISC'],
#   [19, 'spongiform', 'I-MISC'],
#   [20, 'encephalopathy', 'I-MISC'],
#   [21, '(', 'O'],
#   [22, 'bse', 'B-MISC'],
#   [23, ')', 'O'],
#   [24, '--', 'O'],
#   [25, 'mad', 'O'],
#   [26, 'cow', 'O'],
#   [27, 'disease', 'O'],
#   [28, '.', 'O']],
#  [[1, 'but', 'O'],
#   [2, 'fischler', 'B-PER'],
#   [3, 'agreed', 'O'],
#   [4, 'to', 'O'],
#   [5, 'review', 'O'],
#   [6, 'his', 'O'],
#   [7, 'proposal', 'O'],
#   [8, 'after', 'O'],
#   [9, 'the', 'O'],
#   [10, 'eu', 'B-ORG'],
#   [11, "'s", 'O'],
#   [12, 'standing', 'O'],
#   [13, 'veterinary', 'O'],
#   [14, 'committee', 'O'],
#   [15, ',', 'O'],
#   [16, 'mational', 'O'],
#   [17, 'animal', 'O'],
#   [18, 'health', 'O'],
#   [19, 'officials', 'O'],
#   [20, ',', 'O'],
#   [21, 'questioned', 'O'],
#   [22, 'if', 'O'],
#   [23, 'such', 'O'],
#   [24, 'action', 'O'],
#   [25, 'was', 'O'],
#   [26, 'justified', 'O'],
#   [27, 'as', 'O'],
#   [28, 'there', 'O'],
#   [29, 'was', 'O'],
#   [30, 'only', 'O'],
#   [31, 'a', 'O'],
#   [32, 'slight', 'O'],
#   [33, 'risk', 'O'],
#   [34, 'to', 'O'],
#   [35, 'human', 'O'],
#   [36, 'health', 'O'],
#   [37, '.', 'O']],
#  [[1, 'spanish', 'B-MISC'],
#   [2, 'farm', 'O'],
#   [3, 'minister', 'O'],
#   [4, 'loyola', 'B-PER'],
#   [5, 'de', 'I-PER'],
#   [6, 'palacio', 'I-PER'],
#   [7, 'had', 'O'],
#   [8, 'earlier', 'O'],
#   [9, 'accused', 'O'],
#   [10, 'fischler', 'B-PER'],
#   [11, 'at', 'O'],
#   [12, 'an', 'O'],
#   [13, 'eu', 'B-ORG'],
#   [14, 'farm', 'O'],
#   [15, 'ministers', 'O'],
#   [16, "'", 'O'],
#   [17, 'meeting', 'O'],
#   [18, 'of', 'O'],
#   [19, 'causing', 'O'],
#   [20, 'unjustified', 'O'],
#   [21, 'alarm', 'O'],
#   [22, 'through', 'O'],
#   [23, '"', 'O'],
#   [24, 'dangerous', 'O'],
#   [25, 'generalisation', 'O'],
#   [26, '.', 'O'],
#   [27, '"', 'O']],
#  [[1, '.', 'O']],
#  [[1, 'only', 'O'],
#   [2, 'france', 'B-LOC'],
#   [3, 'and', 'O'],
#   [4, 'britain', 'B-LOC'],
#   [5, 'backed', 'O'],
#   [6, 'fischler', 'B-PER'],
#   [7, "'s", 'O'],
#   [8, 'proposal', 'O'],
#   [9, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'eu', 'B-ORG'],
#   [3, "'s", 'O'],
#   [4, 'scientific', 'O'],
#   [5, 'veterinary', 'O'],
#   [6, 'and', 'O'],
#   [7, 'multidisciplinary', 'O'],
#   [8, 'committees', 'O'],
#   [9, 'are', 'O'],
#   [10, 'due', 'O'],
#   [11, 'to', 'O'],
#   [12, 're-examine', 'O'],
#   [13, 'the', 'O'],
#   [14, 'issue', 'O'],
#   [15, 'early', 'O'],
#   [16, 'next', 'O'],
#   [17, 'month', 'O'],
#   [18, 'and', 'O'],
#   [19, 'make', 'O'],
#   [20, 'recommendations', 'O'],
#   [21, 'to', 'O'],
#   [22, 'the', 'O'],
#   [23, 'senior', 'O'],
#   [24, 'veterinary', 'O'],
#   [25, 'officials', 'O'],
#   [26, '.', 'O']],
#  [[1, 'sheep', 'O'],
#   [2, 'have', 'O'],
#   [3, 'long', 'O'],
#   [4, 'been', 'O'],
#   [5, 'known', 'O'],
#   [6, 'to', 'O'],
#   [7, 'contract', 'O'],
#   [8, 'scrapie', 'O'],
#   [9, ',', 'O'],
#   [10, 'a', 'O'],
#   [11, 'brain-wasting', 'O'],
#   [12, 'disease', 'O'],
#   [13, 'similar', 'O'],
#   [14, 'to', 'O'],
#   [15, 'bse', 'B-MISC'],
#   [16, 'which', 'O'],
#   [17, 'is', 'O'],
#   [18, 'believed', 'O'],
#   [19, 'to', 'O'],
#   [20, 'have', 'O'],
#   [21, 'been', 'O'],
#   [22, 'transferred', 'O'],
#   [23, 'to', 'O'],
#   [24, 'cattle', 'O'],
#   [25, 'through', 'O'],
#   [26, 'feed', 'O'],
#   [27, 'containing', 'O'],
#   [28, 'animal', 'O'],
#   [29, 'waste', 'O'],
#   [30, '.', 'O']],
#  [[1, 'british', 'B-MISC'],
#   [2, 'farmers', 'O'],
#   [3, 'denied', 'O'],
#   [4, 'on', 'O'],
#   [5, 'thursday', 'O'],
#   [6, 'there', 'O'],
#   [7, 'was', 'O'],
#   [8, 'any', 'O'],
#   [9, 'danger', 'O'],
#   [10, 'to', 'O'],
#   [11, 'human', 'O'],
#   [12, 'health', 'O'],
#   [13, 'from', 'O'],
#   [14, 'their', 'O'],
#   [15, 'sheep', 'O'],
#   [16, ',', 'O'],
#   [17, 'but', 'O'],
#   [18, 'expressed', 'O'],
#   [19, 'concern', 'O'],
#   [20, 'that', 'O'],
#   [21, 'german', 'B-MISC'],
#   [22, 'government', 'O'],
#   [23, 'advice', 'O'],
#   [24, 'to', 'O'],
#   [25, 'consumers', 'O'],
#   [26, 'to', 'O'],
#   [27, 'avoid', 'O'],
#   [28, 'british', 'B-MISC'],
#   [29, 'lamb', 'O'],
#   [30, 'might', 'O'],
#   [31, 'influence', 'O'],
#   [32, 'consumers', 'O'],
#   [33, 'across', 'O'],
#   [34, 'europe', 'B-LOC'],
#   [35, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'what', 'O'],
#   [3, 'we', 'O'],
#   [4, 'have', 'O'],
#   [5, 'to', 'O'],
#   [6, 'be', 'O'],
#   [7, 'extremely', 'O'],
#   [8, 'careful', 'O'],
#   [9, 'of', 'O'],
#   [10, 'is', 'O'],
#   [11, 'how', 'O'],
#   [12, 'other', 'O'],
#   [13, 'countries', 'O'],
#   [14, 'are', 'O'],
#   [15, 'going', 'O'],
#   [16, 'to', 'O'],
#   [17, 'take', 'O'],
#   [18, 'germany', 'B-LOC'],
#   [19, "'s", 'O'],
#   [20, 'lead', 'O'],
#   [21, ',', 'O'],
#   [22, '"', 'O'],
#   [23, 'welsh', 'B-ORG'],
#   [24, 'national', 'I-ORG'],
#   [25, 'farmers', 'I-ORG'],
#   [26, "'", 'I-ORG'],
#   [27, 'union', 'I-ORG'],
#   [28, '(', 'O'],
#   [29, 'nfu', 'B-ORG'],
#   [30, ')', 'O'],
#   [31, 'chairman', 'O'],
#   [32, 'john', 'B-PER'],
#   [33, 'lloyd', 'I-PER'],
#   [34, 'jones', 'I-PER'],
#   [35, 'said', 'O'],
#   [36, 'on', 'O'],
#   [37, 'bbc', 'B-ORG'],
#   [38, 'radio', 'I-ORG'],
#   [39, '.', 'O']],
#  [[1, 'bonn', 'B-LOC'],
#   [2, 'has', 'O'],
#   [3, 'led', 'O'],
#   [4, 'efforts', 'O'],
#   [5, 'to', 'O'],
#   [6, 'protect', 'O'],
#   [7, 'public', 'O'],
#   [8, 'health', 'O'],
#   [9, 'after', 'O'],
#   [10, 'consumer', 'O'],
#   [11, 'confidence', 'O'],
#   [12, 'collapsed', 'O'],
#   [13, 'in', 'O'],
#   [14, 'march', 'O'],
#   [15, 'after', 'O'],
#   [16, 'a', 'O'],
#   [17, 'british', 'B-MISC'],
#   [18, 'report', 'O'],
#   [19, 'suggested', 'O'],
#   [20, 'humans', 'O'],
#   [21, 'could', 'O'],
#   [22, 'contract', 'O'],
#   [23, 'an', 'O'],
#   [24, 'illness', 'O'],
#   [25, 'similar', 'O'],
#   [26, 'to', 'O'],
#   [27, 'mad', 'O'],
#   [28, 'cow', 'O'],
#   [29, 'disease', 'O'],
#   [30, 'by', 'O'],
#   [31, 'eating', 'O'],
#   [32, 'contaminated', 'O'],
#   [33, 'beef', 'O'],
#   [34, '.', 'O']],
#  [[1, 'germany', 'B-LOC'],
#   [2, 'imported', 'O'],
#   [3, '47,600', 'O'],
#   [4, 'sheep', 'O'],
#   [5, 'from', 'O'],
#   [6, 'britain', 'B-LOC'],
#   [7, 'last', 'O'],
#   [8, 'year', 'O'],
#   [9, ',', 'O'],
#   [10, 'nearly', 'O'],
#   [11, 'half', 'O'],
#   [12, 'of', 'O'],
#   [13, 'total', 'O'],
#   [14, 'imports', 'O'],
#   [15, '.', 'O']],
#  [[1, 'it', 'O'],
#   [2, 'brought', 'O'],
#   [3, 'in', 'O'],
#   [4, '4,275', 'O'],
#   [5, 'tonnes', 'O'],
#   [6, 'of', 'O'],
#   [7, 'british', 'B-MISC'],
#   [8, 'mutton', 'O'],
#   [9, ',', 'O'],
#   [10, 'some', 'O'],
#   [11, '10', 'O'],
#   [12, 'percent', 'O'],
#   [13, 'of', 'O'],
#   [14, 'overall', 'O'],
#   [15, 'imports', 'O'],
#   [16, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'rare', 'O'],
#   [2, 'hendrix', 'B-PER'],
#   [3, 'song', 'O'],
#   [4, 'draft', 'O'],
#   [5, 'sells', 'O'],
#   [6, 'for', 'O'],
#   [7, 'almost', 'O'],
#   [8, '$', 'O'],
#   [9, '17,000', 'O'],
#   [10, '.', 'O']],
#  [[1, 'london', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'a', 'O'],
#   [2, 'rare', 'O'],
#   [3, 'early', 'O'],
#   [4, 'handwritten', 'O'],
#   [5, 'draft', 'O'],
#   [6, 'of', 'O'],
#   [7, 'a', 'O'],
#   [8, 'song', 'O'],
#   [9, 'by', 'O'],
#   [10, 'u.s.', 'B-LOC'],
#   [11, 'guitar', 'O'],
#   [12, 'legend', 'O'],
#   [13, 'jimi', 'B-PER'],
#   [14, 'hendrix', 'I-PER'],
#   [15, 'was', 'O'],
#   [16, 'sold', 'O'],
#   [17, 'for', 'O'],
#   [18, 'almost', 'O'],
#   [19, '$', 'O'],
#   [20, '17,000', 'O'],
#   [21, 'on', 'O'],
#   [22, 'thursday', 'O'],
#   [23, 'at', 'O'],
#   [24, 'an', 'O'],
#   [25, 'auction', 'O'],
#   [26, 'of', 'O'],
#   [27, 'some', 'O'],
#   [28, 'of', 'O'],
#   [29, 'the', 'O'],
#   [30, 'late', 'O'],
#   [31, 'musician', 'O'],
#   [32, "'s", 'O'],
#   [33, 'favourite', 'O'],
#   [34, 'possessions', 'O'],
#   [35, '.', 'O']],
#  [[1, 'a', 'O'],
#   [2, 'florida', 'B-LOC'],
#   [3, 'restaurant', 'O'],
#   [4, 'paid', 'O'],
#   [5, '10,925', 'O'],
#   [6, 'pounds', 'O'],
#   [7, '(', 'O'],
#   [8, '$', 'O'],
#   [9, '16,935', 'O'],
#   [10, ')', 'O'],
#   [11, 'for', 'O'],
#   [12, 'the', 'O'],
#   [13, 'draft', 'O'],
#   [14, 'of', 'O'],
#   [15, '"', 'O'],
#   [16, 'ai', 'B-MISC'],
#   [17, "n't", 'I-MISC'],
#   [18, 'no', 'I-MISC'],
#   [19, 'telling', 'I-MISC'],
#   [20, '"', 'O'],
#   [21, ',', 'O'],
#   [22, 'which', 'O'],
#   [23, 'hendrix', 'B-PER'],
#   [24, 'penned', 'O'],
#   [25, 'on', 'O'],
#   [26, 'a', 'O'],
#   [27, 'piece', 'O'],
#   [28, 'of', 'O'],
#   [29, 'london', 'B-LOC'],
#   [30, 'hotel', 'O'],
#   [31, 'stationery', 'O'],
#   [32, 'in', 'O'],
#   [33, 'late', 'O'],
#   [34, '1966', 'O'],
#   [35, '.', 'O']],
#  [[1, 'at', 'O'],
#   [2, 'the', 'O'],
#   [3, 'end', 'O'],
#   [4, 'of', 'O'],
#   [5, 'a', 'O'],
#   [6, 'january', 'O'],
#   [7, '1967', 'O'],
#   [8, 'concert', 'O'],
#   [9, 'in', 'O'],
#   [10, 'the', 'O'],
#   [11, 'english', 'B-MISC'],
#   [12, 'city', 'O'],
#   [13, 'of', 'O'],
#   [14, 'nottingham', 'B-LOC'],
#   [15, 'he', 'O'],
#   [16, 'threw', 'O'],
#   [17, 'the', 'O'],
#   [18, 'sheet', 'O'],
#   [19, 'of', 'O'],
#   [20, 'paper', 'O'],
#   [21, 'into', 'O'],
#   [22, 'the', 'O'],
#   [23, 'audience', 'O'],
#   [24, ',', 'O'],
#   [25, 'where', 'O'],
#   [26, 'it', 'O'],
#   [27, 'was', 'O'],
#   [28, 'retrieved', 'O'],
#   [29, 'by', 'O'],
#   [30, 'a', 'O'],
#   [31, 'fan', 'O'],
#   [32, '.', 'O']],
#  [[1, 'buyers', 'O'],
#   [2, 'also', 'O'],
#   [3, 'snapped', 'O'],
#   [4, 'up', 'O'],
#   [5, '16', 'O'],
#   [6, 'other', 'O'],
#   [7, 'items', 'O'],
#   [8, 'that', 'O'],
#   [9, 'were', 'O'],
#   [10, 'put', 'O'],
#   [11, 'up', 'O'],
#   [12, 'for', 'O'],
#   [13, 'auction', 'O'],
#   [14, 'by', 'O'],
#   [15, 'hendrix', 'B-PER'],
#   [16, "'s", 'O'],
#   [17, 'former', 'O'],
#   [18, 'girlfriend', 'O'],
#   [19, 'kathy', 'B-PER'],
#   [20, 'etchingham', 'I-PER'],
#   [21, ',', 'O'],
#   [22, 'who', 'O'],
#   [23, 'lived', 'O'],
#   [24, 'with', 'O'],
#   [25, 'him', 'O'],
#   [26, 'from', 'O'],
#   [27, '1966', 'O'],
#   [28, 'to', 'O'],
#   [29, '1969', 'O'],
#   [30, '.', 'O']],
#  [[1, 'they', 'O'],
#   [2, 'included', 'O'],
#   [3, 'a', 'O'],
#   [4, 'black', 'O'],
#   [5, 'lacquer', 'O'],
#   [6, 'and', 'O'],
#   [7, 'mother', 'O'],
#   [8, 'of', 'O'],
#   [9, 'pearl', 'O'],
#   [10, 'inlaid', 'O'],
#   [11, 'box', 'O'],
#   [12, 'used', 'O'],
#   [13, 'by', 'O'],
#   [14, 'hendrix', 'B-PER'],
#   [15, 'to', 'O'],
#   [16, 'store', 'O'],
#   [17, 'his', 'O'],
#   [18, 'drugs', 'O'],
#   [19, ',', 'O'],
#   [20, 'which', 'O'],
#   [21, 'an', 'O'],
#   [22, 'anonymous', 'O'],
#   [23, 'australian', 'B-MISC'],
#   [24, 'purchaser', 'O'],
#   [25, 'bought', 'O'],
#   [26, 'for', 'O'],
#   [27, '5,060', 'O'],
#   [28, 'pounds', 'O'],
#   [29, '(', 'O'],
#   [30, '$', 'O'],
#   [31, '7,845', 'O'],
#   [32, ')', 'O'],
#   [33, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'guitarist', 'O'],
#   [3, 'died', 'O'],
#   [4, 'of', 'O'],
#   [5, 'a', 'O'],
#   [6, 'drugs', 'O'],
#   [7, 'overdose', 'O'],
#   [8, 'in', 'O'],
#   [9, '1970', 'O'],
#   [10, 'aged', 'O'],
#   [11, '27', 'O'],
#   [12, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'china', 'B-LOC'],
#   [2, 'says', 'O'],
#   [3, 'taiwan', 'B-LOC'],
#   [4, 'spoils', 'O'],
#   [5, 'atmosphere', 'O'],
#   [6, 'for', 'O'],
#   [7, 'talks', 'O'],
#   [8, '.', 'O']],
#  [[1, 'beijing', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'china', 'B-LOC'],
#   [2, 'on', 'O'],
#   [3, 'thursday', 'O'],
#   [4, 'accused', 'O'],
#   [5, 'taipei', 'B-LOC'],
#   [6, 'of', 'O'],
#   [7, 'spoiling', 'O'],
#   [8, 'the', 'O'],
#   [9, 'atmosphere', 'O'],
#   [10, 'for', 'O'],
#   [11, 'a', 'O'],
#   [12, 'resumption', 'O'],
#   [13, 'of', 'O'],
#   [14, 'talks', 'O'],
#   [15, 'across', 'O'],
#   [16, 'the', 'O'],
#   [17, 'taiwan', 'B-LOC'],
#   [18, 'strait', 'I-LOC'],
#   [19, 'with', 'O'],
#   [20, 'a', 'O'],
#   [21, 'visit', 'O'],
#   [22, 'to', 'O'],
#   [23, 'ukraine', 'B-LOC'],
#   [24, 'by', 'O'],
#   [25, 'taiwanese', 'B-MISC'],
#   [26, 'vice', 'O'],
#   [27, 'president', 'O'],
#   [28, 'lien', 'B-PER'],
#   [29, 'chan', 'I-PER'],
#   [30, 'this', 'O'],
#   [31, 'week', 'O'],
#   [32, 'that', 'O'],
#   [33, 'infuriated', 'O'],
#   [34, 'beijing', 'B-LOC'],
#   [35, '.', 'O']],
#  [[1, 'speaking', 'O'],
#   [2, 'only', 'O'],
#   [3, 'hours', 'O'],
#   [4, 'after', 'O'],
#   [5, 'chinese', 'B-MISC'],
#   [6, 'state', 'O'],
#   [7, 'media', 'O'],
#   [8, 'said', 'O'],
#   [9, 'the', 'O'],
#   [10, 'time', 'O'],
#   [11, 'was', 'O'],
#   [12, 'right', 'O'],
#   [13, 'to', 'O'],
#   [14, 'engage', 'O'],
#   [15, 'in', 'O'],
#   [16, 'political', 'O'],
#   [17, 'talks', 'O'],
#   [18, 'with', 'O'],
#   [19, 'taiwan', 'B-LOC'],
#   [20, ',', 'O'],
#   [21, 'foreign', 'B-ORG'],
#   [22, 'ministry', 'I-ORG'],
#   [23, 'spokesman', 'O'],
#   [24, 'shen', 'B-PER'],
#   [25, 'guofang', 'I-PER'],
#   [26, 'told', 'O'],
#   [27, 'reuters', 'B-ORG'],
#   [28, ':', 'O'],
#   [29, '"', 'O'],
#   [30, 'the', 'O'],
#   [31, 'necessary', 'O'],
#   [32, 'atmosphere', 'O'],
#   [33, 'for', 'O'],
#   [34, 'the', 'O'],
#   [35, 'opening', 'O'],
#   [36, 'of', 'O'],
#   [37, 'the', 'O'],
#   [38, 'talks', 'O'],
#   [39, 'has', 'O'],
#   [40, 'been', 'O'],
#   [41, 'disrupted', 'O'],
#   [42, 'by', 'O'],
#   [43, 'the', 'O'],
#   [44, 'taiwan', 'B-LOC'],
#   [45, 'authorities', 'O'],
#   [46, '.', 'O'],
#   [47, '"', 'O']],
#  [[1, 'state', 'O'],
#   [2, 'media', 'O'],
#   [3, 'quoted', 'O'],
#   [4, 'china', 'B-LOC'],
#   [5, "'s", 'O'],
#   [6, 'top', 'O'],
#   [7, 'negotiator', 'O'],
#   [8, 'with', 'O'],
#   [9, 'taipei', 'B-LOC'],
#   [10, ',', 'O'],
#   [11, 'tang', 'B-PER'],
#   [12, 'shubei', 'I-PER'],
#   [13, ',', 'O'],
#   [14, 'as', 'O'],
#   [15, 'telling', 'O'],
#   [16, 'a', 'O'],
#   [17, 'visiting', 'O'],
#   [18, 'group', 'O'],
#   [19, 'from', 'O'],
#   [20, 'taiwan', 'B-LOC'],
#   [21, 'on', 'O'],
#   [22, 'wednesday', 'O'],
#   [23, 'that', 'O'],
#   [24, 'it', 'O'],
#   [25, 'was', 'O'],
#   [26, 'time', 'O'],
#   [27, 'for', 'O'],
#   [28, 'the', 'O'],
#   [29, 'rivals', 'O'],
#   [30, 'to', 'O'],
#   [31, 'hold', 'O'],
#   [32, 'political', 'O'],
#   [33, 'talks', 'O'],
#   [34, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'now', 'O'],
#   [3, 'is', 'O'],
#   [4, 'the', 'O'],
#   [5, 'time', 'O'],
#   [6, 'for', 'O'],
#   [7, 'the', 'O'],
#   [8, 'two', 'O'],
#   [9, 'sides', 'O'],
#   [10, 'to', 'O'],
#   [11, 'engage', 'O'],
#   [12, 'in', 'O'],
#   [13, 'political', 'O'],
#   [14, 'talks', 'O'],
#   [15, '...', 'O']],
#  [[1, 'that', 'O'],
#   [2, 'is', 'O'],
#   [3, 'to', 'O'],
#   [4, 'end', 'O'],
#   [5, 'the', 'O'],
#   [6, 'state', 'O'],
#   [7, 'of', 'O'],
#   [8, 'hostility', 'O'],
#   [9, ',', 'O'],
#   [10, '"', 'O'],
#   [11, 'thursday', 'O'],
#   [12, "'s", 'O'],
#   [13, 'overseas', 'O'],
#   [14, 'edition', 'O'],
#   [15, 'of', 'O'],
#   [16, 'the', 'O'],
#   [17, 'people', 'B-ORG'],
#   [18, "'s", 'I-ORG'],
#   [19, 'daily', 'I-ORG'],
#   [20, 'quoted', 'O'],
#   [21, 'tang', 'B-PER'],
#   [22, 'as', 'O'],
#   [23, 'saying', 'O'],
#   [24, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'foreign', 'O'],
#   [3, 'ministry', 'O'],
#   [4, "'s", 'O'],
#   [5, 'shen', 'B-ORG'],
#   [6, 'told', 'O'],
#   [7, 'reuters', 'B-ORG'],
#   [8, 'television', 'I-ORG'],
#   [9, 'in', 'O'],
#   [10, 'an', 'O'],
#   [11, 'interview', 'O'],
#   [12, 'he', 'O'],
#   [13, 'had', 'O'],
#   [14, 'read', 'O'],
#   [15, 'reports', 'O'],
#   [16, 'of', 'O'],
#   [17, 'tang', 'B-PER'],
#   [18, "'s", 'O'],
#   [19, 'comments', 'O'],
#   [20, 'but', 'O'],
#   [21, 'gave', 'O'],
#   [22, 'no', 'O'],
#   [23, 'details', 'O'],
#   [24, 'of', 'O'],
#   [25, 'why', 'O'],
#   [26, 'the', 'O'],
#   [27, 'negotiator', 'O'],
#   [28, 'had', 'O'],
#   [29, 'considered', 'O'],
#   [30, 'the', 'O'],
#   [31, 'time', 'O'],
#   [32, 'right', 'O'],
#   [33, 'for', 'O'],
#   [34, 'talks', 'O'],
#   [35, 'with', 'O'],
#   [36, 'taiwan', 'B-LOC'],
#   [37, ',', 'O'],
#   [38, 'which', 'O'],
#   [39, 'beijing', 'B-LOC'],
#   [40, 'considers', 'O'],
#   [41, 'a', 'O'],
#   [42, 'renegade', 'O'],
#   [43, 'province', 'O'],
#   [44, '.', 'O']],
#  [[1, 'china', 'B-LOC'],
#   [2, ',', 'O'],
#   [3, 'which', 'O'],
#   [4, 'has', 'O'],
#   [5, 'long', 'O'],
#   [6, 'opposed', 'O'],
#   [7, 'all', 'O'],
#   [8, 'taipei', 'B-LOC'],
#   [9, 'efforts', 'O'],
#   [10, 'to', 'O'],
#   [11, 'gain', 'O'],
#   [12, 'greater', 'O'],
#   [13, 'international', 'O'],
#   [14, 'recognition', 'O'],
#   [15, ',', 'O'],
#   [16, 'was', 'O'],
#   [17, 'infuriated', 'O'],
#   [18, 'by', 'O'],
#   [19, 'a', 'O'],
#   [20, 'visit', 'O'],
#   [21, 'to', 'O'],
#   [22, 'ukraine', 'B-LOC'],
#   [23, 'this', 'O'],
#   [24, 'week', 'O'],
#   [25, 'by', 'O'],
#   [26, 'taiwanese', 'B-MISC'],
#   [27, 'vice', 'O'],
#   [28, 'president', 'O'],
#   [29, 'lien', 'B-PER'],
#   [30, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'china', 'B-LOC'],
#   [2, 'says', 'O'],
#   [3, 'time', 'O'],
#   [4, 'right', 'O'],
#   [5, 'for', 'O'],
#   [6, 'taiwan', 'B-LOC'],
#   [7, 'talks', 'O'],
#   [8, '.', 'O']],
#  [[1, 'beijing', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'china', 'B-LOC'],
#   [2, 'has', 'O'],
#   [3, 'said', 'O'],
#   [4, 'it', 'O'],
#   [5, 'was', 'O'],
#   [6, 'time', 'O'],
#   [7, 'for', 'O'],
#   [8, 'political', 'O'],
#   [9, 'talks', 'O'],
#   [10, 'with', 'O'],
#   [11, 'taiwan', 'B-LOC'],
#   [12, 'and', 'O'],
#   [13, 'that', 'O'],
#   [14, 'the', 'O'],
#   [15, 'rival', 'O'],
#   [16, 'island', 'O'],
#   [17, 'should', 'O'],
#   [18, 'take', 'O'],
#   [19, 'practical', 'O'],
#   [20, 'steps', 'O'],
#   [21, 'towards', 'O'],
#   [22, 'that', 'O'],
#   [23, 'goal', 'O'],
#   [24, '.', 'O']],
#  [[1, 'consultations', 'O'],
#   [2, 'should', 'O'],
#   [3, 'be', 'O'],
#   [4, 'held', 'O'],
#   [5, 'to', 'O'],
#   [6, 'set', 'O'],
#   [7, 'the', 'O'],
#   [8, 'time', 'O'],
#   [9, 'and', 'O'],
#   [10, 'format', 'O'],
#   [11, 'of', 'O'],
#   [12, 'the', 'O'],
#   [13, 'talks', 'O'],
#   [14, ',', 'O'],
#   [15, 'the', 'O'],
#   [16, 'official', 'O'],
#   [17, 'xinhua', 'B-ORG'],
#   [18, 'news', 'O'],
#   [19, 'agency', 'O'],
#   [20, 'quoted', 'O'],
#   [21, 'tang', 'B-PER'],
#   [22, 'shubei', 'I-PER'],
#   [23, ',', 'O'],
#   [24, 'executive', 'O'],
#   [25, 'vice', 'O'],
#   [26, 'chairman', 'O'],
#   [27, 'of', 'O'],
#   [28, 'the', 'O'],
#   [29, 'association', 'B-ORG'],
#   [30, 'for', 'I-ORG'],
#   [31, 'relations', 'I-ORG'],
#   [32, 'across', 'I-ORG'],
#   [33, 'the', 'I-ORG'],
#   [34, 'taiwan', 'I-ORG'],
#   [35, 'straits', 'I-ORG'],
#   [36, ',', 'O'],
#   [37, 'as', 'O'],
#   [38, 'saying', 'O'],
#   [39, 'late', 'O'],
#   [40, 'on', 'O'],
#   [41, 'wednesday', 'O'],
#   [42, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'german', 'B-MISC'],
#   [2, 'july', 'O'],
#   [3, 'car', 'O'],
#   [4, 'registrations', 'O'],
#   [5, 'up', 'O'],
#   [6, '14.2', 'O'],
#   [7, 'pct', 'O'],
#   [8, 'yr', 'O'],
#   [9, '/', 'O'],
#   [10, 'yr', 'O'],
#   [11, '.', 'O']],
#  [[1, 'frankfurt', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'german', 'B-MISC'],
#   [2, 'first-time', 'O'],
#   [3, 'registrations', 'O'],
#   [4, 'of', 'O'],
#   [5, 'motor', 'O'],
#   [6, 'vehicles', 'O'],
#   [7, 'jumped', 'O'],
#   [8, '14.2', 'O'],
#   [9, 'percent', 'O'],
#   [10, 'in', 'O'],
#   [11, 'july', 'O'],
#   [12, 'this', 'O'],
#   [13, 'year', 'O'],
#   [14, 'from', 'O'],
#   [15, 'the', 'O'],
#   [16, 'year-earlier', 'O'],
#   [17, 'period', 'O'],
#   [18, ',', 'O'],
#   [19, 'the', 'O'],
#   [20, 'federal', 'B-ORG'],
#   [21, 'office', 'I-ORG'],
#   [22, 'for', 'I-ORG'],
#   [23, 'motor', 'I-ORG'],
#   [24, 'vehicles', 'I-ORG'],
#   [25, 'said', 'O'],
#   [26, 'on', 'O'],
#   [27, 'thursday', 'O'],
#   [28, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'office', 'O'],
#   [3, 'said', 'O'],
#   [4, '356,725', 'O'],
#   [5, 'new', 'O'],
#   [6, 'cars', 'O'],
#   [7, 'were', 'O'],
#   [8, 'registered', 'O'],
#   [9, 'in', 'O'],
#   [10, 'july', 'O'],
#   [11, '1996', 'O'],
#   [12, '--', 'O'],
#   [13, '304,850', 'O'],
#   [14, 'passenger', 'O'],
#   [15, 'cars', 'O'],
#   [16, 'and', 'O'],
#   [17, '15,613', 'O'],
#   [18, 'trucks', 'O'],
#   [19, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'figures', 'O'],
#   [3, 'represent', 'O'],
#   [4, 'a', 'O'],
#   [5, '13.6', 'O'],
#   [6, 'percent', 'O'],
#   [7, 'increase', 'O'],
#   [8, 'for', 'O'],
#   [9, 'passenger', 'O'],
#   [10, 'cars', 'O'],
#   [11, 'and', 'O'],
#   [12, 'a', 'O'],
#   [13, '2.2', 'O'],
#   [14, 'percent', 'O'],
#   [15, 'decline', 'O'],
#   [16, 'for', 'O'],
#   [17, 'trucks', 'O'],
#   [18, 'from', 'O'],
#   [19, 'july', 'O'],
#   [20, '1995', 'O'],
#   [21, '.', 'O']],
#  [[1, 'motor-bike', 'O'],
#   [2, 'registration', 'O'],
#   [3, 'rose', 'O'],
#   [4, '32.7', 'O'],
#   [5, 'percent', 'O'],
#   [6, 'in', 'O'],
#   [7, 'the', 'O'],
#   [8, 'period', 'O'],
#   [9, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'growth', 'O'],
#   [3, 'was', 'O'],
#   [4, 'partly', 'O'],
#   [5, 'due', 'O'],
#   [6, 'to', 'O'],
#   [7, 'an', 'O'],
#   [8, 'increased', 'O'],
#   [9, 'number', 'O'],
#   [10, 'of', 'O'],
#   [11, 'germans', 'B-MISC'],
#   [12, 'buying', 'O'],
#   [13, 'german', 'B-MISC'],
#   [14, 'cars', 'O'],
#   [15, 'abroad', 'O'],
#   [16, ',', 'O'],
#   [17, 'while', 'O'],
#   [18, 'manufacturers', 'O'],
#   [19, 'said', 'O'],
#   [20, 'that', 'O'],
#   [21, 'domestic', 'O'],
#   [22, 'demand', 'O'],
#   [23, 'was', 'O'],
#   [24, 'weak', 'O'],
#   [25, ',', 'O'],
#   [26, 'the', 'O'],
#   [27, 'federal', 'O'],
#   [28, 'office', 'O'],
#   [29, 'said', 'O'],
#   [30, '.', 'O']],
#  [[1, 'almost', 'O'],
#   [2, 'all', 'O'],
#   [3, 'german', 'B-MISC'],
#   [4, 'car', 'O'],
#   [5, 'manufacturers', 'O'],
#   [6, 'posted', 'O'],
#   [7, 'gains', 'O'],
#   [8, 'in', 'O'],
#   [9, 'registration', 'O'],
#   [10, 'numbers', 'O'],
#   [11, 'in', 'O'],
#   [12, 'the', 'O'],
#   [13, 'period', 'O'],
#   [14, '.', 'O']],
#  [[1, 'volkswagen', 'B-ORG'],
#   [2, 'ag', 'I-ORG'],
#   [3, 'won', 'O'],
#   [4, '77,719', 'O'],
#   [5, 'registrations', 'O'],
#   [6, ',', 'O'],
#   [7, 'slightly', 'O'],
#   [8, 'more', 'O'],
#   [9, 'than', 'O'],
#   [10, 'a', 'O'],
#   [11, 'quarter', 'O'],
#   [12, 'of', 'O'],
#   [13, 'the', 'O'],
#   [14, 'total', 'O'],
#   [15, '.', 'O']],
#  [[1, 'opel', 'B-ORG'],
#   [2, 'ag', 'I-ORG'],
#   [3, 'together', 'O'],
#   [4, 'with', 'O'],
#   [5, 'general', 'B-ORG'],
#   [6, 'motors', 'I-ORG'],
#   [7, 'came', 'O'],
#   [8, 'in', 'O'],
#   [9, 'second', 'O'],
#   [10, 'place', 'O'],
#   [11, 'with', 'O'],
#   [12, '49,269', 'O'],
#   [13, 'registrations', 'O'],
#   [14, ',', 'O'],
#   [15, '16.4', 'O'],
#   [16, 'percent', 'O'],
#   [17, 'of', 'O'],
#   [18, 'the', 'O'],
#   [19, 'overall', 'O'],
#   [20, 'figure', 'O'],
#   [21, '.', 'O']],
#  [[1, 'third', 'O'],
#   [2, 'was', 'O'],
#   [3, 'ford', 'B-ORG'],
#   [4, 'with', 'O'],
#   [5, '35,563', 'O'],
#   [6, 'registrations', 'O'],
#   [7, ',', 'O'],
#   [8, 'or', 'O'],
#   [9, '11.7', 'O'],
#   [10, 'percent', 'O'],
#   [11, '.', 'O']],
#  [[1, 'only', 'O'],
#   [2, 'seat', 'B-ORG'],
#   [3, 'and', 'O'],
#   [4, 'porsche', 'B-ORG'],
#   [5, 'had', 'O'],
#   [6, 'fewer', 'O'],
#   [7, 'registrations', 'O'],
#   [8, 'in', 'O'],
#   [9, 'july', 'O'],
#   [10, '1996', 'O'],
#   [11, 'compared', 'O'],
#   [12, 'to', 'O'],
#   [13, 'last', 'O'],
#   [14, 'year', 'O'],
#   [15, "'s", 'O'],
#   [16, 'july', 'O'],
#   [17, '.', 'O']],
#  [[1, 'seat', 'B-ORG'],
#   [2, 'posted', 'O'],
#   [3, '3,420', 'O'],
#   [4, 'registrations', 'O'],
#   [5, 'compared', 'O'],
#   [6, 'with', 'O'],
#   [7, '5522', 'O'],
#   [8, 'registrations', 'O'],
#   [9, 'in', 'O'],
#   [10, 'july', 'O'],
#   [11, 'a', 'O'],
#   [12, 'year', 'O'],
#   [13, 'earlier', 'O'],
#   [14, '.', 'O']],
#  [[1, 'porsche', 'B-ORG'],
#   [2, "'s", 'O'],
#   [3, 'registrations', 'O'],
#   [4, 'fell', 'O'],
#   [5, 'to', 'O'],
#   [6, '554', 'O'],
#   [7, 'from', 'O'],
#   [8, '643', 'O'],
#   [9, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'greek', 'B-MISC'],
#   [2, 'socialists', 'O'],
#   [3, 'give', 'O'],
#   [4, 'green', 'O'],
#   [5, 'light', 'O'],
#   [6, 'to', 'O'],
#   [7, 'pm', 'O'],
#   [8, 'for', 'O'],
#   [9, 'elections', 'O'],
#   [10, '.', 'O']],
#  [[1, 'athens', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'greek', 'B-MISC'],
#   [3, 'socialist', 'O'],
#   [4, 'party', 'O'],
#   [5, "'s", 'O'],
#   [6, 'executive', 'O'],
#   [7, 'bureau', 'O'],
#   [8, 'gave', 'O'],
#   [9, 'the', 'O'],
#   [10, 'green', 'O'],
#   [11, 'light', 'O'],
#   [12, 'to', 'O'],
#   [13, 'prime', 'O'],
#   [14, 'minister', 'O'],
#   [15, 'costas', 'B-PER'],
#   [16, 'simitis', 'I-PER'],
#   [17, 'to', 'O'],
#   [18, 'call', 'O'],
#   [19, 'snap', 'O'],
#   [20, 'elections', 'O'],
#   [21, ',', 'O'],
#   [22, 'its', 'O'],
#   [23, 'general', 'O'],
#   [24, 'secretary', 'O'],
#   [25, 'costas', 'B-PER'],
#   [26, 'skandalidis', 'I-PER'],
#   [27, 'told', 'O'],
#   [28, 'reporters', 'O'],
#   [29, '.', 'O']],
#  [[1, 'prime', 'O'],
#   [2, 'minister', 'O'],
#   [3, 'costas', 'B-PER'],
#   [4, 'simitis', 'I-PER'],
#   [5, 'is', 'O'],
#   [6, 'going', 'O'],
#   [7, 'to', 'O'],
#   [8, 'make', 'O'],
#   [9, 'an', 'O'],
#   [10, 'official', 'O'],
#   [11, 'announcement', 'O'],
#   [12, 'after', 'O'],
#   [13, 'a', 'O'],
#   [14, 'cabinet', 'O'],
#   [15, 'meeting', 'O'],
#   [16, 'later', 'O'],
#   [17, 'on', 'O'],
#   [18, 'thursday', 'O'],
#   [19, ',', 'O'],
#   [20, 'said', 'O'],
#   [21, 'skandalidis', 'B-PER'],
#   [22, '.', 'O']],
#  [[1, '--', 'O'],
#   [2, 'dimitris', 'B-PER'],
#   [3, 'kontogiannis', 'I-PER'],
#   [4, ',', 'O'],
#   [5, 'athens', 'B-ORG'],
#   [6, 'newsroom', 'I-ORG'],
#   [7, '+301', 'O'],
#   [8, '3311812-4', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'bayervb', 'B-ORG'],
#   [2, 'sets', 'O'],
#   [3, 'c$', 'B-MISC'],
#   [4, '100', 'O'],
#   [5, 'million', 'O'],
#   [6, 'six-year', 'O'],
#   [7, 'bond', 'O'],
#   [8, '.', 'O']],
#  [[1, 'london', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'following', 'O'],
#   [3, 'bond', 'O'],
#   [4, 'was', 'O'],
#   [5, 'announced', 'O'],
#   [6, 'by', 'O'],
#   [7, 'lead', 'O'],
#   [8, 'manager', 'O'],
#   [9, 'toronto', 'B-PER'],
#   [10, 'dominion', 'I-PER'],
#   [11, '.', 'O']],
#  [[1, 'borrower', 'O'],
#   [2, 'bayerische', 'B-ORG'],
#   [3, 'vereinsbank', 'I-ORG']],
#  [[1, 'amt', 'O'],
#   [2, 'c$', 'B-MISC'],
#   [3, '100', 'O'],
#   [4, 'mln', 'O'],
#   [5, 'coupon', 'O'],
#   [6, '6.625', 'O'],
#   [7, 'maturity', 'O'],
#   [8, '24.sep.02', 'O']],
#  [[1, 'type', 'O'],
#   [2, 'straight', 'O'],
#   [3, 'iss', 'O'],
#   [4, 'price', 'O'],
#   [5, '100.92', 'O'],
#   [6, 'pay', 'O'],
#   [7, 'date', 'O'],
#   [8, '24.sep.96', 'O']],
#  [[1, 'full', 'O'],
#   [2, 'fees', 'O'],
#   [3, '1.875', 'O'],
#   [4, 'reoffer', 'O'],
#   [5, '99.32', 'O'],
#   [6, 'spread', 'O'],
#   [7, '+20', 'O'],
#   [8, 'bp', 'O']],
#  [[1, 'moody', 'O'],
#   [2, 'aa1', 'O'],
#   [3, 'listing', 'O'],
#   [4, 'lux', 'O'],
#   [5, 'pay', 'O'],
#   [6, 'freq', 'O'],
#   [7, '=', 'O']],
#  [[1, 's&p', 'B-ORG'],
#   [2, '=', 'O'],
#   [3, 'denoms', 'O'],
#   [4, '(', 'O'],
#   [5, 'k', 'O'],
#   [6, ')', 'O'],
#   [7, '1-10-100', 'O'],
#   [8, 'sale', 'O'],
#   [9, 'limits', 'O'],
#   [10, 'us', 'B-LOC'],
#   [11, '/', 'O'],
#   [12, 'uk', 'B-LOC'],
#   [13, '/', 'O'],
#   [14, 'ca', 'B-LOC']],
#  [[1, 'neg', 'O'],
#   [2, 'plg', 'O'],
#   [3, 'no', 'O'],
#   [4, 'crs', 'O'],
#   [5, 'deflt', 'O'],
#   [6, 'no', 'O'],
#   [7, 'force', 'O'],
#   [8, 'maj', 'O'],
#   [9, '=', 'O']],
#  [[1, 'gov', 'O'],
#   [2, 'law', 'O'],
#   [3, 'german', 'B-MISC'],
#   [4, 'home', 'O'],
#   [5, 'ctry', 'O'],
#   [6, '=', 'O'],
#   [7, 'tax', 'O'],
#   [8, 'provs', 'O'],
#   [9, 'standard', 'O']],
#  [[1, 'mgt', 'O'],
#   [2, '/', 'O'],
#   [3, 'und', 'O'],
#   [4, '0.275', 'O'],
#   [5, 'sell', 'O'],
#   [6, 'conc', 'O'],
#   [7, '1.60', 'O'],
#   [8, 'praecip', 'O'],
#   [9, '=', 'O']],
#  [[1, 'underlying', 'O'],
#   [2, 'govt', 'O'],
#   [3, 'bond', 'O'],
#   [4, '7.0', 'O'],
#   [5, 'pct', 'O'],
#   [6, 'sept', 'O'],
#   [7, '2001', 'O']],
#  [[1, 'notes', 'O'],
#   [2, 'bayerische', 'B-ORG'],
#   [3, 'vereinsbank', 'I-ORG'],
#   [4, 'is', 'O'],
#   [5, 'joint', 'O'],
#   [6, 'lead', 'O'],
#   [7, 'manager', 'O']],
#  [[1, '--', 'O'],
#   [2, 'london', 'B-ORG'],
#   [3, 'newsroom', 'I-ORG'],
#   [4, '+44', 'O'],
#   [5, '171', 'O'],
#   [6, '542', 'O'],
#   [7, '7658', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'venantius', 'B-ORG'],
#   [2, 'sets', 'O'],
#   [3, '$', 'O'],
#   [4, '300', 'O'],
#   [5, 'million', 'O'],
#   [6, 'january', 'O'],
#   [7, '1999', 'O'],
#   [8, 'frn', 'O'],
#   [9, '.', 'O']],
#  [[1, 'london', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'following', 'O'],
#   [3, 'floating-rate', 'O'],
#   [4, 'issue', 'O'],
#   [5, 'was', 'O'],
#   [6, 'announced', 'O'],
#   [7, 'by', 'O'],
#   [8, 'lead', 'O'],
#   [9, 'manager', 'O'],
#   [10, 'lehman', 'B-ORG'],
#   [11, 'brothers', 'I-ORG'],
#   [12, 'international', 'I-ORG'],
#   [13, '.', 'O']],
#  [[1, 'borrower', 'O'],
#   [2, 'venantius', 'B-ORG'],
#   [3, 'ab', 'I-ORG'],
#   [4, '(', 'O'],
#   [5, 'swedish', 'B-MISC'],
#   [6, 'national', 'O'],
#   [7, 'mortgage', 'O'],
#   [8, 'agency', 'O'],
#   [9, ')', 'O']],
#  [[1, 'amt', 'O'],
#   [2, '$', 'O'],
#   [3, '300', 'O'],
#   [4, 'mln', 'O'],
#   [5, 'spread', 'O'],
#   [6, '-', 'O'],
#   [7, '12.5', 'O'],
#   [8, 'bp', 'O'],
#   [9, 'maturity', 'O'],
#   [10, '21.jan.99', 'O']],
#  [[1, 'type', 'O'],
#   [2, 'frn', 'O'],
#   [3, 'base', 'O'],
#   [4, '3m', 'B-ORG'],
#   [5, 'libor', 'O'],
#   [6, 'pay', 'O'],
#   [7, 'date', 'O'],
#   [8, 's23.sep.96', 'O']],
#  [[1, 'last', 'O'],
#   [2, 'moody', 'O'],
#   [3, 'aa3', 'O'],
#   [4, 'iss', 'O'],
#   [5, 'price', 'O'],
#   [6, '99.956', 'O'],
#   [7, 'full', 'O'],
#   [8, 'fees', 'O'],
#   [9, '10', 'O'],
#   [10, 'bp', 'O']],
#  [[1, 'last', 'O'],
#   [2, 's&p', 'B-ORG'],
#   [3, 'aa+', 'O'],
#   [4, 'reoffer', 'O'],
#   [5, '=', 'O']],
#  [[1, 'notes', 'O'],
#   [2, 's', 'O'],
#   [3, 'short', 'O'],
#   [4, 'first', 'O'],
#   [5, 'coupon', 'O']],
#  [[1, 'listing', 'O'],
#   [2, 'london', 'B-LOC'],
#   [3, 'denoms', 'O'],
#   [4, '(', 'O'],
#   [5, 'k', 'O'],
#   [6, ')', 'O'],
#   [7, '1-10-100', 'O'],
#   [8, 'sale', 'O'],
#   [9, 'limits', 'O'],
#   [10, 'us', 'B-LOC'],
#   [11, '/', 'O'],
#   [12, 'uk', 'B-LOC'],
#   [13, '/', 'O'],
#   [14, 'jp', 'B-LOC'],
#   [15, '/', 'O'],
#   [16, 'fr', 'B-LOC']],
#  [[1, 'neg', 'O'],
#   [2, 'plg', 'O'],
#   [3, 'yes', 'O'],
#   [4, 'crs', 'O'],
#   [5, 'deflt', 'O'],
#   [6, 'no', 'O'],
#   [7, 'force', 'O'],
#   [8, 'maj', 'O'],
#   [9, 'ipma', 'O'],
#   [10, '2', 'O']],
#  [[1, 'gov', 'O'],
#   [2, 'law', 'O'],
#   [3, 'english', 'B-MISC'],
#   [4, 'home', 'O'],
#   [5, 'ctry', 'O'],
#   [6, 'sweden', 'B-LOC'],
#   [7, 'tax', 'O'],
#   [8, 'provs', 'O'],
#   [9, 'standard', 'O']],
#  [[1, 'mgt', 'O'],
#   [2, '/', 'O'],
#   [3, 'und', 'O'],
#   [4, '5', 'O'],
#   [5, 'bp', 'O'],
#   [6, 'sell', 'O'],
#   [7, 'conc', 'O'],
#   [8, '5', 'O'],
#   [9, 'bp', 'O'],
#   [10, 'praecip', 'O'],
#   [11, '=', 'O']],
#  [[1, 'notes', 'O'],
#   [2, 'issued', 'O'],
#   [3, 'off', 'O'],
#   [4, 'emtn', 'O'],
#   [5, 'programme', 'O']],
#  [[1, '--', 'O'],
#   [2, 'london', 'B-ORG'],
#   [3, 'newsroom', 'I-ORG'],
#   [4, '+44', 'O'],
#   [5, '171', 'O'],
#   [6, '542', 'O'],
#   [7, '8863', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'port', 'O'],
#   [2, 'conditions', 'O'],
#   [3, 'update', 'O'],
#   [4, '-', 'O'],
#   [5, 'syria', 'B-LOC'],
#   [6, '-', 'O'],
#   [7, 'lloyds', 'B-ORG'],
#   [8, 'shipping', 'I-ORG'],
#   [9, '.', 'O']],
#  [[1, 'port', 'O'],
#   [2, 'conditions', 'O'],
#   [3, 'from', 'O'],
#   [4, 'lloyds', 'B-ORG'],
#   [5, 'shipping', 'I-ORG'],
#   [6, 'intelligence', 'I-ORG'],
#   [7, 'service', 'I-ORG'],
#   [8, '--', 'O']],
#  [[1, 'lattakia', 'B-LOC'],
#   [2, ',', 'O'],
#   [3, 'aug', 'O'],
#   [4, '10', 'O'],
#   [5, '-', 'O'],
#   [6, 'waiting', 'O'],
#   [7, 'time', 'O'],
#   [8, 'at', 'O'],
#   [9, 'lattakia', 'B-LOC'],
#   [10, 'and', 'O'],
#   [11, 'tartous', 'B-LOC'],
#   [12, 'presently', 'O'],
#   [13, '24', 'O'],
#   [14, 'hours', 'O'],
#   [15, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'israel', 'B-LOC'],
#   [2, 'plays', 'O'],
#   [3, 'down', 'O'],
#   [4, 'fears', 'O'],
#   [5, 'of', 'O'],
#   [6, 'war', 'O'],
#   [7, 'with', 'O'],
#   [8, 'syria', 'B-LOC'],
#   [9, '.', 'O']],
#  [[1, 'colleen', 'B-PER'], [2, 'siegel', 'I-PER']],
#  [[1, 'jerusalem', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'israel', 'B-LOC'],
#   [2, "'s", 'O'],
#   [3, 'outgoing', 'O'],
#   [4, 'peace', 'O'],
#   [5, 'negotiator', 'O'],
#   [6, 'with', 'O'],
#   [7, 'syria', 'B-LOC'],
#   [8, 'said', 'O'],
#   [9, 'on', 'O'],
#   [10, 'thursday', 'O'],
#   [11, 'current', 'O'],
#   [12, 'tensions', 'O'],
#   [13, 'between', 'O'],
#   [14, 'the', 'O'],
#   [15, 'two', 'O'],
#   [16, 'countries', 'O'],
#   [17, 'appeared', 'O'],
#   [18, 'to', 'O'],
#   [19, 'be', 'O'],
#   [20, 'a', 'O'],
#   [21, 'storm', 'O'],
#   [22, 'in', 'O'],
#   [23, 'a', 'O'],
#   [24, 'teacup', 'O'],
#   [25, '.', 'O']],
#  [[1, 'itamar', 'B-PER'],
#   [2, 'rabinovich', 'I-PER'],
#   [3, ',', 'O'],
#   [4, 'who', 'O'],
#   [5, 'as', 'O'],
#   [6, 'israel', 'B-LOC'],
#   [7, "'s", 'O'],
#   [8, 'ambassador', 'O'],
#   [9, 'to', 'O'],
#   [10, 'washington', 'B-LOC'],
#   [11, 'conducted', 'O'],
#   [12, 'unfruitful', 'O'],
#   [13, 'negotiations', 'O'],
#   [14, 'with', 'O'],
#   [15, 'syria', 'B-LOC'],
#   [16, ',', 'O'],
#   [17, 'told', 'O'],
#   [18, 'israel', 'B-ORG'],
#   [19, 'radio', 'I-ORG'],
#   [20, 'it', 'O'],
#   [21, 'looked', 'O'],
#   [22, 'like', 'O'],
#   [23, 'damascus', 'B-LOC'],
#   [24, 'wanted', 'O'],
#   [25, 'to', 'O'],
#   [26, 'talk', 'O'],
#   [27, 'rather', 'O'],
#   [28, 'than', 'O'],
#   [29, 'fight', 'O'],
#   [30, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'it', 'O'],
#   [3, 'appears', 'O'],
#   [4, 'to', 'O'],
#   [5, 'me', 'O'],
#   [6, 'the', 'O'],
#   [7, 'syrian', 'B-MISC'],
#   [8, 'priority', 'O'],
#   [9, 'is', 'O'],
#   [10, 'still', 'O'],
#   [11, 'to', 'O'],
#   [12, 'negotiate', 'O'],
#   [13, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'syrians', 'B-MISC'],
#   [3, 'are', 'O'],
#   [4, 'confused', 'O'],
#   [5, ',', 'O'],
#   [6, 'they', 'O'],
#   [7, 'are', 'O'],
#   [8, 'definitely', 'O'],
#   [9, 'tense', 'O'],
#   [10, ',', 'O'],
#   [11, 'but', 'O'],
#   [12, 'the', 'O'],
#   [13, 'general', 'O'],
#   [14, 'assessment', 'O'],
#   [15, 'here', 'O'],
#   [16, 'in', 'O'],
#   [17, 'washington', 'B-LOC'],
#   [18, 'is', 'O'],
#   [19, 'that', 'O'],
#   [20, 'this', 'O'],
#   [21, 'is', 'O'],
#   [22, 'essentially', 'O'],
#   [23, 'a', 'O'],
#   [24, 'storm', 'O'],
#   [25, 'in', 'O'],
#   [26, 'a', 'O'],
#   [27, 'teacup', 'O'],
#   [28, ',', 'O'],
#   [29, '"', 'O'],
#   [30, 'he', 'O'],
#   [31, 'said', 'O'],
#   [32, '.', 'O']],
#  [[1, 'rabinovich', 'B-PER'],
#   [2, 'is', 'O'],
#   [3, 'winding', 'O'],
#   [4, 'up', 'O'],
#   [5, 'his', 'O'],
#   [6, 'term', 'O'],
#   [7, 'as', 'O'],
#   [8, 'ambassador', 'O'],
#   [9, '.', 'O']],
#  [[1, 'he', 'O'],
#   [2, 'will', 'O'],
#   [3, 'be', 'O'],
#   [4, 'replaced', 'O'],
#   [5, 'by', 'O'],
#   [6, 'eliahu', 'B-PER'],
#   [7, 'ben-elissar', 'I-PER'],
#   [8, ',', 'O'],
#   [9, 'a', 'O'],
#   [10, 'former', 'O'],
#   [11, 'israeli', 'B-MISC'],
#   [12, 'envoy', 'O'],
#   [13, 'to', 'O'],
#   [14, 'egypt', 'B-LOC'],
#   [15, 'and', 'O'],
#   [16, 'right-wing', 'O'],
#   [17, 'likud', 'B-ORG'],
#   [18, 'party', 'O'],
#   [19, 'politician', 'O'],
#   [20, '.', 'O']],
#  [[1, 'israel', 'B-LOC'],
#   [2, 'on', 'O'],
#   [3, 'wednesday', 'O'],
#   [4, 'sent', 'O'],
#   [5, 'syria', 'B-LOC'],
#   [6, 'a', 'O'],
#   [7, 'message', 'O'],
#   [8, ',', 'O'],
#   [9, 'via', 'O'],
#   [10, 'washington', 'B-LOC'],
#   [11, ',', 'O'],
#   [12, 'saying', 'O'],
#   [13, 'it', 'O'],
#   [14, 'was', 'O'],
#   [15, 'committed', 'O'],
#   [16, 'to', 'O'],
#   [17, 'peace', 'O'],
#   [18, 'and', 'O'],
#   [19, 'wanted', 'O'],
#   [20, 'to', 'O'],
#   [21, 'open', 'O'],
#   [22, 'negotiations', 'O'],
#   [23, 'without', 'O'],
#   [24, 'preconditions', 'O'],
#   [25, '.', 'O']],
#  [[1, 'but', 'O'],
#   [2, 'it', 'O'],
#   [3, 'slammed', 'O'],
#   [4, 'damascus', 'B-LOC'],
#   [5, 'for', 'O'],
#   [6, 'creating', 'O'],
#   [7, 'what', 'O'],
#   [8, 'it', 'O'],
#   [9, 'called', 'O'],
#   [10, 'a', 'O'],
#   [11, 'dangerous', 'O'],
#   [12, 'atmosphere', 'O'],
#   [13, '.', 'O']],
#  [[1, 'syria', 'B-LOC'],
#   [2, 'accused', 'O'],
#   [3, 'israel', 'B-LOC'],
#   [4, 'on', 'O'],
#   [5, 'wednesday', 'O'],
#   [6, 'of', 'O'],
#   [7, 'launching', 'O'],
#   [8, 'a', 'O'],
#   [9, 'hysterical', 'O'],
#   [10, 'campaign', 'O'],
#   [11, 'against', 'O'],
#   [12, 'it', 'O'],
#   [13, 'after', 'O'],
#   [14, 'israeli', 'B-MISC'],
#   [15, 'television', 'O'],
#   [16, 'reported', 'O'],
#   [17, 'that', 'O'],
#   [18, 'damascus', 'B-LOC'],
#   [19, 'had', 'O'],
#   [20, 'recently', 'O'],
#   [21, 'test', 'O'],
#   [22, 'fired', 'O'],
#   [23, 'a', 'O'],
#   [24, 'missile', 'O'],
#   [25, '.', 'O']],
#  [[1, 'it', 'O'],
#   [2, 'said', 'O'],
#   [3, 'its', 'O'],
#   [4, 'arms', 'O'],
#   [5, 'purchases', 'O'],
#   [6, 'were', 'O'],
#   [7, 'for', 'O'],
#   [8, 'defensive', 'O'],
#   [9, 'purposes', 'O'],
#   [10, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'the', 'O'],
#   [3, 'message', 'O'],
#   [4, 'that', 'O'],
#   [5, 'we', 'O'],
#   [6, 'sent', 'O'],
#   [7, 'to', 'O'],
#   [8, '(', 'O'],
#   [9, 'syrian', 'B-MISC'],
#   [10, 'president', 'O'],
#   [11, 'hafez', 'B-PER'],
#   [12, 'al-', 'I-PER'],
#   [13, ')', 'O'],
#   [14, 'assad', 'B-PER'],
#   [15, 'is', 'O'],
#   [16, 'that', 'O'],
#   [17, 'israel', 'B-LOC'],
#   [18, 'is', 'O'],
#   [19, 'ready', 'O'],
#   [20, 'at', 'O'],
#   [21, 'any', 'O'],
#   [22, 'time', 'O'],
#   [23, 'without', 'O'],
#   [24, 'preconditions', 'O'],
#   [25, 'to', 'O'],
#   [26, 'enter', 'O'],
#   [27, 'peace', 'O'],
#   [28, 'negotiations', 'O'],
#   [29, ',', 'O'],
#   [30, '"', 'O'],
#   [31, 'israeli', 'B-MISC'],
#   [32, 'foreign', 'O'],
#   [33, 'minister', 'O'],
#   [34, 'david', 'B-PER'],
#   [35, 'levy', 'I-PER'],
#   [36, 'told', 'O'],
#   [37, 'israel', 'B-ORG'],
#   [38, 'radio', 'I-ORG'],
#   [39, 'in', 'O'],
#   [40, 'an', 'O'],
#   [41, 'interview', 'O'],
#   [42, '.', 'O']],
#  [[1, 'tension', 'O'],
#   [2, 'has', 'O'],
#   [3, 'mounted', 'O'],
#   [4, 'since', 'O'],
#   [5, 'israeli', 'B-MISC'],
#   [6, 'prime', 'O'],
#   [7, 'minister', 'O'],
#   [8, 'benjamin', 'B-PER'],
#   [9, 'netanyahu', 'I-PER'],
#   [10, 'took', 'O'],
#   [11, 'office', 'O'],
#   [12, 'in', 'O'],
#   [13, 'june', 'O'],
#   [14, 'vowing', 'O'],
#   [15, 'to', 'O'],
#   [16, 'retain', 'O'],
#   [17, 'the', 'O'],
#   [18, 'golan', 'B-LOC'],
#   [19, 'heights', 'I-LOC'],
#   [20, 'israel', 'B-LOC'],
#   [21, 'captured', 'O'],
#   [22, 'from', 'O'],
#   [23, 'syria', 'B-LOC'],
#   [24, 'in', 'O'],
#   [25, 'the', 'O'],
#   [26, '1967', 'O'],
#   [27, 'middle', 'B-LOC'],
#   [28, 'east', 'I-LOC'],
#   [29, 'war', 'O'],
#   [30, '.', 'O']],
#  [[1, 'israeli-syrian', 'B-MISC'],
#   [2, 'peace', 'O'],
#   [3, 'talks', 'O'],
#   [4, 'have', 'O'],
#   [5, 'been', 'O'],
#   [6, 'deadlocked', 'O'],
#   [7, 'over', 'O'],
#   [8, 'the', 'O'],
#   [9, 'golan', 'B-LOC'],
#   [10, 'since', 'O'],
#   [11, '1991', 'O'],
#   [12, 'despite', 'O'],
#   [13, 'the', 'O'],
#   [14, 'previous', 'O'],
#   [15, 'government', 'O'],
#   [16, "'s", 'O'],
#   [17, 'willingness', 'O'],
#   [18, 'to', 'O'],
#   [19, 'make', 'O'],
#   [20, 'golan', 'B-LOC'],
#   [21, 'concessions', 'O'],
#   [22, '.', 'O']],
#  [[1, 'peace', 'O'],
#   [2, 'talks', 'O'],
#   [3, 'between', 'O'],
#   [4, 'the', 'O'],
#   [5, 'two', 'O'],
#   [6, 'sides', 'O'],
#   [7, 'were', 'O'],
#   [8, 'last', 'O'],
#   [9, 'held', 'O'],
#   [10, 'in', 'O'],
#   [11, 'february', 'O'],
#   [12, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'the', 'O'],
#   [3, 'voices', 'O'],
#   [4, 'coming', 'O'],
#   [5, 'out', 'O'],
#   [6, 'of', 'O'],
#   [7, 'damascus', 'B-LOC'],
#   [8, 'are', 'O'],
#   [9, 'bad', 'O'],
#   [10, ',', 'O'],
#   [11, 'not', 'O'],
#   [12, 'good', 'O'],
#   [13, '.', 'O']],
#  [[1, 'the', 'O'], [2, 'media', 'O'], [3, '...', 'O']],
#  [[1, 'are', 'O'],
#   [2, 'full', 'O'],
#   [3, 'of', 'O'],
#   [4, 'expressions', 'O'],
#   [5, 'and', 'O'],
#   [6, 'declarations', 'O'],
#   [7, 'that', 'O'],
#   [8, 'must', 'O'],
#   [9, 'be', 'O'],
#   [10, 'worrying', 'O'],
#   [11, '...', 'O']],
#  [[1, 'this', 'O'],
#   [2, 'artificial', 'O'],
#   [3, 'atmosphere', 'O'],
#   [4, 'is', 'O'],
#   [5, 'very', 'O'],
#   [6, 'dangerous', 'O'],
#   [7, 'because', 'O'],
#   [8, 'those', 'O'],
#   [9, 'who', 'O'],
#   [10, 'spread', 'O'],
#   [11, 'it', 'O'],
#   [12, 'could', 'O'],
#   [13, 'become', 'O'],
#   [14, 'its', 'O'],
#   [15, 'prisoners', 'O'],
#   [16, ',', 'O'],
#   [17, '"', 'O'],
#   [18, 'levy', 'B-PER'],
#   [19, 'said', 'O'],
#   [20, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'we', 'O'],
#   [3, 'expect', 'O'],
#   [4, 'from', 'O'],
#   [5, 'syria', 'B-LOC'],
#   [6, ',', 'O'],
#   [7, 'if', 'O'],
#   [8, 'its', 'O'],
#   [9, 'face', 'O'],
#   [10, 'is', 'O'],
#   [11, 'to', 'O'],
#   [12, 'peace', 'O'],
#   [13, ',', 'O'],
#   [14, 'that', 'O'],
#   [15, 'it', 'O'],
#   [16, 'will', 'O'],
#   [17, 'answer', 'O'],
#   [18, 'israel', 'B-LOC'],
#   [19, "'s", 'O'],
#   [20, 'message', 'O'],
#   [21, 'to', 'O'],
#   [22, 'enter', 'O'],
#   [23, 'peace', 'O'],
#   [24, 'negotiations', 'O'],
#   [25, 'because', 'O'],
#   [26, 'that', 'O'],
#   [27, 'is', 'O'],
#   [28, 'our', 'O'],
#   [29, 'goal', 'O'],
#   [30, ',', 'O'],
#   [31, '"', 'O'],
#   [32, 'he', 'O'],
#   [33, 'said', 'O'],
#   [34, '.', 'O'],
#   [35, '"', 'O']],
#  [[1, 'we', 'O'],
#   [2, 'do', 'O'],
#   [3, 'not', 'O'],
#   [4, 'want', 'O'],
#   [5, 'a', 'O'],
#   [6, 'war', 'O'],
#   [7, ',', 'O'],
#   [8, 'god', 'B-PER'],
#   [9, 'forbid', 'O'],
#   [10, '.', 'O']],
#  [[1, 'no', 'O'],
#   [2, 'one', 'O'],
#   [3, 'benefits', 'O'],
#   [4, 'from', 'O'],
#   [5, 'wars', 'O'],
#   [6, '.', 'O'],
#   [7, '"', 'O']],
#  [[1, 'israel', 'B-LOC'],
#   [2, "'s", 'O'],
#   [3, 'channel', 'B-ORG'],
#   [4, 'two', 'I-ORG'],
#   [5, 'television', 'O'],
#   [6, 'said', 'O'],
#   [7, 'damascus', 'B-LOC'],
#   [8, 'had', 'O'],
#   [9, 'sent', 'O'],
#   [10, 'a', 'O'],
#   [11, '"', 'O'],
#   [12, 'calming', 'O'],
#   [13, 'signal', 'O'],
#   [14, '"', 'O'],
#   [15, 'to', 'O'],
#   [16, 'israel', 'B-LOC'],
#   [17, '.', 'O']],
#  [[1, 'it', 'O'],
#   [2, 'gave', 'O'],
#   [3, 'no', 'O'],
#   [4, 'source', 'O'],
#   [5, 'for', 'O'],
#   [6, 'the', 'O'],
#   [7, 'report', 'O'],
#   [8, '.', 'O']],
#  [[1, 'netanyahu', 'B-PER'],
#   [2, 'and', 'O'],
#   [3, 'levy', 'B-PER'],
#   [4, "'s", 'O'],
#   [5, 'spokesmen', 'O'],
#   [6, 'said', 'O'],
#   [7, 'they', 'O'],
#   [8, 'could', 'O'],
#   [9, 'not', 'O'],
#   [10, 'confirm', 'O'],
#   [11, 'it', 'O'],
#   [12, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'television', 'O'],
#   [3, 'also', 'O'],
#   [4, 'said', 'O'],
#   [5, 'that', 'O'],
#   [6, 'netanyahu', 'B-PER'],
#   [7, 'had', 'O'],
#   [8, 'sent', 'O'],
#   [9, 'messages', 'O'],
#   [10, 'to', 'O'],
#   [11, 'reassure', 'O'],
#   [12, 'syria', 'B-LOC'],
#   [13, 'via', 'O'],
#   [14, 'cairo', 'B-LOC'],
#   [15, ',', 'O'],
#   [16, 'the', 'O'],
#   [17, 'united', 'B-LOC'],
#   [18, 'states', 'I-LOC'],
#   [19, 'and', 'O'],
#   [20, 'moscow', 'B-LOC'],
#   [21, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'polish', 'B-MISC'],
#   [2, 'diplomat', 'O'],
#   [3, 'denies', 'O'],
#   [4, 'nurses', 'O'],
#   [5, 'stranded', 'O'],
#   [6, 'in', 'O'],
#   [7, 'libya', 'B-LOC'],
#   [8, '.', 'O']],
#  [[1, 'tunis', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'a', 'O'],
#   [2, 'polish', 'B-MISC'],
#   [3, 'diplomat', 'O'],
#   [4, 'on', 'O'],
#   [5, 'thursday', 'O'],
#   [6, 'denied', 'O'],
#   [7, 'a', 'O'],
#   [8, 'polish', 'B-MISC'],
#   [9, 'tabloid', 'O'],
#   [10, 'report', 'O'],
#   [11, 'this', 'O'],
#   [12, 'week', 'O'],
#   [13, 'that', 'O'],
#   [14, 'libya', 'B-LOC'],
#   [15, 'was', 'O'],
#   [16, 'refusing', 'O'],
#   [17, 'exit', 'O'],
#   [18, 'visas', 'O'],
#   [19, 'to', 'O'],
#   [20, '100', 'O'],
#   [21, 'polish', 'B-MISC'],
#   [22, 'nurses', 'O'],
#   [23, 'trying', 'O'],
#   [24, 'to', 'O'],
#   [25, 'return', 'O'],
#   [26, 'home', 'O'],
#   [27, 'after', 'O'],
#   [28, 'working', 'O'],
#   [29, 'in', 'O'],
#   [30, 'the', 'O'],
#   [31, 'north', 'B-MISC'],
#   [32, 'african', 'I-MISC'],
#   [33, 'country', 'O'],
#   [34, '.', 'O']],
#  [[1, '"', 'O'],
#   [2, 'this', 'O'],
#   [3, 'is', 'O'],
#   [4, 'not', 'O'],
#   [5, 'true', 'O'],
#   [6, '.', 'O']],
#  [[1, 'up', 'O'],
#   [2, 'to', 'O'],
#   [3, 'today', 'O'],
#   [4, ',', 'O'],
#   [5, 'we', 'O'],
#   [6, 'have', 'O'],
#   [7, 'no', 'O'],
#   [8, 'knowledge', 'O'],
#   [9, 'of', 'O'],
#   [10, 'any', 'O'],
#   [11, 'nurse', 'O'],
#   [12, 'stranded', 'O'],
#   [13, 'or', 'O'],
#   [14, 'kept', 'O'],
#   [15, 'in', 'O'],
#   [16, 'libya', 'B-LOC'],
#   [17, 'without', 'O'],
#   [18, 'her', 'O'],
#   [19, 'will', 'O'],
#   [20, ',', 'O'],
#   [21, 'and', 'O'],
#   [22, 'we', 'O'],
#   [23, 'have', 'O'],
#   [24, 'not', 'O'],
#   [25, 'received', 'O'],
#   [26, 'any', 'O'],
#   [27, 'complaint', 'O'],
#   [28, ',', 'O'],
#   [29, '"', 'O'],
#   [30, 'the', 'O'],
#   [31, 'polish', 'B-MISC'],
#   [32, 'embassy', 'O'],
#   [33, "'s", 'O'],
#   [34, 'charge', 'O'],
#   [35, "d'affaires", 'O'],
#   [36, 'in', 'O'],
#   [37, 'tripoli', 'B-LOC'],
#   [38, ',', 'O'],
#   [39, 'tadeusz', 'B-PER'],
#   [40, 'awdankiewicz', 'I-PER'],
#   [41, ',', 'O'],
#   [42, 'told', 'O'],
#   [43, 'reuters', 'B-ORG'],
#   [44, 'by', 'O'],
#   [45, 'telephone', 'O'],
#   [46, '.', 'O']],
#  [[1, 'poland', 'B-LOC'],
#   [2, "'s", 'O'],
#   [3, 'labour', 'O'],
#   [4, 'ministry', 'O'],
#   [5, 'said', 'O'],
#   [6, 'this', 'O'],
#   [7, 'week', 'O'],
#   [8, 'it', 'O'],
#   [9, 'would', 'O'],
#   [10, 'send', 'O'],
#   [11, 'a', 'O'],
#   [12, 'team', 'O'],
#   [13, 'to', 'O'],
#   [14, 'libya', 'B-LOC'],
#   [15, 'to', 'O'],
#   [16, 'investigate', 'O'],
#   [17, ',', 'O'],
#   [18, 'but', 'O'],
#   [19, 'awdankiewicz', 'B-PER'],
#   [20, 'said', 'O'],
#   [21, 'the', 'O'],
#   [22, 'probe', 'O'],
#   [23, 'was', 'O'],
#   [24, 'prompted', 'O'],
#   [25, 'by', 'O'],
#   [26, 'some', 'O'],
#   [27, 'nurses', 'O'],
#   [28, 'complaining', 'O'],
#   [29, 'about', 'O'],
#   [30, 'their', 'O'],
#   [31, 'work', 'O'],
#   [32, 'conditions', 'O'],
#   [33, 'such', 'O'],
#   [34, 'as', 'O'],
#   [35, 'non-payment', 'O'],
#   [36, 'of', 'O'],
#   [37, 'their', 'O'],
#   [38, 'salaries', 'O'],
#   [39, '.', 'O']],
#  [[1, 'he', 'O'],
#   [2, 'said', 'O'],
#   [3, 'that', 'O'],
#   [4, 'there', 'O'],
#   [5, 'are', 'O'],
#   [6, 'an', 'O'],
#   [7, 'estimated', 'O'],
#   [8, '800', 'O'],
#   [9, 'polish', 'B-MISC'],
#   [10, 'nurses', 'O'],
#   [11, 'working', 'O'],
#   [12, 'in', 'O'],
#   [13, 'libya', 'B-LOC'],
#   [14, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'two', 'O'],
#   [2, 'iranian', 'B-MISC'],
#   [3, 'opposition', 'O'],
#   [4, 'leaders', 'O'],
#   [5, 'meet', 'O'],
#   [6, 'in', 'O'],
#   [7, 'baghdad', 'B-LOC'],
#   [8, '.', 'O']],
#  [[1, 'hassan', 'B-PER'], [2, 'hafidh', 'I-PER']],
#  [[1, 'baghdad', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'an', 'O'],
# ...
#   [7, 'the', 'O'],
#   [8, '54th', 'O'],
#   [9, 'minute', 'O'],
#   [10, 'and', 'O'],
#   [11, 'from', 'O'],
#   [12, 'a', 'O'],
#   [13, 'bicycle', 'O'],
#   [14, 'kick', 'O'],
#   [15, '13', 'O'],
#   [16, 'minutes', 'O'],
#   [17, 'later', 'O'],
#   [18, '.', 'O']],
#  [[1, 'arthur', 'B-PER'],
#   [2, 'numan', 'I-PER'],
#   [3, 'and', 'O'],
#   [4, 'luc', 'B-PER'],
#   [5, 'nilis', 'I-PER'],
#   [6, ',', 'O'],
#   [7, 'dutch', 'B-MISC'],
#   [8, 'top', 'O'],
#   [9, 'scorer', 'O'],
#   [10, 'last', 'O'],
#   [11, 'season', 'O'],
#   [12, ',', 'O'],
#   [13, 'were', 'O'],
#   [14, 'psv', 'B-ORG'],
#   [15, "'s", 'O'],
#   [16, 'other', 'O'],
#   [17, 'marksmen', 'O'],
#   [18, '.', 'O']],
#  [[1, 'ajax', 'B-ORG'],
#   [2, 'amsterdam', 'I-ORG'],
#   [3, 'opened', 'O'],
#   [4, 'their', 'O'],
#   [5, 'title', 'O'],
#   [6, 'defence', 'O'],
#   [7, 'with', 'O'],
#   [8, 'a', 'O'],
#   [9, '1-0', 'O'],
#   [10, 'win', 'O'],
#   [11, 'over', 'O'],
#   [12, 'nac', 'B-ORG'],
#   [13, 'breda', 'I-ORG'],
#   [14, 'on', 'O'],
#   [15, 'wednesday', 'O'],
#   [16, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'soccer', 'O'],
#   [2, '-', 'O'],
#   [3, 'dutch', 'B-MISC'],
#   [4, 'first', 'O'],
#   [5, 'division', 'O'],
#   [6, 'summary', 'O'],
#   [7, '.', 'O']],
#  [[1, 'amsterdam', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'summary', 'O'],
#   [2, 'of', 'O'],
#   [3, 'thursday', 'O'],
#   [4, "'s", 'O'],
#   [5, 'only', 'O']],
#  [[1, 'dutch', 'B-MISC'],
#   [2, 'first', 'O'],
#   [3, 'division', 'O'],
#   [4, 'match', 'O'],
#   [5, ':', 'O']],
#  [[1, 'nec', 'B-ORG'],
#   [2, 'nijmegen', 'I-ORG'],
#   [3, '1', 'O'],
#   [4, '(', 'O'],
#   [5, 'van', 'O'],
#   [6, 'eykeren', 'O'],
#   [7, '15th', 'O'],
#   [8, ')', 'O'],
#   [9, 'psv', 'B-ORG'],
#   [10, 'eindhoven', 'I-ORG'],
#   [11, '4', 'O'],
#   [12, '(', 'O'],
#   [13, 'numan', 'O'],
#   [14, '11th', 'O'],
#   [15, ',', 'O']],
#  [[1, 'nilis', 'B-PER'],
#   [2, '42nd', 'O'],
#   [3, ',', 'O'],
#   [4, 'cocu', 'B-PER'],
#   [5, '54th', 'O'],
#   [6, ',', 'O'],
#   [7, '67th', 'O'],
#   [8, ')', 'O'],
#   [9, '.', 'O']],
#  [[1, 'halftime', 'O'], [2, '1-2', 'O'], [3, '.', 'O']],
#  [[1, 'attendance', 'O'], [2, '8,000', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'soccer', 'O'],
#   [2, '-', 'O'],
#   [3, 'dutch', 'B-MISC'],
#   [4, 'first', 'O'],
#   [5, 'division', 'O'],
#   [6, 'result', 'O'],
#   [7, '.', 'O']],
#  [[1, 'amsterdam', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'result', 'O'],
#   [2, 'of', 'O'],
#   [3, 'a', 'O'],
#   [4, 'dutch', 'B-MISC'],
#   [5, 'first', 'O']],
#  [[1, 'division', 'O'],
#   [2, 'match', 'O'],
#   [3, 'on', 'O'],
#   [4, 'thursday', 'O'],
#   [5, ':', 'O']],
#  [[1, 'nec', 'B-ORG'],
#   [2, 'nijmegen', 'I-ORG'],
#   [3, '1', 'O'],
#   [4, 'psv', 'B-ORG'],
#   [5, 'eindhoven', 'I-ORG'],
#   [6, '4', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'soccer', 'O'],
#   [2, '-', 'O'],
#   [3, 'sharpshooter', 'O'],
#   [4, 'knup', 'B-PER'],
#   [5, 'back', 'O'],
#   [6, 'in', 'O'],
#   [7, 'swiss', 'B-MISC'],
#   [8, 'squad', 'O'],
#   [9, '.', 'O']],
#  [[1, 'geneva', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'galatasaray', 'B-ORG'],
#   [2, 'striker', 'O'],
#   [3, 'adrian', 'B-PER'],
#   [4, 'knup', 'I-PER'],
#   [5, ',', 'O'],
#   [6, 'scorer', 'O'],
#   [7, 'of', 'O'],
#   [8, '26', 'O'],
#   [9, 'goals', 'O'],
#   [10, 'in', 'O'],
#   [11, '45', 'O'],
#   [12, 'internationals', 'O'],
#   [13, ',', 'O'],
#   [14, 'has', 'O'],
#   [15, 'been', 'O'],
#   [16, 'recalled', 'O'],
#   [17, 'by', 'O'],
#   [18, 'switzerland', 'B-LOC'],
#   [19, 'for', 'O'],
#   [20, 'the', 'O'],
#   [21, 'world', 'B-MISC'],
#   [22, 'cup', 'I-MISC'],
#   [23, 'qualifier', 'O'],
#   [24, 'against', 'O'],
#   [25, 'azerbaijan', 'B-LOC'],
#   [26, 'in', 'O'],
#   [27, 'baku', 'B-LOC'],
#   [28, 'on', 'O'],
#   [29, 'august', 'O'],
#   [30, '31', 'O'],
#   [31, '.', 'O']],
#  [[1, 'knup', 'B-PER'],
#   [2, 'was', 'O'],
#   [3, 'overlooked', 'O'],
#   [4, 'by', 'O'],
#   [5, 'artur', 'B-PER'],
#   [6, 'jorge', 'I-PER'],
#   [7, 'for', 'O'],
#   [8, 'the', 'O'],
#   [9, 'european', 'B-MISC'],
#   [10, 'championship', 'O'],
#   [11, 'finals', 'O'],
#   [12, 'earlier', 'O'],
#   [13, 'this', 'O'],
#   [14, 'year', 'O'],
#   [15, '.', 'O']],
#  [[1, 'but', 'O'],
#   [2, 'new', 'O'],
#   [3, 'coach', 'O'],
#   [4, 'rolf', 'B-PER'],
#   [5, 'fringer', 'I-PER'],
#   [6, 'is', 'O'],
#   [7, 'clearly', 'O'],
#   [8, 'a', 'O'],
#   [9, 'knup', 'B-PER'],
#   [10, 'fan', 'O'],
#   [11, 'and', 'O'],
#   [12, 'included', 'O'],
#   [13, 'him', 'O'],
#   [14, 'in', 'O'],
#   [15, 'his', 'O'],
#   [16, '19-man', 'O'],
#   [17, 'squad', 'O'],
#   [18, 'on', 'O'],
#   [19, 'thursday', 'O'],
#   [20, '.', 'O']],
#  [[1, 'switzerland', 'B-LOC'],
#   [2, 'failed', 'O'],
#   [3, 'to', 'O'],
#   [4, 'progress', 'O'],
#   [5, 'beyond', 'O'],
#   [6, 'the', 'O'],
#   [7, 'opening', 'O'],
#   [8, 'group', 'O'],
#   [9, 'phase', 'O'],
#   [10, 'in', 'O'],
#   [11, 'euro', 'B-MISC'],
#   [12, '96', 'I-MISC'],
#   [13, '.', 'O']],
#  [[1, 'squad', 'O'], [2, ':', 'O']],
#  [[1, 'goalkeepers', 'O'],
#   [2, '-', 'O'],
#   [3, 'marco', 'B-PER'],
#   [4, 'pascolo', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'cagliari', 'B-ORG'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'pascal', 'B-PER'],
#   [10, 'zuberbuehler', 'I-PER'],
#   [11, '(', 'O'],
#   [12, 'grasshoppers', 'B-ORG'],
#   [13, ')', 'O'],
#   [14, '.', 'O']],
#  [[1, 'defenders', 'O'],
#   [2, '-', 'O'],
#   [3, 'stephane', 'B-PER'],
#   [4, 'henchoz', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'hamburg', 'B-ORG'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'marc', 'B-PER'],
#   [10, 'hottiger', 'I-PER'],
#   [11, '(', 'O'],
#   [12, 'everton', 'B-ORG'],
#   [13, ')', 'O'],
#   [14, ',', 'O'],
#   [15, 'yvan', 'B-PER'],
#   [16, 'quentin', 'I-PER'],
#   [17, '(', 'O'],
#   [18, 'sion', 'B-ORG'],
#   [19, ')', 'O'],
#   [20, ',', 'O'],
#   [21, 'ramon', 'B-PER'],
#   [22, 'vega', 'I-PER'],
#   [23, '(', 'O'],
#   [24, 'cagliari', 'B-ORG'],
#   [25, ')', 'O'],
#   [26, 'raphael', 'B-PER'],
#   [27, 'wicky', 'I-PER'],
#   [28, '(', 'O'],
#   [29, 'sion', 'B-ORG'],
#   [30, ')', 'O'],
#   [31, '.', 'O']],
#  [[1, 'midfielders', 'O'],
#   [2, '-', 'O'],
#   [3, 'alexandre', 'B-PER'],
#   [4, 'comisetti', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'grasshoppers', 'B-ORG'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'antonio', 'B-PER'],
#   [10, 'esposito', 'I-PER'],
#   [11, '(', 'O'],
#   [12, 'grasshoppers', 'B-ORG'],
#   [13, ')', 'O'],
#   [14, ',', 'O'],
#   [15, 'sebastien', 'B-PER'],
#   [16, 'fournier', 'I-PER'],
#   [17, '(', 'O'],
#   [18, 'stuttgart', 'B-LOC'],
#   [19, ')', 'O'],
#   [20, ',', 'O'],
#   [21, 'christophe', 'B-PER'],
#   [22, 'ohrel', 'I-PER'],
#   [23, '(', 'O'],
#   [24, 'lausanne', 'B-LOC'],
#   [25, ')', 'O'],
#   [26, ',', 'O'],
#   [27, 'patrick', 'B-PER'],
#   [28, 'sylvestre', 'I-PER'],
#   [29, '(', 'O'],
#   [30, 'sion', 'B-ORG'],
#   [31, ')', 'O'],
#   [32, ',', 'O'],
#   [33, 'david', 'B-PER'],
#   [34, 'sesa', 'I-PER'],
#   [35, '(', 'O'],
#   [36, 'servette', 'B-ORG'],
#   [37, ')', 'O'],
#   [38, ',', 'O'],
#   [39, 'ciriaco', 'B-PER'],
#   [40, 'sforza', 'I-PER'],
#   [41, '(', 'O'],
#   [42, 'inter', 'B-ORG'],
#   [43, 'milan', 'I-ORG'],
#   [44, ')', 'O'],
#   [45, 'murat', 'B-PER'],
#   [46, 'yakin', 'I-PER'],
#   [47, '(', 'O'],
#   [48, 'grasshoppers', 'B-ORG'],
#   [49, ')', 'O'],
#   [50, '.', 'O']],
#  [[1, 'strikers', 'O'],
#   [2, '-', 'O'],
#   [3, 'kubilay', 'B-PER'],
#   [4, 'turkyilmaz', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'grasshoppers', 'B-ORG'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'adrian', 'B-PER'],
#   [10, 'knup', 'I-PER'],
#   [11, '(', 'O'],
#   [12, 'galatasaray', 'B-ORG'],
#   [13, ')', 'O'],
#   [14, ',', 'O'],
#   [15, 'christophe', 'B-PER'],
#   [16, 'bonvin', 'I-PER'],
#   [17, '(', 'O'],
#   [18, 'sion', 'B-ORG'],
#   [19, ')', 'O'],
#   [20, ',', 'O'],
#   [21, 'stephane', 'B-PER'],
#   [22, 'chapuisat', 'I-PER'],
#   [23, '(', 'O'],
#   [24, 'borussia', 'B-ORG'],
#   [25, 'dortmund', 'I-ORG'],
#   [26, ')', 'O'],
#   [27, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'athletics', 'O'],
#   [2, '-', 'O'],
#   [3, 'it', 'O'],
#   [4, "'s", 'O'],
#   [5, 'a', 'O'],
#   [6, 'record', 'O'],
#   [7, '-', 'O'],
#   [8, '40,000', 'O'],
#   [9, 'beers', 'O'],
#   [10, 'on', 'O'],
#   [11, 'the', 'O'],
#   [12, 'house', 'O'],
#   [13, '.', 'O']],
#  [[1, 'brussels', 'B-LOC'], [2, '1996-08-22', 'O']],
#  [[1, 'spectators', 'O'],
#   [2, 'at', 'O'],
#   [3, 'friday', 'O'],
#   [4, "'s", 'O'],
#   [5, 'brussels', 'B-LOC'],
#   [6, 'grand', 'O'],
#   [7, 'prix', 'O'],
#   [8, 'meeting', 'O'],
#   [9, 'have', 'O'],
#   [10, 'an', 'O'],
#   [11, 'extra', 'O'],
#   [12, 'incentive', 'O'],
#   [13, 'to', 'O'],
#   [14, 'cheer', 'O'],
#   [15, 'on', 'O'],
#   [16, 'the', 'O'],
#   [17, 'athletes', 'O'],
#   [18, 'to', 'O'],
#   [19, 'world', 'O'],
#   [20, 'record', 'O'],
#   [21, 'performances', 'O'],
#   [22, '--', 'O'],
#   [23, 'a', 'O'],
#   [24, 'free', 'O'],
#   [25, 'glass', 'O'],
#   [26, 'of', 'O'],
#   [27, 'beer', 'O'],
#   [28, '.', 'O']],
#  [[1, 'a', 'O'],
#   [2, 'belgian', 'B-MISC'],
#   [3, 'brewery', 'O'],
#   [4, 'has', 'O'],
#   [5, 'offered', 'O'],
#   [6, 'to', 'O'],
#   [7, 'pay', 'O'],
#   [8, 'for', 'O'],
#   [9, 'a', 'O'],
#   [10, 'free', 'O'],
#   [11, 'round', 'O'],
#   [12, 'of', 'O'],
#   [13, 'drinks', 'O'],
#   [14, 'for', 'O'],
#   [15, 'all', 'O'],
#   [16, 'of', 'O'],
#   [17, 'the', 'O'],
#   [18, '40,000', 'O'],
#   [19, 'crowd', 'O'],
#   [20, 'if', 'O'],
#   [21, 'a', 'O'],
#   [22, 'world', 'O'],
#   [23, 'record', 'O'],
#   [24, 'goes', 'O'],
#   [25, 'at', 'O'],
#   [26, 'the', 'O'],
#   [27, 'meeting', 'O'],
#   [28, ',', 'O'],
#   [29, 'organisers', 'O'],
#   [30, 'said', 'O'],
#   [31, 'on', 'O'],
#   [32, 'thursday', 'O'],
#   [33, '.', 'O']],
#  [[1, 'it', 'O'],
#   [2, 'could', 'O'],
#   [3, 'be', 'O'],
#   [4, 'one', 'O'],
#   [5, 'of', 'O'],
#   [6, 'the', 'O'],
#   [7, 'most', 'O'],
#   [8, 'expensive', 'O'],
#   [9, 'rounds', 'O'],
#   [10, 'of', 'O'],
#   [11, 'drinks', 'O'],
#   [12, 'ever', 'O'],
#   [13, '.', 'O']],
#  [[1, 'the', 'O'],
#   [2, 'meeting', 'O'],
#   [3, 'is', 'O'],
#   [4, 'sold', 'O'],
#   [5, 'out', 'O'],
#   [6, 'already', 'O'],
#   [7, '.', 'O']],
#  [[1, 'two', 'O'],
#   [2, 'world', 'O'],
#   [3, 'records', 'O'],
#   [4, 'are', 'O'],
#   [5, 'in', 'O'],
#   [6, 'serious', 'O'],
#   [7, 'danger', 'O'],
#   [8, 'of', 'O'],
#   [9, 'being', 'O'],
#   [10, 'broken', 'O'],
#   [11, 'at', 'O'],
#   [12, 'the', 'O'],
#   [13, 'meeting', 'O'],
#   [14, '--', 'O'],
#   [15, 'the', 'O'],
#   [16, 'women', 'O'],
#   [17, "'s", 'O'],
#   [18, '1,000', 'O'],
#   [19, 'metres', 'O'],
#   [20, 'and', 'O'],
#   [21, 'the', 'O'],
#   [22, 'men', 'O'],
#   [23, "'s", 'O'],
#   [24, '3,000', 'O'],
#   [25, 'metres', 'O'],
#   [26, '.', 'O']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'golf', 'O'],
#   [2, '-', 'O'],
#   [3, 'german', 'B-MISC'],
#   [4, 'open', 'I-MISC'],
#   [5, 'first', 'O'],
#   [6, 'round', 'O'],
#   [7, 'scores', 'O'],
#   [8, '.', 'O']],
#  [[1, 'stuttgart', 'B-LOC'],
#   [2, ',', 'O'],
#   [3, 'germany', 'B-LOC'],
#   [4, '1996-08-22', 'O']],
#  [[1, 'leading', 'O'], [2, 'first', 'O'], [3, 'round', 'O']],
#  [[1, 'scores', 'O'],
#   [2, 'in', 'O'],
#   [3, 'the', 'O'],
#   [4, 'german', 'B-MISC'],
#   [5, 'open', 'I-MISC'],
#   [6, 'golf', 'O'],
#   [7, 'championship', 'O'],
#   [8, 'on', 'O'],
#   [9, 'thursday', 'O'],
#   [10, '(', 'O'],
#   [11, 'britain', 'B-LOC']],
#  [[1, 'unless', 'O'], [2, 'stated', 'O'], [3, ')', 'O'], [4, ':', 'O']],
#  [[1, '62', 'O'], [2, 'paul', 'B-PER'], [3, 'broadhurst', 'I-PER']],
#  [[1, '63', 'O'], [2, 'raymond', 'B-PER'], [3, 'russell', 'I-PER']],
#  [[1, '64', 'O'],
#   [2, 'david', 'B-PER'],
#   [3, 'j.', 'I-PER'],
#   [4, 'russell', 'I-PER'],
#   [5, ',', 'O'],
#   [6, 'michael', 'B-PER'],
#   [7, 'campbell', 'I-PER'],
#   [8, '(', 'O'],
#   [9, 'new', 'B-LOC'],
#   [10, 'zealand', 'I-LOC'],
#   [11, ')', 'O'],
#   [12, ',', 'O'],
#   [13, 'ian', 'B-PER']],
#  [[1, 'woosnam', 'B-PER'],
#   [2, ',', 'O'],
#   [3, 'bernhard', 'B-PER'],
#   [4, 'langer', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'germany', 'B-LOC'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'ronan', 'B-PER'],
#   [10, 'rafferty', 'I-PER'],
#   [11, ',', 'O'],
#   [12, 'mats', 'B-PER']],
#  [[1, 'lanner', 'B-PER'],
#   [2, '(', 'O'],
#   [3, 'sweden', 'B-LOC'],
#   [4, ')', 'O'],
#   [5, ',', 'O'],
#   [6, 'wayne', 'B-PER'],
#   [7, 'riley', 'I-PER'],
#   [8, '(', 'O'],
#   [9, 'australia', 'B-LOC'],
#   [10, ')', 'O']],
#  [[1, '65', 'O'],
#   [2, 'eamonn', 'B-PER'],
#   [3, 'darcy', 'I-PER'],
#   [4, '(', 'O'],
#   [5, 'ireland', 'B-LOC'],
#   [6, ')', 'O'],
#   [7, ',', 'O'],
#   [8, 'per', 'B-PER'],
#   [9, 'nyman', 'I-PER'],
#   [10, '(', 'O'],
#   [11, 'sweden', 'B-LOC'],
#   [12, ')', 'O'],
#   [13, ',', 'O'],
#   [14, 'russell', 'B-PER'],
#   [15, 'claydon', 'I-PER'],
#   [16, ',', 'O']],
#  [[1, 'mark', 'B-PER'],
#   [2, 'roe', 'I-PER'],
#   [3, ',', 'O'],
#   [4, 'retief', 'B-PER'],
#   [5, 'goosen', 'I-PER'],
#   [6, '(', 'O'],
#   [7, 'south', 'B-LOC'],
#   [8, 'africa', 'I-LOC'],
#   [9, ')', 'O'],
#   [10, ',', 'O'],
#   [11, 'carl', 'B-PER'],
#   [12, 'suneson', 'I-PER']],
#  [[1, '66', 'O'],
#   [2, 'stephen', 'B-PER'],
#   [3, 'field', 'I-PER'],
#   [4, ',', 'O'],
#   [5, 'paul', 'B-PER'],
#   [6, 'lawrie', 'I-PER'],
#   [7, ',', 'O'],
#   [8, 'ian', 'B-PER'],
#   [9, 'pyman', 'I-PER'],
#   [10, ',', 'O'],
#   [11, 'max', 'B-PER'],
#   [12, 'anglert', 'I-PER']],
#  [[1, '(', 'O'],
#   [2, 'sweden', 'B-LOC'],
#   [3, ')', 'O'],
#   [4, ',', 'O'],
#   [5, 'miles', 'B-PER'],
#   [6, 'tunnicliff', 'I-PER'],
#   [7, ',', 'O'],
#   [8, 'christian', 'B-PER'],
#   [9, 'cevaer', 'I-PER'],
#   [10, '(', 'O'],
#   [11, 'france', 'B-LOC'],
#   [12, ')', 'O'],
#   [13, ',', 'O']],
#  [[1, 'des', 'B-PER'],
#   [2, 'smyth', 'I-PER'],
#   [3, '(', 'O'],
#   [4, 'ireland', 'B-LOC'],
#   [5, ')', 'O'],
#   [6, ',', 'O'],
#   [7, 'david', 'B-PER'],
#   [8, 'carter', 'I-PER'],
#   [9, ',', 'O'],
#   [10, 'lee', 'B-PER'],
#   [11, 'westwood', 'I-PER'],
#   [12, ',', 'O'],
#   [13, 'greg', 'B-PER']],
#  [[1, 'chalmers', 'B-PER'],
#   [2, '(', 'O'],
#   [3, 'australia', 'B-LOC'],
#   [4, ')', 'O'],
#   [5, ',', 'O'],
#   [6, 'miguel', 'B-PER'],
#   [7, 'angel', 'I-PER'],
#   [8, 'martin', 'I-PER'],
#   [9, '(', 'O'],
#   [10, 'spain', 'B-LOC'],
#   [11, ')', 'O'],
#   [12, ',', 'O']],
#  [[1, 'thomas', 'B-PER'],
#   [2, 'bjorn', 'I-PER'],
#   [3, '(', 'O'],
#   [4, 'denmark', 'B-LOC'],
#   [5, ')', 'O'],
#   [6, ',', 'O'],
#   [7, 'fernando', 'B-PER'],
#   [8, 'roca', 'I-PER'],
#   [9, '(', 'O'],
#   [10, 'spain', 'B-LOC'],
#   [11, ')', 'O'],
#   [12, ',', 'O'],
#   [13, 'derrick', 'B-PER']],
#  [[1, 'cooper', 'B-PER']],
#  [[1, '67', 'O'],
#   [2, 'jeff', 'B-PER'],
#   [3, 'hawksworth', 'I-PER'],
#   [4, ',', 'O'],
#   [5, 'padraig', 'B-PER'],
#   [6, 'harrington', 'I-PER'],
#   [7, '(', 'O'],
#   [8, 'ireland', 'B-LOC'],
#   [9, ')', 'O'],
#   [10, ',', 'O'],
#   [11, 'michael', 'B-PER']],
#  [[1, 'welch', 'B-PER'],
#   [2, ',', 'O'],
#   [3, 'thomas', 'B-PER'],
#   [4, 'gogele', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'germany', 'B-LOC'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'paul', 'B-PER'],
#   [10, 'mcginley', 'I-PER'],
#   [11, '(', 'O'],
#   [12, 'ireland', 'B-LOC'],
#   [13, ')', 'O'],
#   [14, ',', 'O']],
#  [[1, 'gary', 'B-PER'],
#   [2, 'orr', 'I-PER'],
#   [3, ',', 'O'],
#   [4, 'jose-maria', 'B-PER'],
#   [5, 'canizares', 'I-PER'],
#   [6, '(', 'O'],
#   [7, 'spain', 'B-LOC'],
#   [8, ')', 'O'],
#   [9, ',', 'O'],
#   [10, 'michael', 'B-PER'],
#   [11, 'jonzon', 'I-PER']],
#  [[1, '(', 'O'],
#   [2, 'sweden', 'B-LOC'],
#   [3, ')', 'O'],
#   [4, ',', 'O'],
#   [5, 'paul', 'B-PER'],
#   [6, 'eales', 'I-PER'],
#   [7, ',', 'O'],
#   [8, 'david', 'B-PER'],
#   [9, 'williams', 'I-PER'],
#   [10, ',', 'O'],
#   [11, 'andrew', 'B-PER'],
#   [12, 'coltart', 'I-PER'],
#   [13, ',', 'O']],
#  [[1, 'jonathan', 'B-PER'],
#   [2, 'lomas', 'I-PER'],
#   [3, ',', 'O'],
#   [4, 'jose', 'B-PER'],
#   [5, 'rivero', 'I-PER'],
#   [6, '(', 'O'],
#   [7, 'spain', 'B-LOC'],
#   [8, ')', 'O'],
#   [9, ',', 'O'],
#   [10, 'robert', 'B-PER'],
#   [11, 'karlsson', 'I-PER']],
#  [[1, '(', 'O'],
#   [2, 'sweden', 'B-LOC'],
#   [3, ')', 'O'],
#   [4, ',', 'O'],
#   [5, 'marcus', 'B-PER'],
#   [6, 'wills', 'I-PER'],
#   [7, ',', 'O'],
#   [8, 'pedro', 'B-PER'],
#   [9, 'linhart', 'I-PER'],
#   [10, '(', 'O'],
#   [11, 'spain', 'B-LOC'],
#   [12, ')', 'O'],
#   [13, ',', 'O'],
#   [14, 'jamie', 'B-PER']],
#  [[1, 'spence', 'B-PER'],
#   [2, ',', 'O'],
#   [3, 'terry', 'B-PER'],
#   [4, 'price', 'I-PER'],
#   [5, '(', 'O'],
#   [6, 'australia', 'B-LOC'],
#   [7, ')', 'O'],
#   [8, ',', 'O'],
#   [9, 'juan', 'B-PER'],
#   [10, 'carlos', 'I-PER'],
#   [11, 'pinero', 'I-PER'],
#   [12, '(', 'O'],
#   [13, 'spain', 'B-LOC'],
#   [14, ')', 'O'],
#   [15, ',', 'O']],
#  [[1, 'mark', 'B-PER'], [2, 'mouland', 'I-PER']],
#  [[1, '-docstart-', 'O']],
#  [[1, 'soccer', 'O'],
#   [2, '-', 'O'],
#   [3, 'uefa', 'B-ORG'],
#   [4, 'rewards', 'O'],
#   [5, 'three', 'O'],
#   [6, 'countries', 'O'],
#   [7, 'for', 'O'],
#   [8, 'fair', 'O'],
#   [9, 'play', 'O'],
#   [10, '.', 'O']],
#  ...]

# %%
dev_file = pd.read_csv('dev', quoting=csv.QUOTE_NONE,sep=" ", names= ['index', 'word', 'tag'])

dev_array = dev_file.to_numpy()

dev_stream = data_to_stream(dev_array)

dev_word,dev_tag = x_y(dev_stream)

# %%
word_collection = train_word+dev_word

# %%
word_collection
# Out:
# [['eu', 'rejects', 'german', 'call', 'to', 'boycott', 'british', 'lamb', '.'],
#  ['peter', 'blackburn'],
#  ['brussels', '1996-08-22'],
#  ['the',
#   'european',
#   'commission',
#   'said',
#   'on',
#   'thursday',
#   'it',
#   'disagreed',
#   'with',
#   'german',
#   'advice',
#   'to',
#   'consumers',
#   'to',
#   'shun',
#   'british',
#   'lamb',
#   'until',
#   'scientists',
#   'determine',
#   'whether',
#   'mad',
#   'cow',
#   'disease',
#   'can',
#   'be',
#   'transmitted',
#   'to',
#   'sheep',
#   '.'],
#  ['germany',
#   "'s",
#   'representative',
#   'to',
#   'the',
#   'european',
#   'union',
#   "'s",
#   'veterinary',
#   'committee',
#   'werner',
#   'zwingmann',
#   'said',
#   'on',
#   'wednesday',
#   'consumers',
#   'should',
#   'buy',
#   'sheepmeat',
#   'from',
#   'countries',
#   'other',
#   'than',
#   'britain',
#   'until',
#   'the',
#   'scientific',
#   'advice',
#   'was',
#   'clearer',
#   '.'],
#  ['"',
#   'we',
#   'do',
#   "n't",
#   'support',
#   'any',
#   'such',
#   'recommendation',
#   'because',
#   'we',
#   'do',
#   "n't",
#   'see',
#   'any',
#   'grounds',
#   'for',
#   'it',
#   ',',
#   '"',
#   'the',
#   'commission',
#   "'s",
#   'chief',
#   'spokesman',
#   'nikolaus',
#   'van',
#   'der',
#   'pas',
#   'told',
#   'a',
#   'news',
#   'briefing',
#   '.'],
#  ['he',
#   'said',
#   'further',
#   'scientific',
#   'study',
#   'was',
#   'required',
#   'and',
#   'if',
#   'it',
#   'was',
#   'found',
#   'that',
#   'action',
#   'was',
#   'needed',
#   'it',
#   'should',
#   'be',
#   'taken',
#   'by',
#   'the',
#   'european',
#   'union',
#   '.'],
#  ['he',
#   'said',
#   'a',
#   'proposal',
#   'last',
#   'month',
#   'by',
#   'eu',
#   'farm',
#   'commissioner',
#   'franz',
#   'fischler',
#   'to',
#   'ban',
#   'sheep',
#   'brains',
#   ',',
#   'spleens',
#   'and',
#   'spinal',
#   'cords',
#   'from',
#   'the',
#   'human',
#   'and',
#   'animal',
#   'food',
#   'chains',
#   'was',
#   'a',
#   'highly',
#   'specific',
#   'and',
#   'precautionary',
#   'move',
#   'to',
#   'protect',
#   'human',
#   'health',
#   '.'],
#  ['fischler',
#   'proposed',
#   'eu-wide',
#   'measures',
#   'after',
#   'reports',
#   'from',
#   'britain',
#   'and',
#   'france',
#   'that',
#   'under',
#   'laboratory',
#   'conditions',
#   'sheep',
#   'could',
#   'contract',
#   'bovine',
#   'spongiform',
#   'encephalopathy',
#   '(',
#   'bse',
#   ')',
#   '--',
#   'mad',
#   'cow',
#   'disease',
#   '.'],
#  ['but',
#   'fischler',
#   'agreed',
#   'to',
#   'review',
#   'his',
#   'proposal',
#   'after',
#   'the',
#   'eu',
#   "'s",
#   'standing',
#   'veterinary',
#   'committee',
#   ',',
#   'mational',
#   'animal',
#   'health',
#   'officials',
#   ',',
#   'questioned',
#   'if',
#   'such',
#   'action',
#   'was',
#   'justified',
#   'as',
#   'there',
#   'was',
#   'only',
#   'a',
#   'slight',
#   'risk',
#   'to',
#   'human',
#   'health',
#   '.'],
#  ['spanish',
#   'farm',
#   'minister',
#   'loyola',
#   'de',
#   'palacio',
#   'had',
#   'earlier',
#   'accused',
#   'fischler',
#   'at',
#   'an',
#   'eu',
#   'farm',
#   'ministers',
#   "'",
#   'meeting',
#   'of',
#   'causing',
#   'unjustified',
#   'alarm',
#   'through',
#   '"',
#   'dangerous',
#   'generalisation',
#   '.',
#   '"'],
#  ['.'],
#  ['only',
#   'france',
#   'and',
#   'britain',
#   'backed',
#   'fischler',
#   "'s",
#   'proposal',
#   '.'],
#  ['the',
#   'eu',
#   "'s",
#   'scientific',
#   'veterinary',
#   'and',
#   'multidisciplinary',
#   'committees',
#   'are',
#   'due',
#   'to',
#   're-examine',
#   'the',
#   'issue',
#   'early',
#   'next',
#   'month',
#   'and',
#   'make',
#   'recommendations',
#   'to',
#   'the',
#   'senior',
#   'veterinary',
#   'officials',
#   '.'],
#  ['sheep',
#   'have',
#   'long',
#   'been',
#   'known',
#   'to',
#   'contract',
#   'scrapie',
#   ',',
#   'a',
#   'brain-wasting',
#   'disease',
#   'similar',
#   'to',
#   'bse',
#   'which',
#   'is',
#   'believed',
#   'to',
#   'have',
#   'been',
#   'transferred',
#   'to',
#   'cattle',
#   'through',
#   'feed',
#   'containing',
#   'animal',
#   'waste',
#   '.'],
#  ['british',
#   'farmers',
#   'denied',
#   'on',
#   'thursday',
#   'there',
#   'was',
#   'any',
#   'danger',
#   'to',
#   'human',
#   'health',
#   'from',
#   'their',
#   'sheep',
#   ',',
#   'but',
#   'expressed',
#   'concern',
#   'that',
#   'german',
#   'government',
#   'advice',
#   'to',
#   'consumers',
#   'to',
#   'avoid',
#   'british',
#   'lamb',
#   'might',
#   'influence',
#   'consumers',
#   'across',
#   'europe',
#   '.'],
#  ['"',
#   'what',
#   'we',
#   'have',
#   'to',
#   'be',
#   'extremely',
#   'careful',
#   'of',
#   'is',
#   'how',
#   'other',
#   'countries',
#   'are',
#   'going',
#   'to',
#   'take',
#   'germany',
#   "'s",
#   'lead',
#   ',',
#   '"',
#   'welsh',
#   'national',
#   'farmers',
#   "'",
#   'union',
#   '(',
#   'nfu',
#   ')',
#   'chairman',
#   'john',
#   'lloyd',
#   'jones',
#   'said',
#   'on',
#   'bbc',
#   'radio',
#   '.'],
#  ['bonn',
#   'has',
#   'led',
#   'efforts',
#   'to',
#   'protect',
#   'public',
#   'health',
#   'after',
#   'consumer',
#   'confidence',
#   'collapsed',
#   'in',
#   'march',
#   'after',
#   'a',
#   'british',
#   'report',
#   'suggested',
#   'humans',
#   'could',
#   'contract',
#   'an',
#   'illness',
#   'similar',
#   'to',
#   'mad',
#   'cow',
#   'disease',
#   'by',
#   'eating',
#   'contaminated',
#   'beef',
#   '.'],
#  ['germany',
#   'imported',
#   '47,600',
#   'sheep',
#   'from',
#   'britain',
#   'last',
#   'year',
#   ',',
#   'nearly',
#   'half',
#   'of',
#   'total',
#   'imports',
#   '.'],
#  ['it',
#   'brought',
#   'in',
#   '4,275',
#   'tonnes',
#   'of',
#   'british',
#   'mutton',
#   ',',
#   'some',
#   '10',
#   'percent',
#   'of',
#   'overall',
#   'imports',
#   '.'],
#  ['-docstart-'],
#  ['rare',
#   'hendrix',
#   'song',
#   'draft',
#   'sells',
#   'for',
#   'almost',
#   '$',
#   '17,000',
#   '.'],
#  ['london', '1996-08-22'],
#  ['a',
#   'rare',
#   'early',
#   'handwritten',
#   'draft',
#   'of',
#   'a',
#   'song',
#   'by',
#   'u.s.',
#   'guitar',
#   'legend',
#   'jimi',
#   'hendrix',
#   'was',
#   'sold',
#   'for',
#   'almost',
#   '$',
#   '17,000',
#   'on',
#   'thursday',
#   'at',
#   'an',
#   'auction',
#   'of',
#   'some',
#   'of',
#   'the',
#   'late',
#   'musician',
#   "'s",
#   'favourite',
#   'possessions',
#   '.'],
#  ['a',
#   'florida',
#   'restaurant',
#   'paid',
#   '10,925',
#   'pounds',
#   '(',
#   '$',
#   '16,935',
#   ')',
#   'for',
#   'the',
#   'draft',
#   'of',
#   '"',
#   'ai',
#   "n't",
#   'no',
#   'telling',
#   '"',
#   ',',
#   'which',
#   'hendrix',
#   'penned',
#   'on',
#   'a',
#   'piece',
#   'of',
#   'london',
#   'hotel',
#   'stationery',
#   'in',
#   'late',
#   '1966',
#   '.'],
#  ['at',
#   'the',
#   'end',
#   'of',
#   'a',
#   'january',
#   '1967',
#   'concert',
#   'in',
#   'the',
#   'english',
#   'city',
#   'of',
#   'nottingham',
#   'he',
#   'threw',
#   'the',
#   'sheet',
#   'of',
#   'paper',
#   'into',
#   'the',
#   'audience',
#   ',',
#   'where',
#   'it',
#   'was',
#   'retrieved',
#   'by',
#   'a',
#   'fan',
#   '.'],
#  ['buyers',
#   'also',
#   'snapped',
#   'up',
#   '16',
#   'other',
#   'items',
#   'that',
#   'were',
#   'put',
#   'up',
#   'for',
#   'auction',
#   'by',
#   'hendrix',
#   "'s",
#   'former',
#   'girlfriend',
#   'kathy',
#   'etchingham',
#   ',',
#   'who',
#   'lived',
#   'with',
#   'him',
#   'from',
#   '1966',
#   'to',
#   '1969',
#   '.'],
#  ['they',
#   'included',
#   'a',
#   'black',
#   'lacquer',
#   'and',
#   'mother',
#   'of',
#   'pearl',
#   'inlaid',
#   'box',
#   'used',
#   'by',
#   'hendrix',
#   'to',
#   'store',
#   'his',
#   'drugs',
#   ',',
#   'which',
#   'an',
#   'anonymous',
#   'australian',
#   'purchaser',
#   'bought',
#   'for',
#   '5,060',
#   'pounds',
#   '(',
#   '$',
#   '7,845',
#   ')',
#   '.'],
#  ['the',
#   'guitarist',
#   'died',
#   'of',
#   'a',
#   'drugs',
#   'overdose',
#   'in',
#   '1970',
#   'aged',
#   '27',
#   '.'],
#  ['-docstart-'],
#  ['china', 'says', 'taiwan', 'spoils', 'atmosphere', 'for', 'talks', '.'],
#  ['beijing', '1996-08-22'],
#  ['china',
#   'on',
#   'thursday',
#   'accused',
#   'taipei',
#   'of',
#   'spoiling',
#   'the',
#   'atmosphere',
#   'for',
#   'a',
#   'resumption',
#   'of',
#   'talks',
#   'across',
#   'the',
#   'taiwan',
#   'strait',
#   'with',
#   'a',
#   'visit',
#   'to',
#   'ukraine',
#   'by',
#   'taiwanese',
#   'vice',
#   'president',
#   'lien',
#   'chan',
#   'this',
#   'week',
#   'that',
#   'infuriated',
#   'beijing',
#   '.'],
#  ['speaking',
#   'only',
#   'hours',
#   'after',
#   'chinese',
#   'state',
#   'media',
#   'said',
#   'the',
#   'time',
#   'was',
#   'right',
#   'to',
#   'engage',
#   'in',
#   'political',
#   'talks',
#   'with',
#   'taiwan',
#   ',',
#   'foreign',
#   'ministry',
#   'spokesman',
#   'shen',
#   'guofang',
#   'told',
#   'reuters',
#   ':',
#   '"',
#   'the',
#   'necessary',
#   'atmosphere',
#   'for',
#   'the',
#   'opening',
#   'of',
#   'the',
#   'talks',
#   'has',
#   'been',
#   'disrupted',
#   'by',
#   'the',
#   'taiwan',
#   'authorities',
#   '.',
#   '"'],
#  ['state',
#   'media',
#   'quoted',
#   'china',
#   "'s",
#   'top',
#   'negotiator',
#   'with',
#   'taipei',
#   ',',
#   'tang',
#   'shubei',
#   ',',
#   'as',
#   'telling',
#   'a',
#   'visiting',
#   'group',
#   'from',
#   'taiwan',
#   'on',
#   'wednesday',
#   'that',
#   'it',
#   'was',
#   'time',
#   'for',
#   'the',
#   'rivals',
#   'to',
#   'hold',
#   'political',
#   'talks',
#   '.'],
#  ['"',
#   'now',
#   'is',
#   'the',
#   'time',
#   'for',
#   'the',
#   'two',
#   'sides',
#   'to',
#   'engage',
#   'in',
#   'political',
#   'talks',
#   '...'],
#  ['that',
#   'is',
#   'to',
#   'end',
#   'the',
#   'state',
#   'of',
#   'hostility',
#   ',',
#   '"',
#   'thursday',
#   "'s",
#   'overseas',
#   'edition',
#   'of',
#   'the',
#   'people',
#   "'s",
#   'daily',
#   'quoted',
#   'tang',
#   'as',
#   'saying',
#   '.'],
#  ['the',
#   'foreign',
#   'ministry',
#   "'s",
#   'shen',
#   'told',
#   'reuters',
#   'television',
#   'in',
#   'an',
#   'interview',
#   'he',
#   'had',
#   'read',
#   'reports',
#   'of',
#   'tang',
#   "'s",
#   'comments',
#   'but',
#   'gave',
#   'no',
#   'details',
#   'of',
#   'why',
#   'the',
#   'negotiator',
#   'had',
#   'considered',
#   'the',
#   'time',
#   'right',
#   'for',
#   'talks',
#   'with',
#   'taiwan',
#   ',',
#   'which',
#   'beijing',
#   'considers',
#   'a',
#   'renegade',
#   'province',
#   '.'],
#  ['china',
#   ',',
#   'which',
#   'has',
#   'long',
#   'opposed',
#   'all',
#   'taipei',
#   'efforts',
#   'to',
#   'gain',
#   'greater',
#   'international',
#   'recognition',
#   ',',
#   'was',
#   'infuriated',
#   'by',
#   'a',
#   'visit',
#   'to',
#   'ukraine',
#   'this',
#   'week',
#   'by',
#   'taiwanese',
#   'vice',
#   'president',
#   'lien',
#   '.'],
#  ['-docstart-'],
#  ['china', 'says', 'time', 'right', 'for', 'taiwan', 'talks', '.'],
#  ['beijing', '1996-08-22'],
#  ['china',
#   'has',
#   'said',
#   'it',
#   'was',
#   'time',
#   'for',
#   'political',
#   'talks',
#   'with',
#   'taiwan',
#   'and',
#   'that',
#   'the',
#   'rival',
#   'island',
#   'should',
#   'take',
#   'practical',
#   'steps',
#   'towards',
#   'that',
#   'goal',
#   '.'],
#  ['consultations',
#   'should',
#   'be',
#   'held',
#   'to',
#   'set',
#   'the',
#   'time',
#   'and',
#   'format',
#   'of',
#   'the',
#   'talks',
#   ',',
#   'the',
#   'official',
#   'xinhua',
#   'news',
#   'agency',
#   'quoted',
#   'tang',
#   'shubei',
#   ',',
#   'executive',
#   'vice',
#   'chairman',
#   'of',
#   'the',
#   'association',
#   'for',
#   'relations',
#   'across',
#   'the',
#   'taiwan',
#   'straits',
#   ',',
#   'as',
#   'saying',
#   'late',
#   'on',
#   'wednesday',
#   '.'],
#  ['-docstart-'],
#  ['german',
#   'july',
#   'car',
#   'registrations',
#   'up',
#   '14.2',
#   'pct',
#   'yr',
#   '/',
#   'yr',
#   '.'],
#  ['frankfurt', '1996-08-22'],
#  ['german',
#   'first-time',
#   'registrations',
#   'of',
#   'motor',
#   'vehicles',
#   'jumped',
#   '14.2',
#   'percent',
#   'in',
#   'july',
#   'this',
#   'year',
#   'from',
#   'the',
#   'year-earlier',
#   'period',
#   ',',
#   'the',
#   'federal',
#   'office',
#   'for',
#   'motor',
#   'vehicles',
#   'said',
#   'on',
#   'thursday',
#   '.'],
#  ['the',
#   'office',
#   'said',
#   '356,725',
#   'new',
#   'cars',
#   'were',
#   'registered',
#   'in',
#   'july',
#   '1996',
#   '--',
#   '304,850',
#   'passenger',
#   'cars',
#   'and',
#   '15,613',
#   'trucks',
#   '.'],
#  ['the',
#   'figures',
#   'represent',
#   'a',
#   '13.6',
#   'percent',
#   'increase',
#   'for',
#   'passenger',
#   'cars',
#   'and',
#   'a',
#   '2.2',
#   'percent',
#   'decline',
#   'for',
#   'trucks',
#   'from',
#   'july',
#   '1995',
#   '.'],
#  ['motor-bike',
#   'registration',
#   'rose',
#   '32.7',
#   'percent',
#   'in',
#   'the',
#   'period',
#   '.'],
#  ['the',
#   'growth',
#   'was',
#   'partly',
#   'due',
#   'to',
#   'an',
#   'increased',
#   'number',
#   'of',
#   'germans',
#   'buying',
#   'german',
#   'cars',
#   'abroad',
#   ',',
#   'while',
#   'manufacturers',
#   'said',
#   'that',
#   'domestic',
#   'demand',
#   'was',
#   'weak',
#   ',',
#   'the',
#   'federal',
#   'office',
#   'said',
#   '.'],
#  ['almost',
#   'all',
#   'german',
#   'car',
#   'manufacturers',
#   'posted',
#   'gains',
#   'in',
#   'registration',
#   'numbers',
#   'in',
#   'the',
#   'period',
#   '.'],
#  ['volkswagen',
#   'ag',
#   'won',
#   '77,719',
#   'registrations',
#   ',',
#   'slightly',
#   'more',
#   'than',
#   'a',
#   'quarter',
#   'of',
#   'the',
#   'total',
#   '.'],
#  ['opel',
#   'ag',
#   'together',
#   'with',
#   'general',
#   'motors',
#   'came',
#   'in',
#   'second',
#   'place',
#   'with',
#   '49,269',
#   'registrations',
#   ',',
#   '16.4',
#   'percent',
#   'of',
#   'the',
#   'overall',
#   'figure',
#   '.'],
#  ['third',
#   'was',
#   'ford',
#   'with',
#   '35,563',
#   'registrations',
#   ',',
#   'or',
#   '11.7',
#   'percent',
#   '.'],
#  ['only',
#   'seat',
#   'and',
#   'porsche',
#   'had',
#   'fewer',
#   'registrations',
#   'in',
#   'july',
#   '1996',
#   'compared',
#   'to',
#   'last',
#   'year',
#   "'s",
#   'july',
#   '.'],
#  ['seat',
#   'posted',
#   '3,420',
#   'registrations',
#   'compared',
#   'with',
#   '5522',
#   'registrations',
#   'in',
#   'july',
#   'a',
#   'year',
#   'earlier',
#   '.'],
#  ['porsche', "'s", 'registrations', 'fell', 'to', '554', 'from', '643', '.'],
#  ['-docstart-'],
#  ['greek',
#   'socialists',
#   'give',
#   'green',
#   'light',
#   'to',
#   'pm',
#   'for',
#   'elections',
#   '.'],
#  ['athens', '1996-08-22'],
#  ['the',
#   'greek',
#   'socialist',
#   'party',
#   "'s",
#   'executive',
#   'bureau',
#   'gave',
#   'the',
#   'green',
#   'light',
#   'to',
#   'prime',
#   'minister',
#   'costas',
#   'simitis',
#   'to',
#   'call',
#   'snap',
#   'elections',
#   ',',
#   'its',
#   'general',
#   'secretary',
#   'costas',
#   'skandalidis',
#   'told',
#   'reporters',
#   '.'],
#  ['prime',
#   'minister',
#   'costas',
#   'simitis',
#   'is',
#   'going',
#   'to',
#   'make',
#   'an',
#   'official',
#   'announcement',
#   'after',
#   'a',
#   'cabinet',
#   'meeting',
#   'later',
#   'on',
#   'thursday',
#   ',',
#   'said',
#   'skandalidis',
#   '.'],
#  ['--',
#   'dimitris',
#   'kontogiannis',
#   ',',
#   'athens',
#   'newsroom',
#   '+301',
#   '3311812-4'],
#  ['-docstart-'],
#  ['bayervb', 'sets', 'c$', '100', 'million', 'six-year', 'bond', '.'],
#  ['london', '1996-08-22'],
#  ['the',
#   'following',
#   'bond',
#   'was',
#   'announced',
#   'by',
#   'lead',
#   'manager',
#   'toronto',
#   'dominion',
#   '.'],
#  ['borrower', 'bayerische', 'vereinsbank'],
#  ['amt', 'c$', '100', 'mln', 'coupon', '6.625', 'maturity', '24.sep.02'],
#  ['type', 'straight', 'iss', 'price', '100.92', 'pay', 'date', '24.sep.96'],
#  ['full', 'fees', '1.875', 'reoffer', '99.32', 'spread', '+20', 'bp'],
#  ['moody', 'aa1', 'listing', 'lux', 'pay', 'freq', '='],
#  ['s&p',
#   '=',
#   'denoms',
#   '(',
#   'k',
#   ')',
#   '1-10-100',
#   'sale',
#   'limits',
#   'us',
#   '/',
#   'uk',
#   '/',
#   'ca'],
#  ['neg', 'plg', 'no', 'crs', 'deflt', 'no', 'force', 'maj', '='],
#  ['gov', 'law', 'german', 'home', 'ctry', '=', 'tax', 'provs', 'standard'],
#  ['mgt', '/', 'und', '0.275', 'sell', 'conc', '1.60', 'praecip', '='],
#  ['underlying', 'govt', 'bond', '7.0', 'pct', 'sept', '2001'],
#  ['notes', 'bayerische', 'vereinsbank', 'is', 'joint', 'lead', 'manager'],
#  ['--', 'london', 'newsroom', '+44', '171', '542', '7658'],
#  ['-docstart-'],
#  ['venantius', 'sets', '$', '300', 'million', 'january', '1999', 'frn', '.'],
#  ['london', '1996-08-22'],
#  ['the',
#   'following',
#   'floating-rate',
#   'issue',
#   'was',
#   'announced',
#   'by',
#   'lead',
#   'manager',
#   'lehman',
#   'brothers',
#   'international',
#   '.'],
#  ['borrower',
#   'venantius',
#   'ab',
#   '(',
#   'swedish',
#   'national',
#   'mortgage',
#   'agency',
#   ')'],
#  ['amt',
#   '$',
#   '300',
#   'mln',
#   'spread',
#   '-',
#   '12.5',
#   'bp',
#   'maturity',
#   '21.jan.99'],
#  ['type', 'frn', 'base', '3m', 'libor', 'pay', 'date', 's23.sep.96'],
#  ['last',
#   'moody',
#   'aa3',
#   'iss',
#   'price',
#   '99.956',
#   'full',
#   'fees',
#   '10',
#   'bp'],
#  ['last', 's&p', 'aa+', 'reoffer', '='],
#  ['notes', 's', 'short', 'first', 'coupon'],
#  ['listing',
#   'london',
#   'denoms',
#   '(',
#   'k',
#   ')',
#   '1-10-100',
#   'sale',
#   'limits',
#   'us',
#   '/',
#   'uk',
#   '/',
#   'jp',
#   '/',
#   'fr'],
#  ['neg', 'plg', 'yes', 'crs', 'deflt', 'no', 'force', 'maj', 'ipma', '2'],
#  ['gov',
#   'law',
#   'english',
#   'home',
#   'ctry',
#   'sweden',
#   'tax',
#   'provs',
#   'standard'],
#  ['mgt', '/', 'und', '5', 'bp', 'sell', 'conc', '5', 'bp', 'praecip', '='],
#  ['notes', 'issued', 'off', 'emtn', 'programme'],
#  ['--', 'london', 'newsroom', '+44', '171', '542', '8863'],
#  ['-docstart-'],
#  ['port',
#   'conditions',
#   'update',
#   '-',
#   'syria',
#   '-',
#   'lloyds',
#   'shipping',
#   '.'],
#  ['port',
#   'conditions',
#   'from',
#   'lloyds',
#   'shipping',
#   'intelligence',
#   'service',
#   '--'],
#  ['lattakia',
#   ',',
#   'aug',
#   '10',
#   '-',
#   'waiting',
#   'time',
#   'at',
#   'lattakia',
#   'and',
#   'tartous',
#   'presently',
#   '24',
#   'hours',
#   '.'],
#  ['-docstart-'],
#  ['israel', 'plays', 'down', 'fears', 'of', 'war', 'with', 'syria', '.'],
#  ['colleen', 'siegel'],
#  ['jerusalem', '1996-08-22'],
#  ['israel',
#   "'s",
#   'outgoing',
#   'peace',
#   'negotiator',
#   'with',
#   'syria',
#   'said',
#   'on',
#   'thursday',
#   'current',
#   'tensions',
#   'between',
#   'the',
#   'two',
#   'countries',
#   'appeared',
#   'to',
#   'be',
#   'a',
#   'storm',
#   'in',
#   'a',
#   'teacup',
#   '.'],
#  ['itamar',
#   'rabinovich',
#   ',',
#   'who',
#   'as',
#   'israel',
#   "'s",
#   'ambassador',
#   'to',
#   'washington',
#   'conducted',
#   'unfruitful',
#   'negotiations',
#   'with',
#   'syria',
#   ',',
#   'told',
#   'israel',
#   'radio',
#   'it',
#   'looked',
#   'like',
#   'damascus',
#   'wanted',
#   'to',
#   'talk',
#   'rather',
#   'than',
#   'fight',
#   '.'],
#  ['"',
#   'it',
#   'appears',
#   'to',
#   'me',
#   'the',
#   'syrian',
#   'priority',
#   'is',
#   'still',
#   'to',
#   'negotiate',
#   '.'],
#  ['the',
#   'syrians',
#   'are',
#   'confused',
#   ',',
#   'they',
#   'are',
#   'definitely',
#   'tense',
#   ',',
#   'but',
#   'the',
#   'general',
#   'assessment',
#   'here',
#   'in',
#   'washington',
#   'is',
#   'that',
#   'this',
#   'is',
#   'essentially',
#   'a',
#   'storm',
#   'in',
#   'a',
#   'teacup',
#   ',',
#   '"',
#   'he',
#   'said',
#   '.'],
#  ['rabinovich', 'is', 'winding', 'up', 'his', 'term', 'as', 'ambassador', '.'],
#  ['he',
#   'will',
#   'be',
#   'replaced',
#   'by',
#   'eliahu',
#   'ben-elissar',
#   ',',
#   'a',
#   'former',
#   'israeli',
#   'envoy',
#   'to',
#   'egypt',
#   'and',
#   'right-wing',
#   'likud',
#   'party',
#   'politician',
#   '.'],
#  ['israel',
#   'on',
#   'wednesday',
#   'sent',
#   'syria',
#   'a',
#   'message',
#   ',',
#   'via',
#   'washington',
#   ',',
#   'saying',
#   'it',
#   'was',
#   'committed',
#   'to',
#   'peace',
#   'and',
#   'wanted',
#   'to',
#   'open',
#   'negotiations',
#   'without',
#   'preconditions',
#   '.'],
#  ['but',
#   'it',
#   'slammed',
#   'damascus',
#   'for',
#   'creating',
#   'what',
#   'it',
#   'called',
#   'a',
#   'dangerous',
#   'atmosphere',
#   '.'],
#  ['syria',
#   'accused',
#   'israel',
#   'on',
#   'wednesday',
#   'of',
#   'launching',
#   'a',
#   'hysterical',
#   'campaign',
#   'against',
#   'it',
#   'after',
#   'israeli',
#   'television',
#   'reported',
#   'that',
#   'damascus',
#   'had',
#   'recently',
#   'test',
#   'fired',
#   'a',
#   'missile',
#   '.'],
#  ['it',
#   'said',
#   'its',
#   'arms',
#   'purchases',
#   'were',
#   'for',
#   'defensive',
#   'purposes',
#   '.'],
#  ['"',
#   'the',
#   'message',
#   'that',
#   'we',
#   'sent',
#   'to',
#   '(',
#   'syrian',
#   'president',
#   'hafez',
#   'al-',
#   ')',
#   'assad',
#   'is',
#   'that',
#   'israel',
#   'is',
#   'ready',
#   'at',
#   'any',
#   'time',
#   'without',
#   'preconditions',
#   'to',
#   'enter',
#   'peace',
#   'negotiations',
#   ',',
#   '"',
#   'israeli',
#   'foreign',
#   'minister',
#   'david',
#   'levy',
#   'told',
#   'israel',
#   'radio',
#   'in',
#   'an',
#   'interview',
#   '.'],
#  ['tension',
#   'has',
#   'mounted',
#   'since',
#   'israeli',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'took',
#   'office',
#   'in',
#   'june',
#   'vowing',
#   'to',
#   'retain',
#   'the',
#   'golan',
#   'heights',
#   'israel',
#   'captured',
#   'from',
#   'syria',
#   'in',
#   'the',
#   '1967',
#   'middle',
#   'east',
#   'war',
#   '.'],
#  ['israeli-syrian',
#   'peace',
#   'talks',
#   'have',
#   'been',
#   'deadlocked',
#   'over',
#   'the',
#   'golan',
#   'since',
#   '1991',
#   'despite',
#   'the',
#   'previous',
#   'government',
#   "'s",
#   'willingness',
#   'to',
#   'make',
#   'golan',
#   'concessions',
#   '.'],
#  ['peace',
#   'talks',
#   'between',
#   'the',
#   'two',
#   'sides',
#   'were',
#   'last',
#   'held',
#   'in',
#   'february',
#   '.'],
#  ['"',
#   'the',
#   'voices',
#   'coming',
#   'out',
#   'of',
#   'damascus',
#   'are',
#   'bad',
#   ',',
#   'not',
#   'good',
#   '.'],
#  ['the', 'media', '...'],
#  ['are',
#   'full',
#   'of',
#   'expressions',
#   'and',
#   'declarations',
#   'that',
#   'must',
#   'be',
#   'worrying',
#   '...'],
#  ['this',
#   'artificial',
#   'atmosphere',
#   'is',
#   'very',
#   'dangerous',
#   'because',
#   'those',
#   'who',
#   'spread',
#   'it',
#   'could',
#   'become',
#   'its',
#   'prisoners',
#   ',',
#   '"',
#   'levy',
#   'said',
#   '.'],
#  ['"',
#   'we',
#   'expect',
#   'from',
#   'syria',
#   ',',
#   'if',
#   'its',
#   'face',
#   'is',
#   'to',
#   'peace',
#   ',',
#   'that',
#   'it',
#   'will',
#   'answer',
#   'israel',
#   "'s",
#   'message',
#   'to',
#   'enter',
#   'peace',
#   'negotiations',
#   'because',
#   'that',
#   'is',
#   'our',
#   'goal',
#   ',',
#   '"',
#   'he',
#   'said',
#   '.',
#   '"'],
#  ['we', 'do', 'not', 'want', 'a', 'war', ',', 'god', 'forbid', '.'],
#  ['no', 'one', 'benefits', 'from', 'wars', '.', '"'],
#  ['israel',
#   "'s",
#   'channel',
#   'two',
#   'television',
#   'said',
#   'damascus',
#   'had',
#   'sent',
#   'a',
#   '"',
#   'calming',
#   'signal',
#   '"',
#   'to',
#   'israel',
#   '.'],
#  ['it', 'gave', 'no', 'source', 'for', 'the', 'report', '.'],
#  ['netanyahu',
#   'and',
#   'levy',
#   "'s",
#   'spokesmen',
#   'said',
#   'they',
#   'could',
#   'not',
#   'confirm',
#   'it',
#   '.'],
#  ['the',
#   'television',
#   'also',
#   'said',
#   'that',
#   'netanyahu',
#   'had',
#   'sent',
#   'messages',
#   'to',
#   'reassure',
#   'syria',
#   'via',
#   'cairo',
#   ',',
#   'the',
#   'united',
#   'states',
#   'and',
#   'moscow',
#   '.'],
#  ['-docstart-'],
#  ['polish', 'diplomat', 'denies', 'nurses', 'stranded', 'in', 'libya', '.'],
#  ['tunis', '1996-08-22'],
#  ['a',
#   'polish',
#   'diplomat',
#   'on',
#   'thursday',
#   'denied',
#   'a',
#   'polish',
#   'tabloid',
#   'report',
#   'this',
#   'week',
#   'that',
#   'libya',
#   'was',
#   'refusing',
#   'exit',
#   'visas',
#   'to',
#   '100',
#   'polish',
#   'nurses',
#   'trying',
#   'to',
#   'return',
#   'home',
#   'after',
#   'working',
#   'in',
#   'the',
#   'north',
#   'african',
#   'country',
#   '.'],
#  ['"', 'this', 'is', 'not', 'true', '.'],
#  ['up',
#   'to',
#   'today',
#   ',',
#   'we',
#   'have',
#   'no',
#   'knowledge',
#   'of',
#   'any',
#   'nurse',
#   'stranded',
#   'or',
#   'kept',
#   'in',
#   'libya',
#   'without',
#   'her',
#   'will',
#   ',',
#   'and',
#   'we',
#   'have',
#   'not',
#   'received',
#   'any',
#   'complaint',
#   ',',
#   '"',
#   'the',
#   'polish',
#   'embassy',
#   "'s",
#   'charge',
#   "d'affaires",
#   'in',
#   'tripoli',
#   ',',
#   'tadeusz',
#   'awdankiewicz',
#   ',',
#   'told',
#   'reuters',
#   'by',
#   'telephone',
#   '.'],
#  ['poland',
#   "'s",
#   'labour',
#   'ministry',
#   'said',
#   'this',
#   'week',
#   'it',
#   'would',
#   'send',
#   'a',
#   'team',
#   'to',
#   'libya',
#   'to',
#   'investigate',
#   ',',
#   'but',
#   'awdankiewicz',
#   'said',
#   'the',
#   'probe',
#   'was',
#   'prompted',
#   'by',
#   'some',
#   'nurses',
#   'complaining',
#   'about',
#   'their',
#   'work',
#   'conditions',
#   'such',
#   'as',
#   'non-payment',
#   'of',
#   'their',
#   'salaries',
#   '.'],
#  ['he',
#   'said',
#   'that',
#   'there',
#   'are',
#   'an',
#   'estimated',
#   '800',
#   'polish',
#   'nurses',
#   'working',
#   'in',
#   'libya',
#   '.'],
#  ['-docstart-'],
#  ['two', 'iranian', 'opposition', 'leaders', 'meet', 'in', 'baghdad', '.'],
#  ['hassan', 'hafidh'],
#  ['baghdad', '1996-08-22'],
#  ['an',
#   'iranian',
#   'exile',
#   'group',
#   'based',
#   'in',
#   'iraq',
#   'vowed',
#   'on',
#   'thursday',
#   'to',
#   'extend',
#   'support',
#   'to',
#   'iran',
#   "'s",
#   'kurdish',
#   'rebels',
#   'after',
#   'they',
#   'were',
#   'attacked',
#   'by',
#   'iranian',
#   'troops',
#   'deep',
#   'inside',
#   'iraq',
#   'last',
#   'month',
#   '.'],
#  ['a',
#   'mujahideen',
#   'khalq',
#   'statement',
#   'said',
#   'its',
#   'leader',
#   'massoud',
#   'rajavi',
#   'met',
#   'in',
#   'baghdad',
#   'the',
#   'secretary-general',
#   'of',
#   'the',
#   'kurdistan',
#   'democratic',
#   'party',
#   'of',
#   'iran',
#   '(',
#   'kdpi',
#   ')',
#   'hassan',
#   'rastegar',
#   'on',
#   'wednesday',
#   'and',
#   'voiced',
#   'his',
#   'support',
#   'to',
#   'iran',
#   "'s",
#   'rebel',
#   'kurds',
#   '.'],
#  ['"',
#   'rajavi',
#   'emphasised',
#   'that',
#   'the',
#   'iranian',
#   'resistance',
#   'would',
#   'continue',
#   'to',
#   'stand',
#   'side',
#   'by',
#   'side',
#   'with',
#   'their',
#   'kurdish',
#   'compatriots',
#   'and',
#   'the',
#   'resistance',
#   'movement',
#   'in',
#   'iranian',
#   'kurdistan',
#   ',',
#   '"',
#   'it',
#   'said',
#   '.'],
#  ['a',
#   'spokesman',
#   'for',
#   'the',
#   'group',
#   'said',
#   'the',
#   'meeting',
#   '"',
#   'signals',
#   'a',
#   'new',
#   'level',
#   'of',
#   'cooperation',
#   'between',
#   'mujahideen',
#   'khalq',
#   'and',
#   'the',
#   'iranian',
#   'kurdish',
#   'oppositions',
#   '"',
#   '.'],
#  ['iran',
#   'heavily',
#   'bombarded',
#   'targets',
#   'in',
#   'northern',
#   'iraq',
#   'in',
#   'july',
#   'in',
#   'pursuit',
#   'of',
#   'kdpi',
#   'guerrillas',
#   'based',
#   'in',
#   'iraqi',
#   'kurdish',
#   'areas',
#   'outside',
#   'the',
#   'control',
#   'of',
#   'the',
#   'government',
#   'in',
#   'baghdad',
#   '.'],
#  ['iraqi',
#   'kurdish',
#   'areas',
#   'bordering',
#   'iran',
#   'are',
#   'under',
#   'the',
#   'control',
#   'of',
#   'guerrillas',
#   'of',
#   'the',
#   'iraqi',
#   'kurdish',
#   'patriotic',
#   'union',
#   'of',
#   'kurdistan',
#   '(',
#   'puk',
#   ')',
#   'group',
#   '.'],
#  ['puk',
#   'and',
#   'iraq',
#   "'s",
#   'kurdistan',
#   'democratic',
#   'party',
#   '(',
#   'kdp',
#   ')',
#   'the',
#   'two',
#   'main',
#   'iraqi',
#   'kurdish',
#   'factions',
#   ',',
#   'have',
#   'had',
#   'northern',
#   'iraq',
#   'under',
#   'their',
#   'control',
#   'since',
#   'iraqi',
#   'forces',
#   'were',
#   'ousted',
#   'from',
#   'kuwait',
#   'in',
#   'the',
#   '1991',
#   'gulf',
#   'war',
#   '.'],
#  ['clashes',
#   'between',
#   'the',
#   'two',
#   'parties',
#   'broke',
#   'out',
#   'at',
#   'the',
#   'weekend',
#   'in',
#   'the',
#   'most',
#   'serious',
#   'fighting',
#   'since',
#   'a',
#   'u.s.-sponsored',
#   'ceasefire',
#   'last',
#   'year',
#   '.'],
#  ['mujahideen',
#   'khalq',
#   'said',
#   'iranian',
#   'troops',
#   'had',
#   'also',
#   'been',
#   'shelling',
#   'kdp',
#   'positions',
#   'in',
#   'qasri',
#   'region',
#   'in',
#   'suleimaniya',
#   'province',
#   'near',
#   'the',
#   'iranian',
#   'border',
#   'over',
#   'the',
#   'last',
#   'two',
#   'days',
#   '.'],
#  ['it',
#   'said',
#   'about',
#   '100',
#   'iraqi',
#   'kurds',
#   'were',
#   'killed',
#   'or',
#   'wounded',
#   'in',
#   'the',
#   'attack',
#   '.'],
#  ['both',
#   'iran',
#   'and',
#   'turkey',
#   'mount',
#   'air',
#   'and',
#   'land',
#   'strikes',
#   'at',
#   'targets',
#   'in',
#   'northern',
#   'iraq',
#   'in',
#   'pursuit',
#   'of',
#   'their',
#   'own',
#   'kurdish',
#   'rebels',
#   '.'],
#  ['a',
#   'u.s.-led',
#   'air',
#   'force',
#   'in',
#   'southern',
#   'turkey',
#   'protects',
#   'iraqi',
#   'kurds',
#   'from',
#   'possible',
#   'attacks',
#   'by',
#   'baghdad',
#   'troops',
#   '.'],
#  ['-docstart-'],
#  ['saudi', 'riyal', 'rates', 'steady', 'in', 'quiet', 'summer', 'trade', '.'],
#  ['manama', '1996-08-22'],
#  ['the',
#   'spot',
#   'saudi',
#   'riyal',
#   'against',
#   'the',
#   'dollar',
#   'and',
#   'riyal',
#   'interbank',
#   'deposit',
#   'rates',
#   'were',
#   'mainly',
#   'steady',
#   'this',
#   'week',
#   'in',
#   'quiet',
#   'summer',
#   'trade',
#   ',',
#   'dealers',
#   'in',
#   'the',
#   'kingdom',
#   'said',
#   '.'],
#  ['"', 'there', 'were', 'no', 'changes', 'in', 'saudi', 'riyal', 'rates', '.'],
#  ['the',
#   'market',
#   'was',
#   'very',
#   'quiet',
#   'because',
#   'of',
#   'summer',
#   'holidays',
#   ',',
#   '"',
#   'one',
#   'dealer',
#   'said',
#   '.'],
#  ['the',
#   'spot',
#   'riyal',
#   'was',
#   'put',
#   'at',
#   '3.7504',
#   '/',
#   '06',
#   'to',
#   'the',
#   'dollar',
#   '.'],
#  ['one-month',
#   'interbank',
#   'deposits',
#   'were',
#   'at',
#   '5-1/2',
#   ',',
#   '3/8',
#   'percent',
#   ',',
#   'three',
#   'months',
#   'were',
#   '5-5/8',
#   ',',
#   '1/2',
#   'percent',
#   'and',
#   'six',
#   'months',
#   'were',
#   '5-3/4',
#   ',',
#   '5/8',
#   'percent',
#   '.'],
#  ['one-year', 'funds', 'were', 'at', 'six', ',', '5-7/8', 'percent', '.'],
#  ['-docstart-'],
#  ['israel', 'approves', 'arafat', "'s", 'flight', 'to', 'west', 'bank', '.'],
#  ['jerusalem', '1996-08-22'],
#  ['israel',
#   'gave',
#   'palestinian',
#   'president',
#   'yasser',
#   'arafat',
#   'permission',
#   'on',
#   'thursday',
#   'to',
#   'fly',
#   'over',
#   'its',
#   'territory',
#   'to',
#   'the',
#   'west',
#   'bank',
#   ',',
#   'ending',
#   'a',
#   'brief',
#   'israeli-plo',
#   'crisis',
#   ',',
#   'an',
#   'arafat',
#   'adviser',
#   'said',
#   '.'],
#  ['"', 'the', 'problem', 'is', 'over', '.'],
#  ['the',
#   'president',
#   "'s",
#   'aircraft',
#   'has',
#   'received',
#   'permission',
#   'to',
#   'pass',
#   'through',
#   'israeli',
#   'airspace',
#   'but',
#   'the',
#   'president',
#   'is',
#   'not',
#   'expected',
#   'to',
#   'travel',
#   'to',
#   'the',
#   'west',
#   'bank',
#   'before',
#   'monday',
#   ',',
#   '"',
#   'nabil',
#   'abu',
#   'rdainah',
#   'told',
#   'reuters',
#   '.'],
#  ['arafat',
#   'had',
#   'been',
#   'scheduled',
#   'to',
#   'meet',
#   'former',
#   'israeli',
#   'prime',
#   'minister',
#   'shimon',
#   'peres',
#   'in',
#   'the',
#   'west',
#   'bank',
#   'town',
#   'of',
#   'ramallah',
#   'on',
#   'thursday',
#   'but',
#   'the',
#   'venue',
#   'was',
#   'changed',
#   'to',
#   'gaza',
#   'after',
#   'israel',
#   'denied',
#   'flight',
#   'clearance',
#   'to',
#   'the',
#   'palestinian',
#   'leader',
#   "'s",
#   'helicopters',
#   '.'],
#  ['palestinian',
#   'officials',
#   'accused',
#   'right-wing',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'of',
#   'trying',
#   'to',
#   'stop',
#   'the',
#   'ramallah',
#   'meeting',
#   'by',
#   'keeping',
#   'arafat',
#   'grounded',
#   '.'],
#  ['arafat',
#   'subsequently',
#   'cancelled',
#   'a',
#   'meeting',
#   'between',
#   'israeli',
#   'and',
#   'plo',
#   'officials',
#   ',',
#   'on',
#   'civilian',
#   'affairs',
#   ',',
#   'at',
#   'the',
#   'allenby',
#   'bridge',
#   'crossing',
#   'between',
#   'jordan',
#   'and',
#   'the',
#   'west',
#   'bank',
#   '.'],
#  ['abu',
#   'rdainah',
#   'said',
#   'arafat',
#   'had',
#   'decided',
#   'against',
#   'flying',
#   'to',
#   'the',
#   'west',
#   'bank',
#   'on',
#   'thursday',
#   ',',
#   'after',
#   'israel',
#   'lifted',
#   'the',
#   'ban',
#   ',',
#   'because',
#   'he',
#   'had',
#   'a',
#   'busy',
#   'schedule',
#   'in',
#   'gaza',
#   'and',
#   'would',
#   'not',
#   'be',
#   'free',
#   'until',
#   'monday',
#   '.'],
#  ['-docstart-'],
#  ['arafat',
#   'to',
#   'meet',
#   'peres',
#   'in',
#   'gaza',
#   'after',
#   'flight',
#   'ban',
#   '.'],
#  ['jerusalem', '1996-08-22'],
#  ['yasser',
#   'arafat',
#   'will',
#   'meet',
#   'shimon',
#   'peres',
#   'in',
#   'gaza',
#   'on',
#   'thursday',
#   'after',
#   'palestinians',
#   'said',
#   'the',
#   'right-wing',
#   'israeli',
#   'government',
#   'had',
#   'barred',
#   'the',
#   'palestinian',
#   'leader',
#   'from',
#   'flying',
#   'to',
#   'the',
#   'west',
#   'bank',
#   'for',
#   'talks',
#   'with',
#   'the',
#   'former',
#   'prime',
#   'minister',
#   '.'],
#  ['"',
#   'the',
#   'meeting',
#   'between',
#   'peres',
#   'and',
#   'arafat',
#   'will',
#   'take',
#   'place',
#   'at',
#   'erez',
#   'checkpoint',
#   'in',
#   'gaza',
#   'and',
#   'not',
#   'in',
#   'ramallah',
#   'as',
#   'planned',
#   ',',
#   '"',
#   'peres',
#   "'",
#   'office',
#   'said',
#   '.'],
#  ['palestinian',
#   'officials',
#   'said',
#   'the',
#   'israeli',
#   'government',
#   'had',
#   'barred',
#   'arafat',
#   'from',
#   'overflying',
#   'israel',
#   'in',
#   'a',
#   'palestinian',
#   'helicopter',
#   'to',
#   'the',
#   'west',
#   'bank',
#   'in',
#   'an',
#   'attempt',
#   'to',
#   'bar',
#   'the',
#   'meeting',
#   'with',
#   'peres',
#   '.'],
#  ['israeli',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'has',
#   'accused',
#   'opposition',
#   'leader',
#   'peres',
#   ',',
#   'who',
#   'he',
#   'defeated',
#   'in',
#   'may',
#   'elections',
#   ',',
#   'of',
#   'trying',
#   'to',
#   'undermine',
#   'his',
#   'likud',
#   'government',
#   "'s",
#   'authority',
#   'to',
#   'conduct',
#   'peace',
#   'talks',
#   '.'],
#  ['-docstart-'],
#  ['afghan',
#   'uae',
#   'embassy',
#   'says',
#   'taleban',
#   'guards',
#   'going',
#   'home',
#   '.'],
#  ['hilary', 'gush'],
#  ['dubai', '1996-08-22'],
#  ['three',
#   'afghan',
#   'guards',
#   'brought',
#   'to',
#   'the',
#   'united',
#   'arab',
#   'emirates',
#   'last',
#   'week',
#   'by',
#   'russian',
#   'hostages',
#   'who',
#   'escaped',
#   'from',
#   'the',
#   'taleban',
#   'militia',
#   'will',
#   'return',
#   'to',
#   'afghanistan',
#   'in',
#   'a',
#   'few',
#   'days',
#   ',',
#   'the',
#   'afghan',
#   'embassy',
#   'in',
#   'abu',
#   'dhabi',
#   'said',
#   'on',
#   'thursday',
#   '.'],
#  ['"',
#   'our',
#   'ambassador',
#   'is',
#   'in',
#   'touch',
#   'with',
#   'the',
#   'uae',
#   'foreign',
#   'ministry',
#   '.'],
#  ['their',
#   'return',
#   'to',
#   'afghanistan',
#   'will',
#   'take',
#   'place',
#   'in',
#   'two',
#   'or',
#   'three',
#   'days',
#   ',',
#   '"',
#   'an',
#   'embassy',
#   'official',
#   'said',
#   '.'],
#  ['"',
#   'the',
#   'embassy',
#   'is',
#   'issuing',
#   'them',
#   'travel',
#   'documents',
#   'for',
#   'their',
#   'return',
#   'to',
#   'their',
#   'homeland',
#   '.'],
#  ['there',
#   'is',
#   'no',
#   'objection',
#   'to',
#   'their',
#   'travel',
#   ',',
#   '"',
#   'he',
#   'added',
#   '.'],
#  ['the',
#   'three',
#   'islamic',
#   'taleban',
#   'guards',
#   'were',
#   'overpowered',
#   'by',
#   'seven',
#   'russian',
#   'aircrew',
#   'who',
#   'escaped',
#   'to',
#   'uae',
#   'state',
#   'sharjah',
#   'last',
#   'friday',
#   'on',
#   'board',
#   'their',
#   'own',
#   'aircraft',
#   'after',
#   'a',
#   'year',
#   'in',
#   'the',
#   'captivity',
#   'of',
#   'taleban',
#   'militia',
#   'in',
#   'kandahar',
#   'in',
#   'southern',
#   'afghanistan',
#   '.'],
#  ['the',
#   'uae',
#   'said',
#   'on',
#   'monday',
#   'it',
#   'would',
#   'hand',
#   'over',
#   'the',
#   'three',
#   'to',
#   'the',
#   'international',
#   'red',
#   'crescent',
#   ',',
#   'possibly',
#   'last',
#   'tuesday',
#   '.'],
#  ['it', 'has', 'since', 'been', 'silent', 'on', 'the', 'issue', '.'],
#  ['when',
#   'asked',
#   'whether',
#   'the',
#   'three',
#   'guards',
#   'would',
#   'travel',
#   'back',
#   'to',
#   'kandahar',
#   'or',
#   'the',
#   'afghan',
#   'capital',
#   'kabul',
#   ',',
#   'the',
#   'embassy',
#   'official',
#   'said',
#   ':',
#   '"',
#   'that',
#   'has',
#   'not',
#   'been',
#   'decided',
#   ',',
#   'but',
#   'possibly',
#   'kandahar',
#   '.',
#   '"'],
#  ['kandahar',
#   'is',
#   'the',
#   'headquarters',
#   'of',
#   'the',
#   'opposition',
#   'taleban',
#   'militia',
#   '.'],
#  ['kabul',
#   'is',
#   'controlled',
#   'by',
#   'president',
#   'burhanuddin',
#   'rabbani',
#   "'s",
#   'government',
#   ',',
#   'which',
#   'taleban',
#   'is',
#   'fighting',
#   'to',
#   'overthrow',
#   '.'],
#  ['the',
#   'embassy',
#   'official',
#   'said',
#   'the',
#   'three',
#   'men',
#   ',',
#   'believed',
#   'to',
#   'be',
#   'in',
#   'their',
#   '20s',
#   ',',
#   'were',
#   'currently',
#   'in',
#   'abu',
#   'dhabi',
#   '.'],
#  ['he', 'did', 'not', 'elaborate', '.'],
#  ['the',
#   'russians',
#   ',',
#   'working',
#   'for',
#   'the',
#   'aerostan',
#   'firm',
#   'in',
#   'the',
#   'russian',
#   'republic',
#   'of',
#   'tatarstan',
#   ',',
#   'were',
#   'taken',
#   'hostage',
#   'after',
#   'a',
#   'taleban',
#   'mig-19',
#   'fighter',
#   'forced',
#   'their',
#   'cargo',
#   'plane',
#   'to',
#   'land',
#   'in',
#   'august',
#   '1995',
#   '.'],
#  ['taleban',
#   'said',
#   'its',
#   'shipment',
#   'of',
#   'ammunition',
#   'from',
#   'albania',
#   'was',
#   'evidence',
#   'of',
#   'russian',
#   'military',
#   'support',
#   'for',
#   'rabbani',
#   "'s",
#   'government',
#   '.'],
#  ['moscow',
#   'said',
#   'the',
#   'crew',
#   "'s",
#   'nationality',
#   'was',
#   'coincidental',
#   '.'],
#  ['numerous',
#   'diplomatic',
#   'attempts',
#   'to',
#   'free',
#   'the',
#   'seven',
#   'failed',
#   '.'],
#  ['the',
#   'russians',
#   ',',
#   'who',
#   'said',
#   'they',
#   'overpowered',
#   'the',
#   'guards',
#   '--',
#   'two',
#   'armed',
#   'with',
#   'kalashnikov',
#   'automatic',
#   'rifles',
#   '--',
#   'while',
#   'doing',
#   'regular',
#   'maintenance',
#   'work',
#   'on',
#   'their',
#   'ilyushin',
#   '76',
#   'cargo',
#   'plane',
#   'last',
#   'friday',
#   ',',
#   'left',
#   'the',
#   'uae',
#   'capital',
#   'abu',
#   'dhabi',
#   'for',
#   'home',
#   'on',
#   'sunday',
#   '.'],
#  ['-docstart-'],
#  ['iraq', "'s", 'saddam', 'meets', 'russia', "'s", 'zhirinovsky', '.'],
#  ['baghdad', '1996-08-22'],
#  ['iraqi',
#   'president',
#   'saddam',
#   'hussein',
#   'has',
#   'told',
#   'visiting',
#   'russian',
#   'ultra-nationalist',
#   'vladimir',
#   'zhirinovsky',
#   'that',
#   'baghdad',
#   'wanted',
#   'to',
#   'maintain',
#   '"',
#   'friendship',
#   'and',
#   'cooperation',
#   '"',
#   'with',
#   'moscow',
#   ',',
#   'official',
#   'iraqi',
#   'newspapers',
#   'said',
#   'on',
#   'thursday',
#   '.'],
#  ['"',
#   'president',
#   'saddam',
#   'hussein',
#   'stressed',
#   'during',
#   'the',
#   'meeting',
#   'iraq',
#   "'s",
#   'keenness',
#   'to',
#   'maintain',
#   'friendship',
#   'and',
#   'cooperation',
#   'with',
#   'russia',
#   ',',
#   '"',
#   'the',
#   'papers',
#   'said',
#   '.'],
#  ['they',
#   'said',
#   'zhirinovsky',
#   'told',
#   'saddam',
#   'before',
#   'he',
#   'left',
#   'baghdad',
#   'on',
#   'wednesday',
#   'that',
#   'his',
#   'liberal',
#   'democratic',
#   'party',
#   'and',
#   'the',
#   'russian',
#   'duma',
#   '(',
#   'parliament',
#   ')',
#   '"',
#   'are',
#   'calling',
#   'for',
#   'an',
#   'immediate',
#   'lifting',
#   'of',
#   'the',
#   'embargo',
#   '"',
#   'imposed',
#   'on',
#   'iraq',
#   'after',
#   'its',
#   '1990',
#   'invasion',
#   'of',
#   'kuwait',
#   '.'],
#  ['zhirinovsky',
#   'said',
#   'on',
#   'tuesday',
#   'he',
#   'would',
#   'press',
#   'the',
#   'russian',
#   'government',
#   'to',
#   'help',
#   'end',
#   'u.n.',
#   'trade',
#   'sanctions',
#   'on',
#   'iraq',
#   'and',
#   'blamed',
#   'moscow',
#   'for',
#   'delaying',
#   'establishment',
#   'of',
#   'good',
#   'ties',
#   'with',
#   'baghdad',
#   '.'],
#  ['"',
#   'our',
#   'stand',
#   'is',
#   'firm',
#   ',',
#   'namely',
#   'we',
#   'are',
#   'calling',
#   'on',
#   '(',
#   'the',
#   'russian',
#   ')',
#   'government',
#   'to',
#   'end',
#   'the',
#   'economic',
#   'embargo',
#   'on',
#   'iraq',
#   'and',
#   'resume',
#   'trade',
#   'ties',
#   'between',
#   'russia',
#   'and',
#   'iraq',
#   ',',
#   '"',
#   'he',
#   'told',
#   'reporters',
#   '.'],
#  ['zhirinovsky', 'visited', 'iraq', 'twice', 'in', '1995', '.'],
#  ['last',
#   'october',
#   'he',
#   'was',
#   'invited',
#   'to',
#   'attend',
#   'the',
#   'referendum',
#   'held',
#   'on',
#   'iraq',
#   "'s",
#   'presidency',
#   ',',
#   'which',
#   'extended',
#   'saddam',
#   "'s",
#   'term',
#   'for',
#   'seven',
#   'more',
#   'years',
#   '.'],
#  ['-docstart-'],
#  ['press', 'digest', '-', 'iraq', '-', 'aug', '22', '.'],
#  ['baghdad', '1996-08-22'],
#  ['these',
#   'are',
#   'some',
#   'of',
#   'the',
#   'leading',
#   'stories',
#   'in',
#   'the',
#   'official',
#   'iraqi',
#   'press',
#   'on',
#   'thursday',
#   '.'],
#  ['reuters',
#   'has',
#   'not',
#   'verified',
#   'these',
#   'stories',
#   'and',
#   'does',
#   'not',
#   'vouch',
#   'for',
#   'their',
#   'accuracy',
#   '.'],
#  ['thawra'],
#  ['-',
#   'iraq',
#   "'s",
#   'president',
#   'saddam',
#   'hussein',
#   'meets',
#   'with',
#   'chairman',
#   'of',
#   'the',
#   'russian',
#   'liberal',
#   'democratic',
#   'party',
#   'vladimir',
#   'zhirinovsky',
#   '.'],
#  ['-',
#   'turkish',
#   'foreign',
#   'minister',
#   'says',
#   'turkey',
#   'will',
#   'take',
#   'part',
#   'in',
#   'the',
#   'baghdad',
#   'trade',
#   'fair',
#   'that',
#   'will',
#   'be',
#   'held',
#   'in',
#   'november',
#   '.'],
#  ['iraq'],
#  ['-',
#   'a',
#   'shipload',
#   'of',
#   '12',
#   'tonnes',
#   'of',
#   'rice',
#   'arrives',
#   'in',
#   'umm',
#   'qasr',
#   'port',
#   'in',
#   'the',
#   'gulf',
#   '.'],
#  ['-docstart-'],
#  ['press', 'digest', '-', 'lebanon', '-', 'aug', '22', '.'],
#  ['beirut', '1996-08-22'],
#  ['these',
#   'are',
#   'the',
#   'leading',
#   'stories',
#   'in',
#   'the',
#   'beirut',
#   'press',
#   'on',
#   'thursday',
#   '.'],
#  ['reuters',
#   'has',
#   'not',
#   'verified',
#   'these',
#   'stories',
#   'and',
#   'does',
#   'not',
#   'vouch',
#   'for',
#   'their',
#   'accuracy',
#   '.'],
#  ['an-nahar'],
#  ['-',
#   'confrontation',
#   'is',
#   'escalating',
#   'between',
#   'hizbollah',
#   'and',
#   'the',
#   'government',
#   '.'],
#  ['-',
#   'prime',
#   'minister',
#   'hariri',
#   ':',
#   'israeli',
#   'threats',
#   'do',
#   'no',
#   'serve',
#   'peace',
#   '.'],
#  ['as-safir'],
#  ['-',
#   'parliament',
#   'speaker',
#   'berri',
#   ':',
#   'israel',
#   'is',
#   'preparing',
#   'for',
#   'war',
#   'against',
#   'syria',
#   'and',
#   'lebanon',
#   '.'],
#  ['-', 'parliamentary', 'battle', 'in', 'beirut', '..'],
#  ['the', 'three', 'main', 'lists', 'have', 'been', 'prepared', '.'],
#  ['al-anwar'],
#  ['-',
#   'continued',
#   'criticism',
#   'of',
#   'law',
#   'violation',
#   'incidents',
#   '--',
#   'which',
#   'occurred',
#   'in',
#   'the',
#   'mount',
#   'lebanon',
#   'elections',
#   'last',
#   'sunday',
#   '.'],
#  ['ad-diyar'],
#  ['-',
#   'financial',
#   'negotiations',
#   'between',
#   'lebanon',
#   'and',
#   'pakistan',
#   '.'],
#  ['-',
#   'hariri',
#   'to',
#   'step',
#   'into',
#   'the',
#   'election',
#   'battle',
#   'with',
#   'an',
#   'incomplete',
#   'list',
#   '.'],
#  ["nida'a", 'al-watan'],
#  ['-',
#   'maronite',
#   'patriarch',
#   'sfeir',
#   'expressed',
#   'sorrow',
#   'over',
#   'the',
#   'violations',
#   'in',
#   'sunday',
#   "'",
#   'elections',
#   '.'],
#  ['-docstart-'],
#  ['cme', 'live', 'and', 'feeder', 'cattle', 'calls', 'range', 'mixed', '.'],
#  ['chicago', '1996-08-22'],
#  ['early',
#   'calls',
#   'on',
#   'cme',
#   'live',
#   'and',
#   'feeder',
#   'cattle',
#   'futures',
#   'ranged',
#   'from',
#   '0.200',
#   'cent',
#   'higher',
#   'to',
#   '0.100',
#   'lower',
#   ',',
#   'livestock',
#   'analysts',
#   'said',
#   '.'],
#  ['the',
#   'continued',
#   'strong',
#   'tone',
#   'to',
#   'cash',
#   'cattle',
#   'and',
#   'beef',
#   'markets',
#   'should',
#   'prompt',
#   'further',
#   'support',
#   '.'],
#  ['outlook',
#   'for',
#   'a',
#   'bullish',
#   'cattle-on-feed',
#   'report',
#   'is',
#   'also',
#   'expected',
#   'to',
#   'lend',
#   'support',
#   'and',
#   'prompt',
#   'some',
#   'bull',
#   'spreading',
#   ',',
#   'analysts',
#   'said',
#   '.'],
#  ['however',
#   ',',
#   'trade',
#   'will',
#   'likely',
#   'be',
#   'light',
#   'and',
#   'prices',
#   'could',
#   'drift',
#   'on',
#   'evening',
#   'up',
#   'ahead',
#   'of',
#   'the',
#   'report',
#   '.'],
#  ['cash',
#   'markets',
#   'are',
#   'also',
#   'expected',
#   'to',
#   'be',
#   'quiet',
#   'after',
#   'the',
#   'record',
#   'amount',
#   'of',
#   'feedlot',
#   'cattle',
#   'traded',
#   'this',
#   'week',
#   ',',
#   'they',
#   'said',
#   '.'],
#  ['-docstart-'],
#  ['kindercare', 'says', 'debt', 'buy', 'to', 'hit', 'q1', 'results', '.'],
#  ['montgomery', ',', 'ala', '.'],
#  ['1996-08-22'],
#  ['kindercare',
#   'learning',
#   'centers',
#   'inc',
#   'said',
#   'on',
#   'thursday',
#   'that',
#   'a',
#   'debt',
#   'buyback',
#   'would',
#   'mean',
#   'an',
#   'extraordinary',
#   'loss',
#   'of',
#   '$',
#   '1.2',
#   'million',
#   'in',
#   'its',
#   'fiscal',
#   '1997',
#   'first',
#   'quarter',
#   '.'],
#  ['the',
#   'company',
#   'said',
#   'that',
#   'during',
#   'the',
#   'quarter',
#   ',',
#   'which',
#   'began',
#   'june',
#   '1',
#   ',',
#   'it',
#   'bought',
#   '$',
#   '30',
#   'million',
#   'par',
#   'value',
#   'of',
#   'its',
#   'outstanding',
#   '10-3/8',
#   'percent',
#   'senior',
#   'notes',
#   'due',
#   '2001',
#   '.'],
#  ['the', 'notes', 'were', 'bought', 'for', '$', '31.5', 'million', '.'],
#  ['philip',
#   'maslowe',
#   ',',
#   'chief',
#   'financial',
#   'officer',
#   'of',
#   'the',
#   'preschool',
#   'and',
#   'child',
#   'care',
#   'company',
#   ',',
#   'said',
#   'the',
#   'buyback',
#   '"',
#   'offered',
#   'an',
#   'opportunity',
#   'to',
#   'reduce',
#   'the',
#   'company',
#   "'s",
#   'weighted',
#   'average',
#   'interest',
#   'costs',
#   'and',
#   'improve',
#   'future',
#   'cash',
#   'flows',
#   'and',
#   'earnings',
#   '.',
#   '"'],
#  ['-docstart-'],
#  ['research', 'alert', '-', 'lehman', 'starts', 'snet', '.'],
#  ['--',
#   'lehman',
#   'analyst',
#   'blake',
#   'bath',
#   'started',
#   'southern',
#   'new',
#   'england',
#   'telecommunciations',
#   'corp',
#   'with',
#   'an',
#   'outperform',
#   'rating',
#   ',',
#   'his',
#   'office',
#   'said',
#   '.'],
#  ['--',
#   'the',
#   'analyst',
#   'set',
#   'a',
#   '12-month',
#   'price',
#   'target',
#   'of',
#   '$',
#   '45',
#   'and',
#   'a',
#   'fiscal',
#   '1996',
#   'year',
#   'earnings',
#   'estimate',
#   'of',
#   '$',
#   '3.09',
#   'per',
#   'share',
#   ',',
#   'his',
#   'office',
#   'said',
#   '.'],
#  ['--',
#   'the',
#   'analyst',
#   'also',
#   'set',
#   'an',
#   'earnings',
#   'estimate',
#   'for',
#   'the',
#   '1997',
#   'year',
#   ',',
#   'but',
#   'the',
#   'figure',
#   'was',
#   'not',
#   'immediately',
#   'available',
#   '.'],
#  ['--',
#   'southern',
#   'new',
#   'england',
#   'closed',
#   'at',
#   '38-1/2',
#   'wednesday',
#   '.'],
#  ['--', 'e.', 'auchard', ',', 'wall', 'street', 'bureau', ',', '212-859-1736'],
#  ['-docstart-'],
#  ['gateway', 'data', 'sciences', 'q2', 'net', 'rises', '.'],
#  ['phoenix', '1996-08-22'],
#  ['summary', 'of', 'consolidated', 'financial', 'data'],
#  ['(', 'in', 'thousands', ',', 'except', 'per', 'share', 'data', ')'],
#  ['six', 'months', 'ended', 'quarter', 'ended'],
#  ['jul', '31', ',', 'jul', '31', ',', 'jul', '31', ',', 'jul', '31', ','],
#  ['1996', '1995', '1996', '1995'],
#  ['income', 'statement', 'data', ':'],
#  ['total',
#   'revenue',
#   '$',
#   '10,756',
#   '$',
#   '13,102',
#   '$',
#   '7,961',
#   '$',
#   '5,507'],
#  ['software', 'revenue', '2,383', '1,558', '1,086', '1,074'],
#  ['services', 'revenue', '1,154', '692', '624', '465'],
#  ['operating', 'income', '906', '962', '599', '515'],
#  ['net', 'income', '821', '512', '565', '301'],
#  ['earnings', 'per', 'share', '0.31', '0.34', '0.19', '0.20'],
#  ['jul', '31', ',', '1996', 'jan', '31', ',', '1996'],
#  ['balance', 'sheet', 'data', ':'],
#  ['working', 'capital', '$', '5,755', '(', '$', '881', ')'],
#  ['cash', 'and', 'cash', 'equivalents', '2,386', '93'],
#  ['total', 'assets', '14,196', '7,138'],
#  ['shareholders', "'", 'equity', '5,951', '(', '1,461', ')'],
#  ['-docstart-'],
#  ['greek',
#   'socialists',
#   'give',
#   'pm',
#   'green',
#   'light',
#   'for',
#   'election',
#   '.'],
#  ['athens', '1996-08-22'],
#  ['the',
#   'greek',
#   'socialist',
#   'party',
#   "'s",
#   'executive',
#   'bureau',
#   'gave',
#   'prime',
#   'minister',
#   'costas',
#   'simitis',
#   'its',
#   'backing',
#   'if',
#   'he',
#   'chooses',
#   'to',
#   'call',
#   'snap',
#   'elections',
#   ',',
#   'its',
#   'general',
#   'secretary',
#   'costas',
#   'skandalidis',
#   'told',
#   'reporters',
#   'on',
#   'thursday',
#   '.'],
#  ['prime',
#   'minister',
#   'costas',
#   'simitis',
#   'will',
#   'make',
#   'an',
#   'official',
#   'announcement',
#   'after',
#   'a',
#   'cabinet',
#   'meeting',
#   'later',
#   'on',
#   'thursday',
#   ',',
#   'said',
#   'skandalidis',
#   '.'],
#  ['--',
#   'dimitris',
#   'kontogiannis',
#   ',',
#   'athens',
#   'newsroom',
#   '+301',
#   '3311812-4'],
#  ['-docstart-'],
#  ['press', 'digest', '-', 'france', '-', 'le', 'monde', 'aug', '22', '.'],
#  ['paris', '1996-08-22'],
#  ['these',
#   'are',
#   'leading',
#   'stories',
#   'in',
#   'thursday',
#   "'s",
#   'afternoon',
#   'daily',
#   'le',
#   'monde',
#   ',',
#   'dated',
#   'aug',
#   '23',
#   '.'],
#  ['front', 'page'],
#  ['--',
#   'africans',
#   'seeking',
#   'to',
#   'renew',
#   'or',
#   'obtain',
#   'work',
#   'and',
#   'residence',
#   'rights',
#   'say',
#   'prime',
#   'minister',
#   'alain',
#   'juppe',
#   "'s",
#   'proposals',
#   'are',
#   'insufficient',
#   'as',
#   'hunger',
#   'strike',
#   'enters',
#   '49th',
#   'day',
#   'in',
#   'paris',
#   'church',
#   'and',
#   'wednesday',
#   'rally',
#   'attracts',
#   '8,000',
#   'sympathisers',
#   '.'],
#  ['--',
#   'flnc',
#   'corsican',
#   'nationalist',
#   'movement',
#   'announces',
#   'end',
#   'of',
#   'truce',
#   'after',
#   'last',
#   'night',
#   "'s",
#   'attacks',
#   '.'],
#  ['business', 'pages'],
#  ['--',
#   'shutdown',
#   'of',
#   'bally',
#   "'s",
#   'french',
#   'factories',
#   'points',
#   'up',
#   'shoe',
#   'industry',
#   'crisis',
#   ',',
#   'with',
#   'french',
#   'manufacturers',
#   'undercut',
#   'by',
#   'low-wage',
#   'country',
#   'competition',
#   'and',
#   'failure',
#   'to',
#   'keep',
#   'abreast',
#   'of',
#   'trends',
#   '.'],
#  ['--',
#   'secretary',
#   'general',
#   'of',
#   'the',
#   'sud-ptt',
#   'trade',
#   'union',
#   'at',
#   'france',
#   'telecom',
#   'all',
#   'the',
#   'elements',
#   'are',
#   'in',
#   'place',
#   'for',
#   'social',
#   'unrest',
#   'in',
#   'the',
#   'next',
#   'few',
#   'weeks',
#   '.'],
#  ['--', 'paris', 'newsroom', '+33', '1', '42', '21', '53', '81'],
#  ['-docstart-'],
#  ['well',
#   'repairs',
#   'to',
#   'lift',
#   'heidrun',
#   'oil',
#   'output',
#   '-',
#   'statoil',
#   '.'],
#  ['oslo', '1996-08-22'],
#  ['three',
#   'plugged',
#   'water',
#   'injection',
#   'wells',
#   'on',
#   'the',
#   'heidrun',
#   'oilfield',
#   'off',
#   'mid-norway',
#   'will',
#   'be',
#   'reopened',
#   'over',
#   'the',
#   'next',
#   'month',
#   ',',
#   'operator',
#   'den',
#   'norske',
#   'stats',
#   'oljeselskap',
#   'as',
#   '(',
#   'statoil',
#   ')',
#   'said',
#   'on',
#   'thursday',
#   '.'],
#  ['the',
#   'plugged',
#   'wells',
#   'have',
#   'accounted',
#   'for',
#   'a',
#   'dip',
#   'of',
#   '30,000',
#   'barrels',
#   'per',
#   'day',
#   '(',
#   'bpd',
#   ')',
#   'in',
#   'heidrun',
#   'output',
#   'to',
#   'roughly',
#   '220,000',
#   'bpd',
#   ',',
#   'according',
#   'to',
#   'the',
#   'company',
#   "'s",
#   'status',
#   'weekly',
#   'newsletter',
#   '.'],
#  ['the',
#   'wells',
#   'will',
# ...
#   'swing',
#   'on',
#   'it',
#   'and',
#   'put',
#   'it',
#   'in',
#   'play',
#   ',',
#   '"',
#   'greer',
#   'said',
#   '.',
#   '"'],
#  ['this', 'was', 'a', 'big', 'game', '.'],
#  ['the',
#   'crowd',
#   'was',
#   'behind',
#   'him',
#   'and',
#   'it',
#   'was',
#   'intense',
#   '.',
#   '"'],
#  ['the',
#   'shot',
#   'brought',
#   'home',
#   'ivan',
#   'rodriguez',
#   ',',
#   'who',
#   'had',
#   'his',
#   'second',
#   'double',
#   'of',
#   'the',
#   'game',
#   ',',
#   'giving',
#   'him',
#   '42',
#   'this',
#   'season',
#   ',',
#   '41',
#   'as',
#   'a',
#   'catcher',
#   '.'],
#  ['he',
#   'joined',
#   'mickey',
#   'cochrane',
#   ',',
#   'johnny',
#   'bench',
#   'and',
#   'terry',
#   'kennedy',
#   'as',
#   'the',
#   'only',
#   'catchers',
#   'with',
#   '40',
#   'doubles',
#   'in',
#   'a',
#   'season',
#   '.'],
#  ['the',
#   'rangers',
#   'have',
#   'won',
#   '10',
#   'of',
#   'their',
#   'last',
#   '12',
#   'games',
#   'and',
#   'six',
#   'of',
#   'nine',
#   'meetings',
#   'against',
#   'the',
#   'indians',
#   'this',
#   'season',
#   '.'],
#  ['the',
#   'american',
#   'league',
#   'western',
#   'leaders',
#   'have',
#   'won',
#   'eight',
#   'of',
#   '15',
#   'games',
#   'at',
#   'jacobs',
#   'field',
#   ',',
#   'joining',
#   'the',
#   'yankees',
#   'as',
#   'the',
#   'only',
#   'teams',
#   'with',
#   'a',
#   'winning',
#   'record',
#   'at',
#   'the',
#   'a.l.',
#   'central',
#   'leaders',
#   "'",
#   'home',
#   '.'],
#  ['cleveland',
#   'lost',
#   'for',
#   'just',
#   'the',
#   'second',
#   'time',
#   'in',
#   'six',
#   'games',
#   '.'],
#  ['the',
#   'indians',
#   'sent',
#   'the',
#   'game',
#   'into',
#   'extra',
#   'innings',
#   'in',
#   'the',
#   'ninth',
#   'on',
#   'kenny',
#   'lofton',
#   "'s",
#   'two-run',
#   'single',
#   '.'],
#  ['ed',
#   'vosberg',
#   '(',
#   '1-0',
#   ')',
#   'blew',
#   'his',
#   'first',
#   'save',
#   'opportunity',
#   'but',
#   'got',
#   'the',
#   'win',
#   ',',
#   'allowing',
#   'three',
#   'hits',
#   'with',
#   'two',
#   'walks',
#   'and',
#   'three',
#   'strikeouts',
#   'in',
#   '1',
#   '2/3',
#   'scoreless',
#   'innings',
#   '.'],
#  ['dean',
#   'palmer',
#   'hit',
#   'his',
#   '30th',
#   'homer',
#   'for',
#   'the',
#   'rangers',
#   '.'],
#  ['in',
#   'baltimore',
#   ',',
#   'cal',
#   'ripken',
#   'had',
#   'four',
#   'hits',
#   'and',
#   'snapped',
#   'a',
#   'fifth-inning',
#   'tie',
#   'with',
#   'a',
#   'solo',
#   'homer',
#   'and',
#   'bobby',
#   'bonilla',
#   'added',
#   'a',
#   'three-run',
#   'shot',
#   'in',
#   'the',
#   'seventh',
#   'to',
#   'power',
#   'the',
#   'surging',
#   'orioles',
#   'to',
#   'a',
#   '10-5',
#   'victory',
#   'over',
#   'the',
#   'seattle',
#   'mariners',
#   '.'],
#  ['the',
#   'mariners',
#   'scored',
#   'four',
#   'runs',
#   'in',
#   'the',
#   'top',
#   'of',
#   'the',
#   'fifth',
#   'to',
#   'tie',
#   'the',
#   'game',
#   '5-5',
#   'but',
#   'ripken',
#   'led',
#   'off',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'inning',
#   'with',
#   'his',
#   '21st',
#   'homer',
#   'off',
#   'starter',
#   'sterling',
#   'hitchcock',
#   '(',
#   '12-6',
#   ')',
#   '.'],
#  ['bonilla',
#   "'s",
#   'blast',
#   'was',
#   'the',
#   'first',
#   'time',
#   'randy',
#   'johnson',
#   ',',
#   'last',
#   'season',
#   "'s",
#   'cy',
#   'young',
#   'winner',
#   ',',
#   'allowed',
#   'a',
#   'run',
#   'in',
#   'five',
#   'relief',
#   'appearances',
#   'since',
#   'coming',
#   'off',
#   'the',
#   'disabled',
#   'list',
#   'on',
#   'august',
#   '6',
#   '.'],
#  ['bonilla',
#   'has',
#   '21',
#   'rbi',
#   'and',
#   '15',
#   'runs',
#   'in',
#   'his',
#   'last',
#   '20',
#   'games',
#   '.'],
#  ['baltimore',
#   'has',
#   'won',
#   'seven',
#   'of',
#   'nine',
#   'and',
#   '16',
#   'of',
#   'its',
#   'last',
#   '22',
#   'and',
#   'cut',
#   'the',
#   'yankees',
#   "'",
#   'lead',
#   'in',
#   'the',
#   'a.l.',
#   'east',
#   'to',
#   'five',
#   'games',
#   '.'],
#  ['scott',
#   'erickson',
#   '(',
#   '8-10',
#   ')',
#   'laboured',
#   'to',
#   'his',
#   'third',
#   'straight',
#   'win',
#   '.'],
#  ['alex',
#   'rodriguez',
#   'had',
#   'two',
#   'homers',
#   'and',
#   'four',
#   'rbi',
#   'for',
#   'the',
#   'mariners',
#   ',',
#   'who',
#   'have',
#   'dropped',
#   'three',
#   'in',
#   'a',
#   'row',
#   'and',
#   '11',
#   'of',
#   '15',
#   '.'],
#  ['he',
#   'became',
#   'the',
#   'fifth',
#   'shortstop',
#   'in',
#   'major-league',
#   'history',
#   'to',
#   'hit',
#   '30',
#   'homers',
#   'in',
#   'a',
#   'season',
#   'and',
#   'the',
#   'first',
#   'since',
#   'ripken',
#   'hit',
#   '34',
#   'in',
#   '1991',
#   '.'],
#  ['chris', 'hoiles', 'hit', 'his', '22nd', 'homer', 'for', 'baltimore', '.'],
#  ['in',
#   'new',
#   'york',
#   ',',
#   'jason',
#   'dickson',
#   'scattered',
#   '10',
#   'hits',
#   'over',
#   '6',
#   '1/3',
#   'innings',
#   'in',
#   'his',
#   'major-league',
#   'debut',
#   'and',
#   'chili',
#   'davis',
#   'belted',
#   'a',
#   'homer',
#   'from',
#   'each',
#   'side',
#   'of',
#   'the',
#   'plate',
#   'as',
#   'the',
#   'california',
#   'angels',
#   'defeated',
#   'the',
#   'yankees',
#   '7-1',
#   '.'],
#  ['dickson',
#   'allowed',
#   'a',
#   'homer',
#   'to',
#   'derek',
#   'jeter',
#   'on',
#   'his',
#   'first',
#   'major-league',
#   'pitch',
#   'but',
#   'settled',
#   'down',
#   '.'],
#  ['he',
#   'was',
#   'the',
#   '27th',
#   'pitcher',
#   'used',
#   'by',
#   'the',
#   'angels',
#   'this',
#   'season',
#   ',',
#   'tying',
#   'a',
#   'major-league',
#   'record',
#   '.'],
#  ['jimmy',
#   'key',
#   '(',
#   '9-10',
#   ')',
#   'took',
#   'the',
#   'loss',
#   'as',
#   'the',
#   'yankees',
#   'lost',
#   'their',
#   'ninth',
#   'in',
#   '14',
#   'games',
#   '.'],
#  ['they', 'stranded', '11', 'baserunners', '.'],
#  ['california',
#   'played',
#   'without',
#   'interim',
#   'manager',
#   'john',
#   'mcnamara',
#   ',',
#   'who',
#   'was',
#   'admitted',
#   'to',
#   'a',
#   'new',
#   'york',
#   'hospital',
#   'with',
#   'a',
#   'blood',
#   'clot',
#   'in',
#   'his',
#   'right',
#   'calf',
#   '.'],
#  ['in',
#   'boston',
#   ',',
#   'mike',
#   'stanley',
#   "'s",
#   'bases-loaded',
#   'two-run',
#   'single',
#   'snapped',
#   'an',
#   'eighth-inning',
#   'tie',
#   'and',
#   'gave',
#   'the',
#   'red',
#   'sox',
#   'their',
#   'third',
#   'straight',
#   'win',
#   ',',
#   '6-4',
#   'over',
#   'the',
#   'oakland',
#   'athletics',
#   '.'],
#  ['stanley',
#   'owns',
#   'a',
#   '.367',
#   'career',
#   'batting',
#   'average',
#   'with',
#   'the',
#   'bases',
#   'loaded',
#   '(',
#   '33-for-90',
#   ')',
#   '.'],
#  ['boston',
#   "'s",
#   'mo',
#   'vaughn',
#   'went',
#   '3-for-3',
#   'with',
#   'a',
#   'walk',
#   ',',
#   'stole',
#   'home',
#   'for',
#   'one',
#   'of',
#   'his',
#   'three',
#   'runs',
#   'scored',
#   'and',
#   'collected',
#   'his',
#   '116th',
#   'rbi',
#   '.'],
#  ['scott',
#   'brosius',
#   'homered',
#   'and',
#   'drove',
#   'in',
#   'two',
#   'runs',
#   'for',
#   'the',
#   'athletics',
#   ',',
#   'who',
#   'have',
#   'lost',
#   'seven',
#   'of',
#   'their',
#   'last',
#   'nine',
#   'games',
#   '.'],
#  ['in',
#   'detroit',
#   ',',
#   'brad',
#   'ausmus',
#   "'s",
#   'three-run',
#   'homer',
#   'capped',
#   'a',
#   'four-run',
#   'eighth',
#   'and',
#   'lifted',
#   'the',
#   'tigers',
#   'to',
#   'a',
#   '7-4',
#   'victory',
#   'over',
#   'the',
#   'reeling',
#   'chicago',
#   'white',
#   'sox',
#   '.'],
#  ['the',
#   'tigers',
#   'have',
#   'won',
#   'consecutive',
#   'games',
#   'after',
#   'dropping',
#   'eight',
#   'in',
#   'a',
#   'row',
#   ',',
#   'but',
#   'have',
#   'won',
#   'nine',
#   'of',
#   'their',
#   'last',
#   '12',
#   'at',
#   'home',
#   '.'],
#  ['the',
#   'white',
#   'sox',
#   'have',
#   'lost',
#   'six',
#   'of',
#   'their',
#   'last',
#   'eight',
#   'games',
#   '.'],
#  ['in',
#   'kansas',
#   'city',
#   ',',
#   'juan',
#   'guzman',
#   'tossed',
#   'a',
#   'complete-game',
#   'six-hitter',
#   'to',
#   'win',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'over',
#   'a',
#   'month',
#   'and',
#   'lower',
#   'his',
#   'league-best',
#   'era',
#   'as',
#   'the',
#   'toronto',
#   'blue',
#   'jays',
#   'won',
#   'their',
#   'fourth',
#   'straight',
#   ',',
#   '6-2',
#   'over',
#   'the',
#   'royals',
#   '.'],
#  ['guzman',
#   '(',
#   '10-8',
#   ')',
#   'won',
#   'for',
#   'the',
#   'first',
#   'time',
#   'since',
#   'july',
#   '16',
#   ',',
#   'a',
#   'span',
#   'of',
#   'six',
#   'starts',
#   '.'],
#  ['he',
#   'allowed',
#   'two',
#   'runs',
#   '--',
#   'one',
#   'earned',
#   '--',
#   'and',
#   'lowered',
#   'his',
#   'era',
#   'to',
#   '2.99',
#   '.'],
#  ['at',
#   'minnesota',
#   ',',
#   'john',
#   'jaha',
#   "'s",
#   'three-run',
#   'homer',
#   ',',
#   'his',
#   '26th',
#   ',',
#   'capped',
#   'a',
#   'five-run',
#   'eighth',
#   'inning',
#   'that',
#   'rallied',
#   'the',
#   'milwaukee',
#   'brewers',
#   'to',
#   'a',
#   '10-7',
#   'victory',
#   'over',
#   'the',
#   'twins',
#   '.'],
#  ['jaha',
#   'added',
#   'an',
#   'rbi',
#   'single',
#   'in',
#   'the',
#   'ninth',
#   'and',
#   'had',
#   'four',
#   'rbi',
#   '.'],
#  ['jose', 'valentin', 'hit', 'his', '21st', 'homer', 'for', 'milwaukee', '.'],
#  ['-docstart-'],
#  ['soccer', '-', 'cocu', 'double', 'earns', 'psv', '4-1', 'win', '.'],
#  ['amsterdam', '1996-08-22'],
#  ['philip',
#   'cocu',
#   'scored',
#   'twice',
#   'in',
#   'the',
#   'second',
#   'half',
#   'to',
#   'spur',
#   'psv',
#   'eindhoven',
#   'to',
#   'a',
#   '4-1',
#   'away',
#   'win',
#   'over',
#   'nec',
#   'nijmegen',
#   'in',
#   'the',
#   'dutch',
#   'first',
#   'division',
#   'on',
#   'thursday',
#   '.'],
#  ['he',
#   'scored',
#   'from',
#   'close',
#   'range',
#   'in',
#   'the',
#   '54th',
#   'minute',
#   'and',
#   'from',
#   'a',
#   'bicycle',
#   'kick',
#   '13',
#   'minutes',
#   'later',
#   '.'],
#  ['arthur',
#   'numan',
#   'and',
#   'luc',
#   'nilis',
#   ',',
#   'dutch',
#   'top',
#   'scorer',
#   'last',
#   'season',
#   ',',
#   'were',
#   'psv',
#   "'s",
#   'other',
#   'marksmen',
#   '.'],
#  ['ajax',
#   'amsterdam',
#   'opened',
#   'their',
#   'title',
#   'defence',
#   'with',
#   'a',
#   '1-0',
#   'win',
#   'over',
#   'nac',
#   'breda',
#   'on',
#   'wednesday',
#   '.'],
#  ['-docstart-'],
#  ['soccer', '-', 'dutch', 'first', 'division', 'summary', '.'],
#  ['amsterdam', '1996-08-22'],
#  ['summary', 'of', 'thursday', "'s", 'only'],
#  ['dutch', 'first', 'division', 'match', ':'],
#  ['nec',
#   'nijmegen',
#   '1',
#   '(',
#   'van',
#   'eykeren',
#   '15th',
#   ')',
#   'psv',
#   'eindhoven',
#   '4',
#   '(',
#   'numan',
#   '11th',
#   ','],
#  ['nilis', '42nd', ',', 'cocu', '54th', ',', '67th', ')', '.'],
#  ['halftime', '1-2', '.'],
#  ['attendance', '8,000'],
#  ['-docstart-'],
#  ['soccer', '-', 'dutch', 'first', 'division', 'result', '.'],
#  ['amsterdam', '1996-08-22'],
#  ['result', 'of', 'a', 'dutch', 'first'],
#  ['division', 'match', 'on', 'thursday', ':'],
#  ['nec', 'nijmegen', '1', 'psv', 'eindhoven', '4'],
#  ['-docstart-'],
#  ['soccer', '-', 'sharpshooter', 'knup', 'back', 'in', 'swiss', 'squad', '.'],
#  ['geneva', '1996-08-22'],
#  ['galatasaray',
#   'striker',
#   'adrian',
#   'knup',
#   ',',
#   'scorer',
#   'of',
#   '26',
#   'goals',
#   'in',
#   '45',
#   'internationals',
#   ',',
#   'has',
#   'been',
#   'recalled',
#   'by',
#   'switzerland',
#   'for',
#   'the',
#   'world',
#   'cup',
#   'qualifier',
#   'against',
#   'azerbaijan',
#   'in',
#   'baku',
#   'on',
#   'august',
#   '31',
#   '.'],
#  ['knup',
#   'was',
#   'overlooked',
#   'by',
#   'artur',
#   'jorge',
#   'for',
#   'the',
#   'european',
#   'championship',
#   'finals',
#   'earlier',
#   'this',
#   'year',
#   '.'],
#  ['but',
#   'new',
#   'coach',
#   'rolf',
#   'fringer',
#   'is',
#   'clearly',
#   'a',
#   'knup',
#   'fan',
#   'and',
#   'included',
#   'him',
#   'in',
#   'his',
#   '19-man',
#   'squad',
#   'on',
#   'thursday',
#   '.'],
#  ['switzerland',
#   'failed',
#   'to',
#   'progress',
#   'beyond',
#   'the',
#   'opening',
#   'group',
#   'phase',
#   'in',
#   'euro',
#   '96',
#   '.'],
#  ['squad', ':'],
#  ['goalkeepers',
#   '-',
#   'marco',
#   'pascolo',
#   '(',
#   'cagliari',
#   ')',
#   ',',
#   'pascal',
#   'zuberbuehler',
#   '(',
#   'grasshoppers',
#   ')',
#   '.'],
#  ['defenders',
#   '-',
#   'stephane',
#   'henchoz',
#   '(',
#   'hamburg',
#   ')',
#   ',',
#   'marc',
#   'hottiger',
#   '(',
#   'everton',
#   ')',
#   ',',
#   'yvan',
#   'quentin',
#   '(',
#   'sion',
#   ')',
#   ',',
#   'ramon',
#   'vega',
#   '(',
#   'cagliari',
#   ')',
#   'raphael',
#   'wicky',
#   '(',
#   'sion',
#   ')',
#   '.'],
#  ['midfielders',
#   '-',
#   'alexandre',
#   'comisetti',
#   '(',
#   'grasshoppers',
#   ')',
#   ',',
#   'antonio',
#   'esposito',
#   '(',
#   'grasshoppers',
#   ')',
#   ',',
#   'sebastien',
#   'fournier',
#   '(',
#   'stuttgart',
#   ')',
#   ',',
#   'christophe',
#   'ohrel',
#   '(',
#   'lausanne',
#   ')',
#   ',',
#   'patrick',
#   'sylvestre',
#   '(',
#   'sion',
#   ')',
#   ',',
#   'david',
#   'sesa',
#   '(',
#   'servette',
#   ')',
#   ',',
#   'ciriaco',
#   'sforza',
#   '(',
#   'inter',
#   'milan',
#   ')',
#   'murat',
#   'yakin',
#   '(',
#   'grasshoppers',
#   ')',
#   '.'],
#  ['strikers',
#   '-',
#   'kubilay',
#   'turkyilmaz',
#   '(',
#   'grasshoppers',
#   ')',
#   ',',
#   'adrian',
#   'knup',
#   '(',
#   'galatasaray',
#   ')',
#   ',',
#   'christophe',
#   'bonvin',
#   '(',
#   'sion',
#   ')',
#   ',',
#   'stephane',
#   'chapuisat',
#   '(',
#   'borussia',
#   'dortmund',
#   ')',
#   '.'],
#  ['-docstart-'],
#  ['athletics',
#   '-',
#   'it',
#   "'s",
#   'a',
#   'record',
#   '-',
#   '40,000',
#   'beers',
#   'on',
#   'the',
#   'house',
#   '.'],
#  ['brussels', '1996-08-22'],
#  ['spectators',
#   'at',
#   'friday',
#   "'s",
#   'brussels',
#   'grand',
#   'prix',
#   'meeting',
#   'have',
#   'an',
#   'extra',
#   'incentive',
#   'to',
#   'cheer',
#   'on',
#   'the',
#   'athletes',
#   'to',
#   'world',
#   'record',
#   'performances',
#   '--',
#   'a',
#   'free',
#   'glass',
#   'of',
#   'beer',
#   '.'],
#  ['a',
#   'belgian',
#   'brewery',
#   'has',
#   'offered',
#   'to',
#   'pay',
#   'for',
#   'a',
#   'free',
#   'round',
#   'of',
#   'drinks',
#   'for',
#   'all',
#   'of',
#   'the',
#   '40,000',
#   'crowd',
#   'if',
#   'a',
#   'world',
#   'record',
#   'goes',
#   'at',
#   'the',
#   'meeting',
#   ',',
#   'organisers',
#   'said',
#   'on',
#   'thursday',
#   '.'],
#  ['it',
#   'could',
#   'be',
#   'one',
#   'of',
#   'the',
#   'most',
#   'expensive',
#   'rounds',
#   'of',
#   'drinks',
#   'ever',
#   '.'],
#  ['the', 'meeting', 'is', 'sold', 'out', 'already', '.'],
#  ['two',
#   'world',
#   'records',
#   'are',
#   'in',
#   'serious',
#   'danger',
#   'of',
#   'being',
#   'broken',
#   'at',
#   'the',
#   'meeting',
#   '--',
#   'the',
#   'women',
#   "'s",
#   '1,000',
#   'metres',
#   'and',
#   'the',
#   'men',
#   "'s",
#   '3,000',
#   'metres',
#   '.'],
#  ['-docstart-'],
#  ['golf', '-', 'german', 'open', 'first', 'round', 'scores', '.'],
#  ['stuttgart', ',', 'germany', '1996-08-22'],
#  ['leading', 'first', 'round'],
#  ['scores',
#   'in',
#   'the',
#   'german',
#   'open',
#   'golf',
#   'championship',
#   'on',
#   'thursday',
#   '(',
#   'britain'],
#  ['unless', 'stated', ')', ':'],
#  ['62', 'paul', 'broadhurst'],
#  ['63', 'raymond', 'russell'],
#  ['64',
#   'david',
#   'j.',
#   'russell',
#   ',',
#   'michael',
#   'campbell',
#   '(',
#   'new',
#   'zealand',
#   ')',
#   ',',
#   'ian'],
#  ['woosnam',
#   ',',
#   'bernhard',
#   'langer',
#   '(',
#   'germany',
#   ')',
#   ',',
#   'ronan',
#   'rafferty',
#   ',',
#   'mats'],
#  ['lanner', '(', 'sweden', ')', ',', 'wayne', 'riley', '(', 'australia', ')'],
#  ['65',
#   'eamonn',
#   'darcy',
#   '(',
#   'ireland',
#   ')',
#   ',',
#   'per',
#   'nyman',
#   '(',
#   'sweden',
#   ')',
#   ',',
#   'russell',
#   'claydon',
#   ','],
#  ['mark',
#   'roe',
#   ',',
#   'retief',
#   'goosen',
#   '(',
#   'south',
#   'africa',
#   ')',
#   ',',
#   'carl',
#   'suneson'],
#  ['66',
#   'stephen',
#   'field',
#   ',',
#   'paul',
#   'lawrie',
#   ',',
#   'ian',
#   'pyman',
#   ',',
#   'max',
#   'anglert'],
#  ['(',
#   'sweden',
#   ')',
#   ',',
#   'miles',
#   'tunnicliff',
#   ',',
#   'christian',
#   'cevaer',
#   '(',
#   'france',
#   ')',
#   ','],
#  ['des',
#   'smyth',
#   '(',
#   'ireland',
#   ')',
#   ',',
#   'david',
#   'carter',
#   ',',
#   'lee',
#   'westwood',
#   ',',
#   'greg'],
#  ['chalmers',
#   '(',
#   'australia',
#   ')',
#   ',',
#   'miguel',
#   'angel',
#   'martin',
#   '(',
#   'spain',
#   ')',
#   ','],
#  ['thomas',
#   'bjorn',
#   '(',
#   'denmark',
#   ')',
#   ',',
#   'fernando',
#   'roca',
#   '(',
#   'spain',
#   ')',
#   ',',
#   'derrick'],
#  ['cooper'],
#  ['67',
#   'jeff',
#   'hawksworth',
#   ',',
#   'padraig',
#   'harrington',
#   '(',
#   'ireland',
#   ')',
#   ',',
#   'michael'],
#  ['welch',
#   ',',
#   'thomas',
#   'gogele',
#   '(',
#   'germany',
#   ')',
#   ',',
#   'paul',
#   'mcginley',
#   '(',
#   'ireland',
#   ')',
#   ','],
#  ['gary',
#   'orr',
#   ',',
#   'jose-maria',
#   'canizares',
#   '(',
#   'spain',
#   ')',
#   ',',
#   'michael',
#   'jonzon'],
#  ['(',
#   'sweden',
#   ')',
#   ',',
#   'paul',
#   'eales',
#   ',',
#   'david',
#   'williams',
#   ',',
#   'andrew',
#   'coltart',
#   ','],
#  ['jonathan',
#   'lomas',
#   ',',
#   'jose',
#   'rivero',
#   '(',
#   'spain',
#   ')',
#   ',',
#   'robert',
#   'karlsson'],
#  ['(',
#   'sweden',
#   ')',
#   ',',
#   'marcus',
#   'wills',
#   ',',
#   'pedro',
#   'linhart',
#   '(',
#   'spain',
#   ')',
#   ',',
#   'jamie'],
#  ['spence',
#   ',',
#   'terry',
#   'price',
#   '(',
#   'australia',
#   ')',
#   ',',
#   'juan',
#   'carlos',
#   'pinero',
#   '(',
#   'spain',
#   ')',
#   ','],
#  ['mark', 'mouland'],
#  ['-docstart-'],
#  ['soccer',
#   '-',
#   'uefa',
#   'rewards',
#   'three',
#   'countries',
#   'for',
#   'fair',
#   'play',
#   '.'],
#  ...]

# %%
word_set = set([str(word).lower() for seq in word_collection for word in seq])

# %%
word_set
# Out:
# {'desmond',
#  'encourage',
#  'battlefields',
#  'sairyu',
#  'lme',
#  'tranches',
#  'provides',
#  'ecumenical',
#  'upstairs',
#  'kenyan',
#  'cracking',
#  'maracaibo',
#  'knowledge',
#  'ipswich',
#  '62.65',
#  'hardy',
#  'post-handover',
#  'draws',
#  'kinshasa',
#  'warren',
#  '55-11-2324411',
#  '633.6',
#  'stefko',
#  'plying',
#  'longer',
#  '3/1/90',
#  'reformed',
#  'canada',
#  'lb-2',
#  'rebels',
#  'pothole',
#  'subsequent',
#  '---------------------',
#  'subdue',
#  'ulimo-j',
#  'story',
#  'tissues',
#  '1,123',
#  '7,149',
#  'unhelpful',
#  '9.12',
#  'ringed',
#  'sorensen',
#  'f.h.',
#  'half-century',
#  'mazeikyte',
#  'rig',
#  'tel+44',
#  'sympathy',
#  'source',
#  'kazanjoglus',
#  'belgrade',
#  'irani',
#  'year-olds',
#  'wieczorek',
#  'dmitri',
#  'overshoot',
#  'reprise',
#  'reluctant',
#  'evident',
#  '232',
#  '+11',
#  '3.30',
#  'roadside',
#  'ouedec',
#  'selection',
#  'testud',
#  'matuzici',
#  'democratic',
#  'argyle',
#  'context',
#  'indeed',
#  'heels',
#  '36.242',
#  'bosia-hercegovina',
#  'cjd',
#  'minor',
#  'guerrilla',
#  '28/08',
#  'echoing',
#  'medalist',
#  '406',
#  'alex',
#  'high-performing',
#  'pfeffer',
#  'olo',
#  'levski',
#  'finns',
#  '12.3',
#  'insurers',
#  'liabilities',
#  'jared',
#  'exporting',
#  'mild-mannered',
#  '118',
#  'kukic',
#  'earlier',
#  'knifed',
#  'leasing',
#  '+91-22-265',
#  'railways',
#  'dfl',
#  'cultures',
#  'right',
#  'kalashnikov',
#  'approx',
#  'gratitude',
#  'factors',
#  'tilli',
#  'express',
#  'passat',
#  '51.9',
#  '2.62',
#  'nb-1',
#  'tasmania',
#  'pudong',
#  'balloons',
#  'timisoara',
#  'sailing',
#  'chairman',
#  'tim',
#  'endeavours',
#  'dukla',
#  'jemison',
#  't-bonds',
#  'boland',
#  'motorist',
#  'unspecified',
#  'appeals',
#  'ostensibly',
#  'charles',
#  'seoul',
#  'catania',
#  'study',
#  'bbc',
#  'semi-upright',
#  'larisa',
#  '24,800',
#  '15.3',
#  '4:09.95',
#  '29-8',
#  'newt',
#  'perrin',
#  'gloria',
#  '732.50',
#  'confirming',
#  'remaking',
#  '195',
#  'immunity',
#  '617-367-4106',
#  'above',
#  'neumann',
#  '4yrs',
#  '2011',
#  'payment',
#  'post-election',
#  '2-85',
#  'increasingly',
#  'mideast',
#  'hungary',
#  '4-36',
#  'spoke',
#  'ochieng',
#  'securities',
#  '18,174,000',
#  'unpopular',
#  'all-england',
#  'lancer',
#  '31.44',
#  'arrived',
#  'mar',
#  'guided',
#  '834405',
#  'legislations',
#  '91.37',
#  'hoek',
#  'saddam',
#  'ernst',
#  'schein',
#  'quality',
#  'muratovic',
#  'dubrovshchik',
#  'pass',
#  'same',
#  'nightly',
#  'urgent',
#  'schering',
#  'stationed',
#  'invited',
#  'utility',
#  'miyaga',
#  'help-wanted',
#  'coercive',
#  'calling',
#  'surrendered',
#  '388.75',
#  'domestic',
#  'rustu',
#  '.460',
#  'lawyers',
#  'mnlf',
#  '+8',
#  'trevor',
#  'kwai',
#  'telegraph',
#  'workforce',
#  '9,500',
#  '9.32',
#  'kibet',
#  'stake',
#  'factory',
#  'boonen',
#  'fagan',
#  'eternal',
#  'convenient',
#  'tamer',
#  '8.30',
#  '37.624',
#  'schalke',
#  'jointly',
#  'tobago',
#  'surpass',
#  'driver',
#  'affairs',
#  '1:46',
#  '7.77',
#  'crosson',
#  '23-27',
#  'borrower',
#  'fidelis',
#  'siow',
#  'quitting',
#  '181',
#  '3.85',
#  '202-5',
#  'feasible',
#  'ford',
#  'reperforated',
#  '22.15',
#  'experience',
#  'dearest',
#  'freight-tonne',
#  'knew',
#  'instead',
#  'overhead',
#  '199.71',
#  'stairs',
#  'fis',
#  'josh',
#  'montrose',
#  'kingston',
#  'tampere',
#  'greenock',
#  'fever',
#  'faizy',
#  '8.03',
#  'jeffrey',
#  'tolerated',
#  'wonderful',
#  'milenko',
#  'midrates',
#  'profit',
#  '.453',
#  'no-fly',
#  'terrified',
#  'uyo',
#  'captives',
#  '4.5350',
#  '38:36.306',
#  '82-96f',
#  'navy',
#  'wsrl',
#  'establishes',
#  'lacking',
#  'apartment',
#  '758.75',
#  'hemmings',
#  'serb',
#  '1,200',
#  'testimony',
#  'sharply',
#  'hottest',
#  'hiring',
#  'sorts',
#  'show',
#  'trillion',
#  '5.15',
#  'evil',
#  'drag',
#  'sinead',
#  'magistrate',
#  'displaced',
#  'barjuan',
#  'seaside',
#  'jane',
#  '295',
#  'caufield',
#  'sarka',
#  'home',
#  'uncertainty',
#  '1w',
#  'nice',
#  'babel',
#  'inlaid',
#  'saffet',
#  '3/94',
#  'choices',
#  '30-sept',
#  'right-hander',
#  'assisted',
#  'smit',
#  '257',
#  'scandanavia',
#  'fly-half',
#  'declare',
#  '71',
#  'u.n',
#  'eye',
#  'share',
#  '22.84',
#  'cup',
#  'l-orizzont',
#  'claudio',
#  '25-45',
#  'elsner',
#  '75-100',
#  'dodging',
#  'eat',
#  'year-end',
#  'exeter',
#  'enabled',
#  'blitz',
#  'jeroen',
#  'puk-run',
#  'arce',
#  'dreyfus',
#  'baked',
#  'gaseous',
#  '4-for-5',
#  'words',
#  'no-confidence',
#  'vip',
#  'surged',
#  'edge',
#  'discussed',
#  '30.0',
#  'dist',
#  'verified',
#  'turnhout',
#  '256.9',
#  'fireball',
#  'thinking',
#  'chelny',
#  '0.47',
#  'grzybowska',
#  'obilic',
#  'appellants',
#  '11.27',
#  'smicer',
#  'asylum-seekers',
#  'riots',
#  '4,378',
#  'challenging',
#  'fraternite',
#  '8-1',
#  'decades',
#  'defiant',
#  '12.',
#  'hamas',
#  'barnet',
#  'knife',
#  '175',
#  'indicated',
#  'spruce',
#  'ignore',
#  'stefanovic',
#  'complaint',
#  'togliatti',
#  'cast',
#  'imprisoned',
#  'lufthanseat',
#  '.630',
#  '55th',
#  'irish',
#  'susan',
#  'tossed',
#  'shamay',
#  'inform',
#  'hiv',
#  '135-9',
#  'gift',
#  'franco',
#  'sprints',
#  'third-placed',
#  '56',
#  'sforza',
#  'whistle',
#  'steps',
#  'rebels-interfax',
#  'systematically',
#  'othello',
#  'trained',
#  'threatening',
#  'stick',
#  'damian',
#  '3:53.85',
#  'intention',
#  'musician',
#  'virtually',
#  'rave',
#  'pilots',
#  'improvements',
#  '93.30',
#  'fashion',
#  'hunger',
#  'employee',
#  'song',
#  'fomc',
#  'roughly',
#  'aki',
#  'landed',
#  'interviewer',
#  'succession',
#  'gorgona',
#  'shattering',
#  'isbank',
#  'four-under',
#  'weibring',
#  'gabriel',
#  'penetrating',
#  'cycling',
#  '15-30',
#  'workington',
#  'abbey',
#  'reconvene',
#  '62.50',
#  'chequered',
#  'paralyzed',
#  'model',
#  'simple',
#  'parke',
#  'real',
#  'waiting',
#  'rusedski',
#  'llong',
#  'level',
#  'campana',
#  'unfairness',
#  '0.59',
#  'multico',
#  'reliable',
#  '15.19',
#  'thou',
#  'advocate',
#  'airforce',
#  'panhandle',
#  'anarchy',
#  '1980-88',
#  'f.a.',
#  'eyesight',
#  'consolation',
#  'compensatory',
#  'annabel',
#  '8,000',
#  'white',
#  'a',
#  'puebla',
#  'transcendental',
#  '3,674',
#  'subscription',
#  'dhahran',
#  'unnamed',
#  'protocol',
#  'polyester',
#  'fame',
#  'plotted',
#  'writes',
#  'penrose',
#  'venezuelan',
#  '442,201',
#  '1,113,785',
#  'questioned',
#  'protege',
#  'cantons',
#  'tortelli',
#  '11/01/96',
#  'azerbaijani',
#  'zarins',
#  'canberra',
#  'right-hand',
#  'substantial',
#  'vierklau',
#  'lausgberg',
#  'leeson',
#  'aranyaprathet',
#  '447',
#  'kitigawa',
#  'socha',
#  'gazeta',
#  'mamatuyeva',
#  '37.50',
#  'dan',
#  'toshiba',
#  'debated',
#  'demise',
#  '2:00.91',
#  '18.40',
#  'wives',
#  'assessed',
#  'litmanen',
#  '61.36',
#  'countries',
#  'scandal',
#  'disguise',
#  'spaniard',
#  'shayne',
#  'big-capitalised',
#  'umpires',
#  'notice',
#  'eighth-ranked',
#  'lila',
#  'brew',
#  'nations-sponsored',
#  'three-month',
#  'banco',
#  'distances',
#  'margin',
#  '0.958',
#  '10-game',
#  'mongia',
#  'treating',
#  '1754',
#  'arrange',
#  'dimitrios',
#  'shutters',
#  'w-1',
#  '25-8-61-1',
#  'maintaining',
#  'sympathisers',
#  'boxed',
#  'sabourin',
#  'janeiro',
#  'explosion',
#  'zia',
#  'def',
#  '7',
#  'pines',
#  'par-five',
#  '290.3',
#  'miami',
#  'becanovic',
#  'aa3',
#  'gasoline-to-crude',
#  '1464/96',
#  'jayasuriya',
#  'tunbridge',
#  'thanks',
#  '14,494',
#  'ekeren',
#  'mpumulanga',
#  'legend',
#  'shaughnessy',
#  'showdown',
#  'detectives',
#  'maynard',
#  '206,464',
#  '2.9',
#  'slaps',
#  'railway',
#  '5.75',
#  '1860',
#  'irvine',
#  'infect',
#  'ease',
#  'converted',
#  'wholly',
#  'mary',
#  'kromah',
#  'agassi',
#  'grossard',
#  '40.',
#  'apache',
#  'roberto',
#  '413',
#  '12/01',
#  'repo',
#  'summer',
#  '525',
#  'pecs',
#  'divisions',
#  'portsmouth',
#  'rif',
#  'laborers',
#  '0.6',
#  'tracking',
#  'networks',
#  '32',
#  'wo',
#  'weight',
#  'lubarskij',
#  'technique',
#  'withdrew',
#  'hiddink',
#  '2.07',
#  '21.8',
#  'sprinkling',
#  'shaped',
#  'coloured',
#  'holy',
#  'tiebreaker',
#  'stepping',
#  'eilts',
#  'mechelen',
#  "'d",
#  'healthcare',
#  'mounted',
#  'when',
#  'grown',
#  'third-seeded',
#  '1996-a',
#  'mistakes',
#  'appelmans',
#  'prem',
#  'proponents',
#  'govt.budget',
#  'theron',
#  'lawrence',
#  '7.1875',
#  'closure',
#  '5-3/4',
#  'indicators',
#  'fails',
#  'seared',
#  'citko',
#  'pretoria',
#  'bartha',
#  'sensational',
#  'giuly',
#  'numbers',
#  '7149',
#  'gulbuddin',
#  '10,650,407',
#  'madeleine',
#  'bohemians',
#  'abroad',
#  '5.80',
#  'dogs',
#  '64',
#  'sheepmeat',
#  'short-dated',
#  'dietzsch',
#  'nomura',
#  'homme',
#  'imported',
#  '88-year-old',
#  '1.13',
#  'bedibunder',
#  'durante',
#  'auction',
#  '.406',
#  'leveilly',
#  '12.341',
#  'padres',
#  'citto',
#  'koranic',
#  '6-10',
#  '.533',
#  'overhang',
#  'trafficker',
#  '1:51.857',
#  'deschamps',
#  'ag',
#  'checkfree',
#  'format',
#  '702',
#  '100no',
#  'rapidly',
#  '0.63',
#  'birt',
#  '30m',
#  'wan',
#  'sharpshooter',
#  'half-mast',
#  'slows',
#  'kazakstan',
#  'his',
#  'sir',
#  'deletraz',
#  'ip',
#  'wilson',
#  'hryvna',
#  '10.17',
#  '80-100',
#  'remarkable',
#  'ring',
#  'three-pointer',
#  '14,000',
#  'masayoshi',
#  'pleaded',
#  'guzman',
#  'practical',
#  'constitutes',
#  '0.1',
#  'pierre-henri',
#  'backwardation',
#  'heathrow',
#  'herzliya',
#  'mccall',
#  'norms',
#  'distress',
#  '0-4',
#  'cesena',
#  'ill.-based',
#  'ophran',
#  'tactic',
#  'indies',
#  'serb-held',
#  'towards',
#  'aime',
#  'benedict',
#  'edited',
#  'appearance',
#  '0.28',
#  'catching',
#  'bisconti',
#  'organisation',
#  'partial',
#  'unc',
#  'assemby',
#  'opinion',
#  'ineligible',
#  'embracing',
#  'spell',
#  'ascot',
#  's.b.k-',
#  'dejesus',
#  '11.959',
#  'adler',
#  'three-month-to-three-year',
#  'shen',
#  '09/04/96',
#  'mexicans',
#  '08/26/96',
#  'jone',
#  'attendance',
#  '107.83',
#  'best-selling',
#  'swedish',
#  'sheds',
#  'catalan',
#  'wah',
#  'hmg',
#  'joked',
#  'simex',
#  'zion',
#  '38:19.313',
#  'mositure',
#  'rocks',
#  '4254',
#  'honda',
#  'morariu',
#  'sokol',
#  'qotbuddin',
#  'kdpi',
#  'sks',
#  'advisory',
#  'unitaire',
#  'bat',
#  'intermittent',
#  'kankunnen',
#  'claar',
#  '32.3',
#  'amoco',
#  'bird',
#  'admitted',
#  'definite',
#  'unified',
#  'anita',
#  'ducati',
#  'tonnes',
#  'action',
#  'league-best',
#  'lille',
#  'governor',
#  'eco-terrorism',
#  'writer',
#  'guard',
#  'terrorists',
#  '+41',
#  'beside',
#  '6-',
#  'england',
#  'anymore',
#  '1,279',
#  'stinnes',
#  'xiao',
#  'qualifying',
#  'boje',
#  'bouquets',
#  'heerden',
#  'world-class',
#  'jesus',
#  '1996',
#  'universitatea',
#  '864148',
#  'petrobulk',
#  'co-chairman',
#  '4-35',
#  '4:14.784',
#  'ipo',
#  'recess',
#  'kpaitan',
#  '1350',
#  'kobus',
#  'waalijk',
#  'delay',
#  'coceres',
#  '5.50-6.00',
#  'kareda',
#  'tauranga',
#  '2/9',
#  'low-level',
#  'm.p.h.',
#  'pitting',
#  'luli',
#  'mcmanaman',
#  'rotherham',
#  'frankfurt',
#  'buddy',
#  '3.5',
#  'pursuit',
#  'moosa',
#  'fsu',
#  'manner',
#  'manufacturers',
#  'shabir',
#  'quayle',
#  '6.1',
#  'startups',
#  'mckinley',
#  'ec',
#  'gadoon',
#  'jd',
#  'owns',
#  'outspoken',
#  'bids',
#  'ibrahimi',
#  'sadam',
#  'hernan',
#  'barnes',
#  '158',
#  '1,000',
#  '3921.8',
#  'onic',
#  'discouraged',
#  'springfield',
#  'hamilton',
#  'defer',
#  '212-859-1736',
#  'yuri',
#  'kfar',
#  'downtrodden',
#  'insist',
#  'exempt-rev',
#  '141',
#  '56rd',
#  '15-2',
#  'occupying',
#  'sobering',
#  'saarbruecken',
#  '473-6',
#  'overseas',
#  'lieutenant',
#  'mehemdagic',
#  'ridiculous',
#  '979',
#  'aerostan',
#  '+10.8',
#  'underway',
#  'illawarra',
#  'danish',
#  'stumped',
#  '0.',
#  '7-0-32-0',
#  'introduction',
#  '684',
#  '111.50',
#  'poorest',
#  'inderjit',
#  'annett',
#  'adrift',
#  'hunte',
#  'magistrates',
#  '27-year-old',
#  'isaac',
#  'alina',
#  '236-4',
#  'underpriviledged',
#  'plight',
#  'banc',
#  '12.92',
#  'arrive',
#  'ruined',
#  '2.01',
#  'noticeable',
#  'tartabull',
#  'economy',
#  'topolcany',
#  'ramallah',
#  'diario',
#  '229-1',
#  'kengo',
#  'toenail',
#  'coconut',
#  'frankness',
#  'changing',
#  'ugly',
#  'taxpayer',
#  'vladimir',
#  'become',
#  'york',
#  'indah',
#  '6-0-30-1',
#  'abolished',
#  'narciso',
#  'mid-july',
#  '14,600',
#  '38.08',
#  'hansma',
#  'violating',
#  'immunizes',
#  'flooding',
#  'keyed',
#  'sandberg',
#  'jan-july',
#  'improvement',
#  'h.k.',
#  'stalemate',
#  'kikinda',
#  'region',
#  '5.24',
#  'pedestrian',
#  '15.',
#  '21.0',
#  'sergi',
#  'stg',
#  'doorn',
#  'lean',
#  'nato-led',
#  'harmful',
#  '2,292.9',
#  'threats',
#  '0.23',
#  'marion',
#  'sidestepped',
#  'feinstein',
#  'stoke',
#  'proprietor',
#  'computerised',
#  'breadbasket',
#  'panel',
#  'refuses',
#  'yone',
#  'closes',
#  'major-league',
#  'ceske',
#  'fuels',
#  '1990-95',
#  '273',
#  'office',
#  'looming',
#  'regalia',
#  'reichel',
#  'gdansk',
#  'tyler-sharman',
#  'notionally',
#  'repeat',
#  'chatelet',
#  'importers',
#  'briefing',
#  'interfere',
#  'rescuers',
#  '18-hole',
#  'beauty',
#  'tubes',
#  'acct',
#  'indifference',
#  '1970s',
#  '48',
#  'universities',
#  'jack',
#  'goalkeepers',
#  '0.35',
#  'electric',
#  'cable',
#  'hints',
#  '5.50',
#  'elimination',
#  'no.2',
#  'shell',
#  ...}

# %%
word_vocab = ['<pad>']+['<unk>']+sorted(word_set)

# %%
word_to_index = {word:idx for idx,word in enumerate(word_vocab)}

# %%
len(word_to_index)
# Out:
# 23867

# %%
index_to_word = {idx:word for idx,word in enumerate(word_vocab)}

# %%
index_to_word
# Out:
# {0: '<pad>',
#  1: '<unk>',
#  2: '!',
#  3: '"',
#  4: '$',
#  5: '%',
#  6: '&',
#  7: "'",
#  8: "'d",
#  9: "'ll",
#  10: "'m",
#  11: "'re",
#  12: "'s",
#  13: "'ve",
#  14: '(',
#  15: ')',
#  16: '*',
#  17: '**',
#  18: '**general',
#  19: '*indices',
#  20: '*name',
#  21: '*note',
#  22: '+',
#  23: '++359-2',
#  24: '+0,2',
#  25: '+0.0',
#  26: '+0.05',
#  27: '+0.089',
#  28: '+0.1',
#  29: '+0.2',
#  30: '+0.237',
#  31: '+0.300',
#  32: '+0.435',
#  33: '+0.4m',
#  34: '+0.578',
#  35: '+0.7',
#  36: '+0.9;+23.6',
#  37: '+1',
#  38: '+1,161',
#  39: '+1.0',
#  40: '+1.2',
#  41: '+1.5',
#  42: '+1.660',
#  43: '+1.7;+22.0',
#  44: '+1.9',
#  45: '+10.436',
#  46: '+10.8',
#  47: '+11',
#  48: '+12',
#  49: '+12,696',
#  50: '+15,272',
#  51: '+16',
#  52: '+16.4',
#  53: '+167,330',
#  54: '+168,130',
#  55: '+17',
#  56: '+18.3',
#  57: '+19',
#  58: '+2',
#  59: '+2.3r',
#  60: '+2.6',
#  61: '+20',
#  62: '+22',
#  63: '+225',
#  64: '+230.4',
#  65: '+25',
#  66: '+27',
#  67: '+27-11',
#  68: '+282.1',
#  69: '+3',
#  70: '+3,428',
#  71: '+3,831',
#  72: '+3.06',
#  73: '+3.4',
#  74: '+3.5',
#  75: '+3.6',
#  76: '+3.7',
#  77: '+301',
#  78: '+31',
#  79: '+31,230',
#  80: '+310.4',
#  81: '+33',
#  82: '+331',
#  83: '+34',
#  84: '+353',
#  85: '+358',
#  86: '+361',
#  87: '+381',
#  88: '+387-71-663-864',
#  89: '+4',
#  90: '+4.2r',
#  91: '+4.7',
#  92: '+400.9',
#  93: '+41',
#  94: '+431',
#  95: '+44',
#  96: '+45',
#  97: '+46-8-700',
#  98: '+47',
#  99: '+48',
#  100: '+49',
#  101: '+5',
#  102: '+5.2',
#  103: '+525',
#  104: '+541',
#  105: '+6',
#  106: '+6221',
#  107: '+65',
#  108: '+65-8703086',
#  109: '+6613377',
#  110: '+7',
#  111: '+7.1',
#  112: '+7.3;-3.6',
#  113: '+7095',
#  114: '+8',
#  115: '+9',
#  116: '+9.8',
#  117: '+90-212-275',
#  118: '+91-11-3012024',
#  119: '+91-22-265',
#  120: ',',
#  121: '-',
#  122: '--',
#  123: '---',
#  124: '-----',
#  125: '---------------------',
#  126: '------------------------',
#  127: '-------------------------',
#  128: '--------------------------------',
#  129: '----------------------------------',
#  130: '------------------------------------------------------------',
#  131: '-------------------------------------------------------------',
#  132: '-docstart-',
#  133: '.',
#  134: '..',
#  135: '...',
#  136: '....',
#  137: '...and',
#  138: '...for',
#  139: '...i',
#  140: '.01',
#  141: '.02',
#  142: '.10',
#  143: '.22',
#  144: '.307',
#  145: '.333',
#  146: '.349',
#  147: '.353',
#  148: '.354',
#  149: '.356',
#  150: '.357',
#  151: '.358',
#  152: '.359',
#  153: '.362',
#  154: '.363',
#  155: '.367',
#  156: '.400',
#  157: '.402',
#  158: '.403',
#  159: '.405',
#  160: '.406',
#  161: '.407',
#  162: '.408',
#  163: '.409',
#  164: '.411',
#  165: '.413',
#  166: '.414',
#  167: '.418',
#  168: '.421',
#  169: '.423',
#  170: '.424',
#  171: '.425',
#  172: '.426',
#  173: '.427',
#  174: '.429',
#  175: '.430',
#  176: '.431',
#  177: '.432',
#  178: '.434',
#  179: '.435',
#  180: '.436',
#  181: '.437',
#  182: '.439',
#  183: '.440',
#  184: '.441',
#  185: '.443',
#  186: '.444',
#  187: '.446',
#  188: '.447',
#  189: '.449',
#  190: '.450',
#  191: '.451',
#  192: '.452',
#  193: '.453',
#  194: '.454',
#  195: '.455',
#  196: '.456',
#  197: '.457',
#  198: '.459',
#  199: '.460',
#  200: '.461',
#  201: '.462',
#  202: '.463',
#  203: '.464',
#  204: '.465',
#  205: '.466',
#  206: '.467',
#  207: '.468',
#  208: '.469',
#  209: '.470',
#  210: '.471',
#  211: '.473',
#  212: '.474',
#  213: '.477',
#  214: '.478',
#  215: '.481',
#  216: '.492',
#  217: '.493',
#  218: '.496',
#  219: '.500',
#  220: '.504',
#  221: '.508',
#  222: '.511',
#  223: '.512',
#  224: '.515',
#  225: '.516',
#  226: '.519',
#  227: '.520',
#  228: '.522',
#  229: '.523',
#  230: '.524',
#  231: '.526',
#  232: '.527',
#  233: '.528',
#  234: '.529',
#  235: '.530',
#  236: '.531',
#  237: '.532',
#  238: '.533',
#  239: '.534',
#  240: '.535',
#  241: '.536',
#  242: '.537',
#  243: '.538',
#  244: '.539',
#  245: '.540',
#  246: '.541',
#  247: '.542',
#  248: '.543',
#  249: '.545',
#  250: '.547',
#  251: '.549',
#  252: '.550',
#  253: '.551',
#  254: '.552',
#  255: '.556',
#  256: '.559',
#  257: '.560',
#  258: '.561',
#  259: '.564',
#  260: '.565',
#  261: '.567',
#  262: '.568',
#  263: '.569',
#  264: '.571',
#  265: '.573',
#  266: '.574',
#  267: '.575',
#  268: '.576',
#  269: '.578',
#  270: '.589',
#  271: '.592',
#  272: '.594',
#  273: '.595',
#  274: '.596',
#  275: '.597',
#  276: '.598',
#  277: '.602',
#  278: '.604',
#  279: '.606',
#  280: '.610',
#  281: '.623',
#  282: '.626',
#  283: '.627',
#  284: '.628',
#  285: '.629',
#  286: '.630',
#  287: '.632',
#  288: '.633',
#  289: '.8787',
#  290: '.giuseppe',
#  291: '.robbie',
#  292: '/',
#  293: '0',
#  294: '0*',
#  295: '0-0',
#  296: '0-1',
#  297: '0-2',
#  298: '0-4',
#  299: '0-50',
#  300: '0-6',
#  301: '0.',
#  302: '0.004',
#  303: '0.005',
#  304: '0.01',
#  305: '0.02',
#  306: '0.03',
#  307: '0.04',
#  308: '0.042',
#  309: '0.05',
#  310: '0.056',
#  311: '0.07',
#  312: '0.08',
#  313: '0.0817',
#  314: '0.0822',
#  315: '0.1',
#  316: '0.10',
#  317: '0.100',
#  318: '0.12',
#  319: '0.13',
#  320: '0.14',
#  321: '0.15',
#  322: '0.17',
#  323: '0.19',
#  324: '0.2',
#  325: '0.20',
#  326: '0.20-0.70',
#  327: '0.200',
#  328: '0.21',
#  329: '0.22',
#  330: '0.23',
#  331: '0.25',
#  332: '0.25-1.00',
#  333: '0.25-1.30',
#  334: '0.26',
#  335: '0.27',
#  336: '0.275',
#  337: '0.28',
#  338: '0.3',
#  339: '0.30',
#  340: '0.300',
#  341: '0.31',
#  342: '0.33',
#  343: '0.34',
#  344: '0.35',
#  345: '0.355',
#  346: '0.36',
#  347: '0.37',
#  348: '0.375',
#  349: '0.38',
#  350: '0.39',
#  351: '0.4',
#  352: '0.4-0-9-0',
#  353: '0.40',
#  354: '0.41',
#  355: '0.42',
#  356: '0.43',
#  357: '0.44',
#  358: '0.445',
#  359: '0.45',
#  360: '0.46',
#  361: '0.47',
#  362: '0.48',
#  363: '0.5',
#  364: '0.50',
#  365: '0.53',
#  366: '0.55',
#  367: '0.59',
#  368: '0.6',
#  369: '0.60',
#  370: '0.629',
#  371: '0.63',
#  372: '0.65',
#  373: '0.68',
#  374: '0.69',
#  375: '0.7',
#  376: '0.70',
#  377: '0.73',
#  378: '0.75',
#  379: '0.76',
#  380: '0.79',
#  381: '0.8',
#  382: '0.81',
#  383: '0.85',
#  384: '0.8584',
#  385: '0.86',
#  386: '0.87',
#  387: '0.9',
#  388: '0.94',
#  389: '0.95',
#  390: '0.958',
#  391: '0.96',
#  392: '0.966',
#  393: '0.98',
#  394: '00--44-171-542-7947',
#  395: '00.42',
#  396: '000',
#  397: '000s',
#  398: '0025',
#  399: '003',
#  400: '0050',
#  401: '01.77',
#  402: '0100',
#  403: '0120',
#  404: '0172',
#  405: '02.777',
#  406: '02.sep.96-06.mar.97',
#  407: '02.sep.96-21.nov.97',
#  408: '02/09',
#  409: '020-504-5040',
#  410: '03.684',
#  411: '03/09',
#  412: '0300',
#  413: '0330',
#  414: '04',
#  415: '04.95',
#  416: '04/06/96',
#  417: '0400',
#  418: '05/01/97',
#  419: '05/09',
#  420: '0515',
#  421: '05:30',
#  422: '05:53',
#  423: '06',
#  424: '06/01',
#  425: '0645',
#  426: '07.00',
#  427: '072261',
#  428: '08/21/96',
#  429: '08/23/96',
#  430: '08/26/96',
#  431: '08/27/96',
#  432: '08/28/96',
#  433: '08/29/1996',
#  434: '0800',
#  435: '0815',
#  436: '0875',
#  437: '09/01/96',
#  438: '09/04/96',
#  439: '09/05/1996',
#  440: '09/05/96',
#  441: '0900',
#  442: '0915',
#  443: '0:04',
#  444: '0:06',
#  445: '0:07',
#  446: '0:08',
#  447: '0:09',
#  448: '0:10',
#  449: '1',
#  450: '1)266',
#  451: '1,000',
#  452: '1,002',
#  453: '1,003',
#  454: '1,037',
#  455: '1,041',
#  456: '1,044',
#  457: '1,071',
#  458: '1,074',
#  459: '1,086',
#  460: '1,100',
#  461: '1,100.7',
#  462: '1,113,785',
#  463: '1,119.0',
#  464: '1,123',
#  465: '1,130',
#  466: '1,141.50',
#  467: '1,143',
#  468: '1,154',
#  469: '1,156.79',
#  470: '1,164.1',
#  471: '1,184.0',
#  472: '1,185',
#  473: '1,190',
#  474: '1,196',
#  475: '1,196.35',
#  476: '1,200',
#  477: '1,200,000',
#  478: '1,236.5',
#  479: '1,242.9',
#  480: '1,279',
#  481: '1,294.5',
#  482: '1,305',
#  483: '1,315.7',
#  484: '1,328',
#  485: '1,334.0',
#  486: '1,380',
#  487: '1,400',
#  488: '1,420.9',
#  489: '1,421.90',
#  490: '1,429',
#  491: '1,433.4',
#  492: '1,445',
#  493: '1,452-km',
#  494: '1,453',
#  495: '1,456.7',
#  496: '1,461',
#  497: '1,466.1',
#  498: '1,500',
#  499: '1,523',
#  500: '1,558',
#  501: '1,574,799',
#  502: '1,600',
#  503: '1,617',
#  504: '1,627',
#  505: '1,650',
#  506: '1,683',
#  507: '1,700',
#  508: '1,700-hectare',
#  509: '1,750-hectare',
#  510: '1,800',
#  511: '1,803',
#  512: '1,806',
#  513: '1,820,000',
#  514: '1,850-1,900',
#  515: '1,874-of-3,362',
#  516: '1,897.85',
#  517: '1,900',
#  518: '1,940',
#  519: '1,967',
#  520: '1-',
#  521: '1-0',
#  522: '1-1',
#  523: '1-1/2',
#  524: '1-1/3',
#  525: '1-1/4',
#  526: '1-10-100',
#  527: '1-103',
#  528: '1-106',
#  529: '1-129',
#  530: '1-15',
#  531: '1-16',
#  532: '1-2',
#  533: '1-21',
#  534: '1-22',
#  535: '1-3',
#  536: '1-3/4',
#  537: '1-4',
#  538: '1-48',
#  539: '1-5',
#  540: '1-57',
#  541: '1-6',
#  542: '1-64',
#  543: '1-7',
#  544: '1-82',
#  545: '1-96',
#  546: '1-for-2',
#  547: '1-mth',
#  548: '1.',
#  549: '1.0',
#  550: '1.00',
#  551: '1.000',
#  552: '1.02',
#  553: '1.03',
#  554: '1.05',
#  555: '1.069',
#  556: '1.07',
#  557: '1.09',
#  558: '1.1',
#  559: '1.10',
#  560: '1.12',
#  561: '1.126',
#  562: '1.13',
#  563: '1.15',
#  564: '1.16',
#  565: '1.1875',
#  566: '1.19',
#  567: '1.2',
#  568: '1.20',
#  569: '1.206',
#  570: '1.209',
#  571: '1.210',
#  572: '1.210-1.236',
#  573: '1.215',
#  574: '1.24',
#  575: '1.26',
#  576: '1.3',
#  577: '1.30',
#  578: '1.33',
#  579: '1.343',
#  580: '1.3438',
#  581: '1.35',
#  582: '1.38',
#  583: '1.39',
#  584: '1.4',
#  585: '1.43',
#  586: '1.45',
#  587: '1.4765',
#  588: '1.4767',
#  589: '1.4772',
#  590: '1.4779',
#  591: '1.4788',
#  592: '1.4789',
#  593: '1.48',
#  594: '1.4871',
#  595: '1.4935',
#  596: '1.5',
#  597: '1.50',
#  598: '1.54',
#  599: '1.5497',
#  600: '1.55',
#  601: '1.5520',
#  602: '1.56',
#  603: '1.59',
#  604: '1.6',
#  605: '1.60',
#  606: '1.62',
#  607: '1.63',
#  608: '1.64',
#  609: '1.66',
#  610: '1.7',
#  611: '1.70',
#  612: '1.75',
#  613: '1.8',
#  614: '1.80',
#  615: '1.82',
#  616: '1.84',
#  617: '1.85',
#  618: '1.875',
#  619: '1.88',
#  620: '1.9',
#  621: '1.90',
#  622: '1.91',
#  623: '1.92',
#  624: '1.94',
#  625: '1.96',
#  626: '1.97',
#  627: '1/16',
#  628: '1/2',
#  629: '1/3',
#  630: '1/32',
#  631: '1/8',
#  632: '1/9',
#  633: '1/9/95',
#  634: '10',
#  635: '10,000',
#  636: '10,000-seat',
#  637: '10,056.4',
#  638: '10,119,000',
#  639: '10,204.87',
#  640: '10,300',
#  641: '10,650,407',
#  642: '10,655',
#  643: '10,663',
#  644: '10,725',
#  645: '10,756',
#  646: '10,760',
#  647: '10,880,000',
#  648: '10,896',
#  649: '10,925',
#  650: '10-0',
#  651: '10-0-33-2',
#  652: '10-0-38-3',
#  653: '10-0-41-2',
#  654: '10-0-42-0',
#  655: '10-0-43-2',
#  656: '10-0-44-1',
#  657: '10-0-50-0',
#  658: '10-0-52-0',
#  659: '10-0-53-3',
#  660: '10-0-56-1',
#  661: '10-0-59-1',
#  662: '10-1',
#  663: '10-1-36-2',
#  664: '10-1-39-1',
#  665: '10-1-40-0',
#  666: '10-1-47-2',
#  667: '10-1-50-1',
#  668: '10-1-54-0',
#  669: '10-12',
#  670: '10-15',
#  671: '10-2',
#  672: '10-2-51-0',
#  673: '10-20',
#  674: '10-23',
#  675: '10-3',
#  676: '10-3-30-0',
#  677: '10-3-31-1',
#  678: '10-3/8',
#  679: '10-30',
#  680: '10-4',
#  681: '10-5',
#  682: '10-7',
#  683: '10-8',
#  684: '10-day',
#  685: '10-game',
#  686: '10-man',
#  687: '10-metre',
#  688: '10-round',
#  689: '10-session',
#  690: '10-week',
#  691: '10-year',
#  692: '10-year-old',
#  693: '10.',
#  694: '10.0',
#  695: '10.00',
#  696: '10.01',
#  697: '10.02',
#  698: '10.03',
#  699: '10.06',
#  700: '10.08',
#  701: '10.09',
#  702: '10.10',
#  703: '10.11',
#  704: '10.12',
#  705: '10.13',
#  706: '10.14',
#  707: '10.15',
#  708: '10.16',
#  709: '10.17',
#  710: '10.18',
#  711: '10.19',
#  712: '10.22',
#  713: '10.24',
#  714: '10.28',
#  715: '10.29',
#  716: '10.3',
#  717: '10.30',
#  718: '10.33',
#  719: '10.43',
#  720: '10.45',
#  721: '10.48',
#  722: '10.5',
#  723: '10.5-42.3',
#  724: '10.57:33',
#  725: '10.6',
#  726: '10.75',
#  727: '10.8',
#  728: '10.84',
#  729: '10.89',
#  730: '10.9',
#  731: '10.94',
#  732: '10.95',
#  733: '10.982',
#  734: '10/01',
#  735: '10/32',
#  736: '100',
#  737: '100,000',
#  738: '100,600',
#  739: '100-2',
#  740: '100-30',
#  741: '100-5',
#  742: '100.6',
#  743: '100.92',
#  744: '1000',
#  745: '1000.0',
#  746: '1003',
#  747: '1006',
#  748: '1009',
#  749: '100=1990',
#  750: '100=1992',
#  751: '100m',
#  752: '100no',
#  753: '101',
#  754: '101-member',
#  755: '101-strong',
#  756: '101.15',
#  757: '101.40',
#  758: '101.80',
#  759: '1017',
#  760: '102',
#  761: '102-0',
#  762: '1021',
#  763: '103',
#  764: '103-95',
#  765: '1036.575',
#  766: '104.625',
#  767: '1045.56',
#  768: '104th-ranked',
#  769: '105',
#  770: '105,000',
#  771: '105-17/32',
#  772: '105-4',
#  773: '105.07',
#  774: '106',
#  775: '106-25/32',
#  776: '106-26/32',
#  777: '106.375',
#  778: '106.5',
#  779: '106.53',
#  780: '1060.00',
#  781: '107',
#  782: '107-06',
#  783: '107-06/32',
#  784: '107-10',
#  785: '107-11/32',
#  786: '107-12',
#  787: '107-2/32',
#  788: '107.0',
#  789: '107.24',
#  790: '107.55',
#  791: '107.74',
#  792: '107.78',
#  793: '107.83',
#  794: '10700',
#  795: '10752.092',
#  796: '10772',
#  797: '108',
#  798: '108,000',
#  799: '108,288',
#  800: '108-3',
#  801: '108.4**',
#  802: '108.40',
#  803: '108.43',
#  804: '108.45',
#  805: '108.50',
#  806: '108.9',
#  807: '109',
#  808: '109-5',
#  809: '109.36',
#  810: '109.4',
#  811: '109.45',
#  812: '10no',
#  813: '10th',
#  814: '10th-ranked',
#  815: '11',
#  816: '11,000',
#  817: '11,046,000',
#  818: '11,175,000',
#  819: '11,244',
#  820: '11,346,000',
#  821: '11,424.64',
#  822: '11,450',
#  823: '11,500',
#  824: '11,525',
#  825: '11,594.99',
#  826: '11,900-12,100',
#  827: '11-',
#  828: '11-1',
#  829: '11-13',
#  830: '11-15',
#  831: '11-2',
#  832: '11-25',
#  833: '11-3',
#  834: '11-3/8',
#  835: '11-4',
#  836: '11-6',
#  837: '11-7',
#  838: '11-8',
#  839: '11-9',
#  840: '11-game',
#  841: '11-year',
#  842: '11-year-old',
#  843: '11.',
#  844: '11.0',
#  845: '11.00',
#  846: '11.04',
#  847: '11.07',
#  848: '11.09',
#  849: '11.12',
#  850: '11.14',
#  851: '11.16',
#  852: '11.18',
#  853: '11.2',
#  854: '11.20',
#  855: '11.20:33',
#  856: '11.25',
#  857: '11.26',
#  858: '11.27',
#  859: '11.28',
#  860: '11.3',
#  861: '11.31',
#  862: '11.34',
#  863: '11.37',
#  864: '11.38',
#  865: '11.4',
#  866: '11.45',
#  867: '11.53',
#  868: '11.55',
#  869: '11.60',
#  870: '11.61',
#  871: '11.7',
#  872: '11.776',
#  873: '11.8',
#  874: '11.833',
#  875: '11.900',
#  876: '11.959',
#  877: '11/01/96',
#  878: '11/1/05',
#  879: '11/1/07',
#  880: '11/1/96-11',
#  881: '110',
#  882: '110,000',
#  883: '110-seat',
#  884: '110.4',
#  885: '110.50',
#  886: '1100',
#  887: '110th',
#  888: '111',
#  889: '111-20/32',
#  890: '111.2',
#  891: '111.50',
#  892: '112',
#  893: '112,200',
#  894: '112.0-149.0',
#  895: '112.1-113.4',
#  896: '112.56',
#  897: '112.8',
#  898: '112th-ranked',
#  899: '113',
#  900: '113.0',
#  901: '113.00',
#  902: '113.02',
#  903: '113.576',
#  904: '1130',
#  905: '11361.330',
#  906: '114',
#  907: '115',
#  908: '115,000',
#  909: '115,941',
#  910: '115.1',
#  911: '115.259',
#  912: '115.32',
#  913: '115.45',
#  914: '115.58',
#  915: '115.62',
#  916: '116',
#  917: '116th',
#  918: '117',
#  919: '117.00',
#  920: '117.9',
#  921: '118',
#  922: '118.8',
#  923: '119',
#  924: '119.3',
#  925: '119.3**',
#  926: '119.49',
#  927: '119.6',
#  928: '119.6**',
#  929: '11th',
#  930: '11th-ranked',
#  931: '11th-seeded',
#  932: '12',
#  933: '12,000',
#  934: '12,201.09',
#  935: '12,300',
#  936: '12,350',
#  937: '12,600-12,750',
#  938: '12,700-12,800',
#  939: '12,700-12,850',
#  940: '12,700-12,900',
#  941: '12,700-12,950',
#  942: '12,750-12,850',
#  943: '12,750-12,900',
#  944: '12,750-12,950',
#  945: '12,800-13,000',
#  946: '12,850-13,050',
#  947: '12,855.7',
#  948: '12,900-13,100',
#  949: '12,900-13,150',
#  950: '12,940',
#  951: '12-1',
#  952: '12-1-41-1',
#  953: '12-1-76-0',
#  954: '12-11',
#  955: '12-12',
#  956: '12-15',
#  957: '12-17',
#  958: '12-2',
#  959: '12-3',
#  960: '12-6',
#  961: '12-7',
#  962: '12-8',
#  963: '12-footer',
#  964: '12-month',
#  965: '12-mth',
#  966: '12-week',
#  967: '12-year',
#  968: '12-year-old',
#  969: '12.',
#  970: '12.0',
#  971: '12.033',
#  972: '12.08',
#  973: '12.10',
#  974: '12.112',
#  975: '12.124',
#  976: '12.130',
#  977: '12.177).',
#  978: '12.19',
#  979: '12.2',
#  980: '12.208',
#  981: '12.211',
#  982: '12.225',
#  983: '12.246',
#  984: '12.3',
#  985: '12.341',
#  986: '12.348',
#  987: '12.4.1996',
#  988: '12.434',
#  989: '12.442',
#  990: '12.5',
#  991: '12.50',
#  992: '12.56',
#  993: '12.60',
#  994: '12.63',
#  995: '12.70',
#  996: '12.71',
#  997: '12.74',
#  998: '12.77',
#  999: '12.83',
#  ...}

# %%
glove = np.zeros((23867,100))

# %%
for i in index_to_word.keys():
    target_word = index_to_word[i]
    if target_word in glove_vocab:
        glove[i] = glove_vocab[target_word]

# %%
tag_set =set([str(tag)for sentence in train_tag for tag in sentence])
tag_vocab = ['<pad>'] + sorted(tag_set) 
tag_to_index = {tag:idx for idx,tag in enumerate(tag_vocab)}
index_to_tag = {idx:tag for idx,tag in enumerate(tag_vocab)}

# %%
def indexical_sentence_word(sentence,word_to_index):
    w=[]
    for word in sentence:
        if word in word_to_index:
            w.append(word_to_index[word])
        else:
            w.append(word_to_index['<unk>'])
    #w_tensor = torch.Tensor(w)
    return w

# %%
def indexical_sentence_tag(sentence,tag_to_index):
    t = []
    for tag in sentence:
        t.append(tag_to_index[tag])
    #t_tensor = torch.Tensor(t)
    return t

# %%
def indexical_x_y(all_data_list):
    indexical_x_train = []
    indexical_y_train = []
    for item in all_data_list:
        words,tags = item[0],item[1]
        seq_tensor = indexical_sentence_word(words,word_to_index)
        tags_tensor = indexical_sentence_tag(tags,tag_to_index)
        indexical_x_train.append(seq_tensor)
        indexical_y_train.append(tags_tensor)
    return indexical_x_train,indexical_y_train

# %%
all_data_list = list(zip(train_word, train_tag ))
indexical_x_train, indexical_y_train = indexical_x_y(all_data_list)

# %%
indexical_x_train
# Out:
# [[10093, 18686, 11326, 6968, 22002, 6605, 6724, 13968, 133],
#  [17245, 6321],
#  [6779, 1633],
#  [21781,
#   10109,
#   7839,
#   19443,
#   16533,
#   21915,
#   13139,
#   9138,
#   23493,
#   11326,
#   4749,
#   22002,
#   8104,
#   22002,
#   20191,
#   6724,
#   13968,
#   22656,
#   19663,
#   9006,
#   23361,
#   14695,
#   8329,
#   9182,
#   7015,
#   6033,
#   22193,
#   22002,
#   20066,
#   133],
#  [11332,
#   12,
#   18813,
#   22002,
#   21781,
#   10109,
#   22591,
#   12,
#   22888,
#   7847,
#   23323,
#   23861,
#   19443,
#   16533,
#   23268,
#   8104,
#   20157,
#   6902,
#   20067,
#   11088,
#   8295,
#   16693,
#   21773,
#   6723,
#   22656,
#   21781,
#   19661,
#   4749,
#   23194,
#   7613,
#   133],
#  [3,
#   23237,
#   9316,
#   15804,
#   21296,
#   5274,
#   21198,
#   18529,
#   6054,
#   23237,
#   9316,
#   15804,
#   19782,
#   5274,
#   11652,
#   10881,
#   13139,
#   120,
#   3,
#   21781,
#   7839,
#   12,
#   7448,
#   20727,
#   16115,
#   22789,
#   8928,
#   17004,
#   22019,
#   4476,
#   16056,
#   6704,
#   133],
#  [12002,
#   19443,
#   11156,
#   19661,
#   21125,
#   23194,
#   18842,
#   5155,
#   12558,
#   13139,
#   23194,
#   10958,
#   21778,
#   4657,
#   23194,
#   15966,
#   13139,
#   20157,
#   6033,
#   21506,
#   6912,
#   21781,
#   10109,
#   22591,
#   133],
#  [12002,
#   19443,
#   4476,
#   17986,
#   14047,
#   15561,
#   6912,
#   10093,
#   10441,
#   7840,
#   11022,
#   10725,
#   22002,
#   5852,
#   20066,
#   6631,
#   120,
#   20714,
#   5155,
#   20698,
#   8220,
#   11088,
#   21781,
#   12447,
#   5155,
#   5197,
#   10864,
#   7296,
#   23194,
#   4476,
#   12196,
#   20668,
#   5155,
#   17715,
#   15669,
#   22002,
#   18011,
#   12447,
#   12021,
#   133],
#  [10725,
#   17989,
#   10094,
#   15123,
#   4792,
#   18808,
#   11088,
#   6723,
#   5155,
#   10997,
#   21778,
#   22508,
#   13934,
#   7981,
#   20066,
#   8280,
#   8147,
#   6586,
#   20730,
#   9874,
#   14,
#   6786,
#   15,
#   122,
#   14695,
#   8329,
#   9182,
#   133],
#  [6896,
#   10725,
#   4828,
#   22002,
#   18979,
#   12243,
#   17986,
#   4792,
#   21781,
#   10093,
#   12,
#   20840,
#   22888,
#   7847,
#   120,
#   15020,
#   5197,
#   12021,
#   16457,
#   120,
#   18218,
#   12558,
#   21198,
#   4657,
#   23194,
#   13475,
#   5480,
#   21797,
#   23194,
#   16568,
#   4476,
#   20401,
#   19109,
#   22002,
#   12447,
#   12021,
#   133],
#  [20638,
#   10441,
#   15377,
#   14590,
#   8673,
#   16874,
#   11790,
#   9617,
#   4627,
#   10725,
#   5565,
#   5135,
#   10093,
#   10441,
#   15379,
#   7,
#   15161,
#   16429,
#   7196,
#   22610,
#   4933,
#   21898,
#   3,
#   8602,
#   11290,
#   133,
#   3],
#  [133],
#  [16568, 10997, 5155, 6723, 5762, 10725, 12, 17986, 133],
#  [21781,
#   10093,
#   12,
#   19661,
#   22888,
#   5155,
#   15733,
#   7848,
#   5381,
#   9534,
#   22002,
#   18440,
#   21781,
#   13132,
#   9619,
#   16068,
#   15561,
#   5155,
#   14760,
#   18530,
#   22002,
#   21781,
#   19865,
#   22888,
#   16457,
#   133],
#  [20066,
#   11991,
#   14497,
#   6072,
#   13777,
#   22002,
#   8147,
#   19692,
#   120,
#   4476,
#   6630,
#   9182,
#   20265,
#   22002,
#   6786,
#   23362,
#   13102,
#   6119,
#   22002,
#   11991,
#   6072,
#   22178,
#   22002,
#   7187,
#   21898,
#   10525,
#   8116,
#   5197,
#   23201,
#   133],
#  [6724,
#   10443,
#   8874,
#   16533,
#   21915,
#   21797,
#   23194,
#   5274,
#   8601,
#   22002,
#   12447,
#   12021,
#   11088,
#   21785,
#   20066,
#   120,
#   6896,
#   10293,
#   7957,
#   21778,
#   11326,
#   11524,
#   4749,
#   22002,
#   8104,
#   22002,
#   5695,
#   6724,
#   13968,
#   15309,
#   12822,
#   8104,
#   4654,
#   10108,
#   133],
#  [3,
#   23345,
#   23237,
#   11991,
#   22002,
#   6033,
#   10327,
#   7098,
#   16429,
#   13102,
#   12410,
#   16693,
#   8295,
#   5381,
#   11462,
#   22002,
#   21502,
#   11332,
#   12,
#   14124,
#   120,
#   3,
#   23310,
#   15893,
#   10443,
#   7,
#   22591,
#   14,
#   16071,
#   15,
#   7298,
#   13362,
#   14442,
#   13390,
#   19443,
#   16533,
#   6027,
#   18271,
#   133],
#  [6485,
#   11970,
#   14163,
#   9714,
#   22002,
#   18011,
#   18071,
#   12021,
#   4792,
#   8103,
#   7998,
#   7745,
#   12674,
#   14875,
#   4792,
#   4476,
#   6724,
#   18802,
#   21221,
#   12450,
#   8280,
#   8147,
#   5135,
#   12594,
#   20265,
#   22002,
#   14695,
#   8329,
#   9182,
#   6912,
#   9642,
#   8119,
#   6070,
#   133],
#  [11332,
#   12647,
#   3186,
#   20066,
#   11088,
#   6723,
#   14047,
#   23669,
#   120,
#   15952,
#   11823,
#   16429,
#   22092,
#   12650,
#   133],
#  [13139,
#   6758,
#   12674,
#   2921,
#   22049,
#   16429,
#   6724,
#   15788,
#   120,
#   20556,
#   634,
#   17167,
#   16429,
#   16758,
#   12650,
#   133],
#  [132],
#  [18388, 12114, 20568, 9432, 19839, 10881, 5041, 4, 1374, 133],
#  [14492, 1633],
#  [4476,
#   18388,
#   9619,
#   11881,
#   9432,
#   16429,
#   4476,
#   20568,
#   6912,
#   22428,
#   11719,
#   14187,
#   13337,
#   12114,
#   23194,
#   20529,
#   10881,
#   5041,
#   4,
#   1374,
#   16533,
#   21915,
#   5565,
#   5135,
#   5629,
#   16429,
#   20556,
#   16429,
#   21781,
#   14055,
#   15775,
#   12,
#   10492,
#   17610,
#   133],
#  [4476,
#   10817,
#   18900,
#   16860,
#   649,
#   17658,
#   14,
#   4,
#   1304,
#   15,
#   10881,
#   21781,
#   9432,
#   16429,
#   3,
#   4848,
#   15804,
#   16150,
#   21691,
#   3,
#   120,
#   23362,
#   12114,
#   17151,
#   16533,
#   4476,
#   17335,
#   16429,
#   14492,
#   12386,
#   20884,
#   12674,
#   14055,
#   1577,
#   133],
#  [5565,
#   21781,
#   9884,
#   16429,
#   4476,
#   13236,
#   1579,
#   7961,
#   12674,
#   21781,
#   9929,
#   7560,
#   16429,
#   16276,
#   12002,
#   21891,
#   21781,
#   20068,
#   16429,
#   16915,
#   13011,
#   21781,
#   5634,
#   120,
#   23357,
#   13139,
#   23194,
#   18951,
#   6912,
#   4476,
#   10427,
#   133],
#  [6906,
#   5056,
#   20469,
#   22667,
#   1299,
#   16693,
#   13148,
#   21778,
#   23322,
#   18147,
#   22667,
#   10881,
#   5629,
#   6912,
#   12114,
#   12,
#   10927,
#   11390,
#   13574,
#   10082,
#   120,
#   23382,
#   14423,
#   23493,
#   12213,
#   11088,
#   1577,
#   22002,
#   1581,
#   133],
#  [21804,
#   12709,
#   4476,
#   6320,
#   13949,
#   5155,
#   15627,
#   16429,
#   17099,
#   12873,
#   6596,
#   22722,
#   6912,
#   12114,
#   22002,
#   21004,
#   12243,
#   9507,
#   120,
#   23362,
#   5135,
#   5233,
#   5649,
#   18123,
#   6563,
#   10881,
#   3312,
#   17658,
#   14,
#   4,
#   3885,
#   15,
#   133],
#  [21781, 11720, 9067, 16429, 4476, 9507, 16765, 12674, 1583, 4804, 2274, 133],
#  [132],
#  [7468, 19585, 21497, 20723, 5585, 10881, 21526, 133],
#  [6094, 1633],
#  [7468,
#   16533,
#   21915,
#   4627,
#   21496,
#   16429,
#   20722,
#   21781,
#   5585,
#   10881,
#   4476,
#   18924,
#   16429,
#   21526,
#   4654,
#   21781,
#   21497,
#   21028,
#   23493,
#   4476,
#   22993,
#   22002,
#   22454,
#   6912,
#   21498,
#   22902,
#   17781,
#   14309,
#   7318,
#   21836,
#   23269,
#   21778,
#   12836,
#   6094,
#   133],
#  [20657,
#   16568,
#   12394,
#   4792,
#   7471,
#   20869,
#   15138,
#   19443,
#   21781,
#   21962,
#   23194,
#   19064,
#   22002,
#   9917,
#   12674,
#   17533,
#   21526,
#   23493,
#   21497,
#   120,
#   10901,
#   15381,
#   20727,
#   20084,
#   11749,
#   22019,
#   18961,
#   4466,
#   3,
#   21781,
#   15959,
#   5585,
#   10881,
#   21781,
#   16580,
#   16429,
#   21781,
#   21526,
#   11970,
#   6072,
#   9234,
#   6912,
#   21781,
#   21497,
#   5658,
#   133,
#   3],
#  [20869,
#   15138,
#   18244,
#   7468,
#   12,
#   22057,
#   15981,
#   23493,
#   21496,
#   120,
#   21547,
#   20185,
#   120,
#   5480,
#   21691,
#   4476,
#   22995,
#   11653,
#   11088,
#   21497,
#   16533,
#   23268,
#   21778,
#   13139,
#   23194,
#   21962,
#   10881,
#   21781,
#   19118,
#   22002,
#   12290,
#   17533,
#   21526,
#   133],
#  [3,
#   16295,
#   13102,
#   21781,
#   21962,
#   10881,
#   21781,
#   22382,
#   20211,
#   22002,
#   9917,
#   12674,
#   17533,
#   21526,
#   135],
#  [21778,
#   13102,
#   22002,
#   9884,
#   21781,
#   20869,
#   16429,
#   12380,
#   120,
#   3,
#   21915,
#   12,
#   16786,
#   9684,
#   16429,
#   21781,
#   17163,
#   12,
#   8570,
#   18244,
#   21547,
#   5480,
#   19584,
#   133],
#  [21781,
#   10901,
#   15381,
#   12,
#   20084,
#   22019,
#   18961,
#   21685,
#   12674,
#   5135,
#   13001,
#   12002,
#   11790,
#   18453,
#   18808,
#   16429,
#   21547,
#   12,
#   7836,
#   6896,
#   11261,
#   16150,
#   8988,
#   16429,
#   23393,
#   21781,
#   15981,
#   11790,
#   8056,
#   21781,
#   21962,
#   19064,
#   10881,
#   21526,
#   23493,
#   21497,
#   120,
#   23362,
#   6094,
#   8058,
#   4476,
#   18749,
#   18040,
#   133],
#  [7468,
#   120,
#   23362,
#   11970,
#   14497,
#   16603,
#   4998,
#   21496,
#   9714,
#   22002,
#   11181,
#   11594,
#   12979,
#   18524,
#   120,
#   23194,
#   12836,
#   6912,
#   4476,
#   22993,
#   22002,
#   22454,
#   21836,
#   23269,
#   6912,
#   21498,
#   22902,
#   17781,
#   14309,
#   133],
#  [132],
#  [7468, 19585, 21962, 19064, 10881, 21497, 21526, 133],
#  [6094, 1633],
#  [7468,
#   11970,
#   19443,
#   13139,
#   23194,
#   21962,
#   10881,
#   17533,
#   21526,
#   23493,
#   21497,
#   5155,
#   21778,
#   21781,
#   19117,
#   13116,
#   20157,
#   21502,
#   17675,
#   20946,
#   22120,
#   21778,
#   11442,
#   133],
#  [8099,
#   20157,
#   6033,
#   12086,
#   22002,
#   19939,
#   21781,
#   21962,
#   5155,
#   10924,
#   16429,
#   21781,
#   21526,
#   120,
#   21781,
#   16455,
#   23643,
#   16056,
#   4806,
#   18244,
#   21547,
#   20185,
#   120,
#   10204,
#   22902,
#   7298,
#   16429,
#   21781,
#   5543,
#   10881,
#   18692,
#   4654,
#   21781,
#   21497,
#   21029,
#   120,
#   5480,
#   19584,
#   14055,
#   16533,
#   23268,
#   133],
#  [132],
#  [11326, 13450, 7081, 18650, 22667, 1171, 17086, 23737, 292, 23737, 133],
#  [11015, 1633],
#  [11326,
#   10719,
#   18650,
#   16429,
#   15637,
#   22834,
#   13457,
#   1171,
#   17167,
#   12674,
#   13450,
#   21836,
#   23669,
#   11088,
#   21781,
#   23671,
#   17190,
#   120,
#   21781,
#   10518,
#   16451,
#   10881,
#   15637,
#   22834,
#   19443,
#   16533,
#   21915,
#   133],
#  [21781,
#   16451,
#   19443,
#   2727,
#   16033,
#   7140,
#   23322,
#   18647,
#   12674,
#   13450,
#   1630,
#   122,
#   2584,
#   17013,
#   7140,
#   5155,
#   1220,
#   22305,
#   133],
#  [21781,
#   10634,
#   18812,
#   4476,
#   1091,
#   17167,
#   12724,
#   10881,
#   17013,
#   7140,
#   5155,
#   4476,
#   1847,
#   17167,
#   8739,
#   10881,
#   22305,
#   11088,
#   13450,
#   1627,
#   133],
#  [15638, 18649, 19242, 2639, 17167, 12674, 21781, 17190, 133],
#  [21781,
#   11661,
#   23194,
#   16995,
#   9534,
#   22002,
#   5135,
#   12725,
#   16314,
#   16429,
#   11331,
#   6907,
#   11326,
#   7140,
#   4559,
#   120,
#   23363,
#   14850,
#   19443,
#   21778,
#   9346,
#   8845,
#   23194,
#   23239,
#   120,
#   21781,
#   10518,
#   16451,
#   19443,
#   133],
#  [5041,
#   4998,
#   11326,
#   7081,
#   14850,
#   17631,
#   11186,
#   12674,
#   18649,
#   16315,
#   12674,
#   21781,
#   17190,
#   133],
#  [23040,
#   4796,
#   23527,
#   4043,
#   18650,
#   120,
#   20402,
#   15588,
#   21773,
#   4476,
#   18193,
#   16429,
#   21781,
#   22092,
#   133],
#  [16576,
#   4796,
#   22013,
#   23493,
#   11289,
#   15648,
#   6991,
#   12674,
#   19744,
#   17404,
#   23493,
#   3234,
#   18650,
#   120,
#   1321,
#   17167,
#   16429,
#   21781,
#   16758,
#   10632,
#   133],
#  [21819, 23194, 10890, 23493, 2705, 18650, 120, 16624, 871, 17167, 133],
#  [16568,
#   19733,
#   5155,
#   17579,
#   11790,
#   10586,
#   18650,
#   12674,
#   13450,
#   1630,
#   7880,
#   22002,
#   14047,
#   23669,
#   12,
#   13450,
#   133],
#  [19733,
#   17631,
#   2432,
#   18650,
#   7880,
#   23493,
#   3546,
#   18650,
#   12674,
#   13450,
#   4476,
#   23669,
#   9617,
#   133],
#  [17579, 12, 18650, 10544, 22002, 3547, 11088, 3795, 133],
#  [132],
#  [11598, 20507, 11398, 11599, 14327, 22002, 17485, 10881, 9766, 133],
#  [5571, 1633],
#  [21781,
#   11598,
#   20506,
#   17002,
#   12,
#   10204,
#   6859,
#   11261,
#   21781,
#   11599,
#   14327,
#   22002,
#   17827,
#   15377,
#   8269,
#   20267,
#   22002,
#   6968,
#   20468,
#   9766,
#   120,
#   13151,
#   11289,
#   19763,
#   8269,
#   20340,
#   22019,
#   18806,
#   133],
#  [17827,
#   15377,
#   8269,
#   20267,
#   13102,
#   11462,
#   22002,
#   14760,
#   5135,
#   16455,
#   5223,
#   4792,
#   4476,
#   6928,
#   15161,
#   14057,
#   16533,
#   21915,
#   120,
#   19443,
#   20340,
#   133],
#  [122, 9107, 13813, 120, 5571, 16065, 77, 2667],
#  [132],
#  [6020, 19944, 6921, 736, 15347, 20327, 6475, 133],
#  [14492, 1633],
#  [21781, 10857, 6475, 23194, 5222, 6912, 14124, 14807, 22073, 9358, 133],
#  [6530, 6018, 22867],
#  [5130, 6921, 736, 15455, 8305, 3693, 15035, 2175],
#  [22412, 21019, 13129, 17813, 743, 17072, 8639, 2176],
#  [11126, 10534, 618, 18769, 4458, 20752, 61, 6611],
#  [15575, 4497, 14410, 14647, 17072, 11068, 4468],
#  [19393,
#   4468,
#   8880,
#   14,
#   13484,
#   15,
#   526,
#   19465,
#   14362,
#   22713,
#   292,
#   22451,
#   292,
#   6925],
#  [15972, 17463, 16150, 8434, 8793, 16150, 10885, 14746, 4468],
#  [11520, 14088, 11326, 12309, 8463, 4468, 21609, 18049, 20837],
#  [15253, 292, 22504, 336, 19832, 7945, 605, 17683, 4468],
#  [22520, 11531, 6475, 3924, 17086, 19892, 1944],
#  [16260, 6018, 22867, 13102, 13371, 14124, 14807],
#  [122, 14492, 16065, 95, 1405, 3521, 4038],
#  [132],
#  [22845, 19944, 4, 2568, 15347, 13236, 1656, 11087, 133],
#  [14492, 1633],
#  [21781,
#   10857,
#   10804,
#   13132,
#   23194,
#   5222,
#   6912,
#   14124,
#   14807,
#   14198,
#   6757,
#   12979,
#   133],
#  [6530, 22845, 4505, 14, 21393, 15893, 15605, 4806, 15],
#  [5130, 4, 2568, 15455, 20752, 121, 990, 6611, 15035, 2013],
#  [22412, 11087, 5958, 2908, 14290, 17072, 8639, 19400],
#  [14047, 15575, 4499, 13129, 17813, 4462, 11126, 10534, 634, 6611],
#  [14047, 19393, 4495, 18769, 4468],
#  [16260, 19391, 20141, 10711, 8305],
#  [14410,
#   14492,
#   8880,
#   14,
#   13484,
#   15,
#   526,
#   19465,
#   14362,
#   22713,
#   292,
#   22451,
#   292,
#   13423,
#   292,
#   10987],
#  [15972, 17463, 23693, 8434, 8793, 16150, 10885, 14746, 13065, 1749],
#  [11520, 14088, 9929, 12309, 8463, 21392, 21609, 18049, 20837],
#  [15253, 292, 22504, 3309, 6611, 19832, 7945, 3309, 6611, 17683, 4468],
#  [16260, 13133, 16430, 9866, 17936],
#  [122, 14492, 16065, 95, 1405, 3521, 4267],
#  [132],
#  [17580, 7981, 22671, 121, 21448, 121, 14443, 20114, 133],
#  [17580, 7981, 11088, 14443, 20114, 12942, 19929, 122],
#  [14065,
#   120,
#   5635,
#   634,
#   121,
#   23123,
#   21962,
#   5565,
#   14065,
#   5155,
#   21586,
#   17773,
#   2155,
#   12394,
#   133],
#  [132],
#  [13123, 17447, 9412, 10506, 16429, 23159, 23493, 21448, 133],
#  [7758, 20222],
#  [13306, 1633],
#  [13123,
#   12,
#   16727,
#   17090,
#   15981,
#   23493,
#   21448,
#   19443,
#   16533,
#   21915,
#   8501,
#   21720,
#   6232,
#   21781,
#   22382,
#   8295,
#   5312,
#   22002,
#   6033,
#   4476,
#   21010,
#   12674,
#   4476,
#   21629,
#   133],
#  [13144,
#   18251,
#   120,
#   23382,
#   5480,
#   13123,
#   12,
#   5081,
#   22002,
#   23198,
#   7985,
#   22572,
#   15980,
#   23493,
#   21448,
#   120,
#   22019,
#   13123,
#   18271,
#   13139,
#   14522,
#   14336,
#   8586,
#   23155,
#   22002,
#   21523,
#   18401,
#   21773,
#   10625,
#   133],
#  [3,
#   13139,
#   5314,
#   22002,
#   15107,
#   21781,
#   21449,
#   17845,
#   13102,
#   20968,
#   22002,
#   15976,
#   133],
#  [21781,
#   21451,
#   5381,
#   8019,
#   120,
#   21804,
#   5381,
#   8789,
#   21718,
#   120,
#   6896,
#   21781,
#   11289,
#   5527,
#   12132,
#   12674,
#   23198,
#   13102,
#   21778,
#   21836,
#   13102,
#   10062,
#   4476,
#   21010,
#   12674,
#   4476,
#   21629,
#   120,
#   3,
#   12002,
#   19443,
#   133],
#  [18251, 13102, 23456, 22667, 12243, 21729, 5480, 5081, 133],
#  [12002,
#   23436,
#   6033,
#   18792,
#   6912,
#   9786,
#   6139,
#   120,
#   4476,
#   10927,
#   13125,
#   9981,
#   22002,
#   9717,
#   5155,
#   19071,
#   14343,
#   17002,
#   17535,
#   133],
#  [13123,
#   16533,
#   23268,
#   19871,
#   21448,
#   4476,
#   15221,
#   120,
#   22895,
#   23198,
#   120,
#   19584,
#   13139,
#   23194,
#   7846,
#   22002,
#   17090,
#   5155,
#   23155,
#   22002,
#   16577,
#   15980,
#   23502,
#   17723,
#   133],
#  [6896,
#   13139,
#   20374,
#   8586,
#   10881,
#   8360,
#   23345,
#   13139,
#   6970,
#   4476,
#   8602,
#   5585,
#   133],
#  [21448,
#   4627,
#   13123,
#   16533,
#   23268,
#   16429,
#   14077,
#   4476,
#   12514,
#   7003,
#   4799,
#   13139,
#   4792,
#   13125,
#   21685,
#   18803,
#   21778,
#   8586,
#   11790,
#   18516,
#   21749,
#   10697,
#   4476,
#   15422,
#   133],
#  [13139, 19443, 13151, 5421, 18125, 23322, 10881, 8778, 18136, 133],
#  [3,
#   21781,
#   15221,
#   21778,
#   23237,
#   19871,
#   22002,
#   14,
#   21449,
#   17781,
#   11797,
#   4904,
#   15,
#   5510,
#   13102,
#   21778,
#   13123,
#   13102,
#   18458,
#   5565,
#   5274,
#   21962,
#   23502,
#   17723,
#   22002,
#   9959,
#   17090,
#   15980,
#   120,
#   3,
#   13125,
#   10901,
#   15377,
#   8651,
#   14260,
#   22019,
#   13123,
#   18271,
#   12674,
#   5135,
#   13001,
#   133],
#  [21719,
#   11970,
#   15660,
#   20275,
#   13125,
#   17827,
#   15377,
#   6166,
#   16011,
#   22054,
#   16451,
#   12674,
#   13463,
#   23067,
#   22002,
#   18932,
#   21781,
#   11464,
#   12074,
#   13123,
#   7079,
#   11088,
#   21448,
#   12674,
#   21781,
#   1579,
#   15292,
#   9637,
#   23159,
#   133],
#  [13127,
#   17090,
#   21526,
#   11991,
#   6072,
#   8678,
#   16754,
#   21781,
#   11464,
#   20275,
#   1617,
#   8971,
#   21781,
#   17808,
#   11524,
#   12,
#   23442,
#   22002,
#   14760,
#   11464,
#   7963,
#   133],
#  [17090,
#   21526,
#   6232,
#   21781,
#   22382,
#   20211,
#   23322,
#   14047,
#   12086,
#   12674,
#   10516,
#   133],
#  [3,
#   21781,
#   23023,
#   7817,
#   16712,
#   16429,
#   8586,
#   5381,
#   5778,
#   120,
#   16254,
#   11487,
#   133],
#  [21781, 15138, 135],
#  [5381, 11126, 16429, 10297, 5155, 8734, 21778, 15777, 6033, 23567, 135],
#  [21836,
#   5465,
#   5585,
#   13102,
#   22883,
#   8602,
#   6054,
#   21850,
#   23382,
#   20752,
#   13139,
#   8280,
#   6059,
#   13151,
#   17848,
#   120,
#   3,
#   14260,
#   19443,
#   133],
#  [3,
#   23237,
#   10232,
#   11088,
#   21448,
#   120,
#   12558,
#   13151,
#   10361,
#   13102,
#   22002,
#   17090,
#   120,
#   21778,
#   13139,
#   23436,
#   5238,
#   13123,
#   12,
#   15221,
#   22002,
#   9959,
#   17090,
#   15980,
#   6054,
#   21778,
#   13102,
#   16706,
#   11442,
#   120,
#   3,
#   12002,
#   19443,
#   133,
#   3],
#  [23237, 9316, 16254, 23153, 4476, 23159, 120, 11451, 10883, 133],
#  [16150, 16542, 6151, 11088, 23186, 133, 3],
#  [13123,
#   12,
#   7337,
#   22382,
#   21685,
#   19443,
#   8586,
#   11790,
#   19871,
#   4476,
#   3,
#   6979,
#   20240,
#   3,
#   22002,
#   13123,
#   133],
#  [13139, 11261, 16150, 20601, 10881, 21781, 18802, 133],
#  [16011, 5155, 14260, 12, 20728, 19443, 21804, 8280, 16254, 8003, 13139, 133],
#  [21781,
#   21685,
#   5056,
#   19443,
#   21778,
#   16011,
#   11790,
#   19871,
#   15222,
#   22002,
#   18482,
#   21448,
#   22895,
#   6949,
#   120,
#   21781,
#   22601,
#   20879,
#   5155,
#   15608,
#   133],
#  [132],
#  [17530, 9118, 8875, 16327, 21030, 12674, 14293, 133],
#  [22333, 1633],
#  [4476,
#   17530,
#   9118,
#   16533,
#   21915,
#   8874,
#   4476,
#   17530,
#   21474,
#   18802,
#   21836,
#   23269,
#   21778,
#   14293,
#   23194,
#   18626,
#   10223,
#   22989,
#   22002,
#   736,
#   17530,
#   16327,
#   22315,
#   22002,
#   18952,
#   12309,
#   4792,
#   23550,
#   12674,
#   21781,
#   16234,
#   4787,
#   8296,
#   133],
#  [3, 21836, 13102, 16254, 22306, 133],
#  [22667,
#   22002,
#   22006,
#   120,
#   23237,
#   11991,
#   16150,
#   13775,
#   16429,
#   5274,
#   16326,
#   21030,
#   16624,
#   13623,
#   12674,
#   14293,
#   23502,
#   12127,
#   23436,
#   120,
#   5155,
#   23237,
#   11991,
#   16254,
#   18512,
#   5274,
#   7905,
#   120,
#   3,
#   21781,
#   17530,
#   9818,
#   12,
#   7354,
#   8548,
#   12674,
#   22276,
#   120,
#   21488,
#   5713,
#   120,
#   22019,
#   18961,
#   6912,
#   21680,
#   133],
#  [17516,
#   12,
#   13936,
#   15381,
#   19443,
#   21836,
#   23269,
#   13139,
#   23577,
#   19858,
#   4476,
#   21631,
#   22002,
#   14293,
#   22002,
#   13038,
#   120,
#   6896,
#   5713,
#   19443,
#   21781,
#   17889,
#   23194,
#   17972,
#   6912,
#   20556,
#   16327,
#   7904,
#   4552,
#   21785,
#   23545,
#   7981,
#   21198,
#   5480,
#   16193,
#   16429,
#   21785,
#   19462,
#   133],
#  [12002,
#   19443,
#   21778,
#   21797,
#   5381,
#   5135,
#   10074,
#   4173,
#   17530,
#   16327,
#   23550,
#   12674,
#   14293,
#   133],
#  [132],
#  [22382, 13072, 16607, 14129, 15160, 12674, 5789, 133],
#  [11977, 11798],
#  [5789, 1633],
#  [5135,
#   13072,
#   10216,
#   11653,
#   5961,
#   12674,
#   13074,
#   23066,
#   16533,
#   21915,
#   22002,
#   10300,
#   21296,
#   22002,
#   13070,
#   12,
#   13904,
#   18492,
#   4792,
#   21804,
#   23322,
#   5595,
#   6912,
#   13072,
#   22291,
#   8753,
#   12887,
#   13074,
#   14047,
#   15561,
#   133],
#  [4476,
#   15716,
#   13649,
#   20877,
#   19443,
#   13151,
#   14128,
#   14993,
#   18320,
#   15226,
#   12674,
#   5789,
#   21781,
#   19765,
#   16429,
#   21781,
#   13906,
#   8856,
#   17002,
#   16429,
#   13070,
#   14,
#   13587,
#   15,
#   11977,
#   18395,
#   16533,
#   23268,
#   5155,
#   23022,
#   12243,
#   21296,
#   22002,
#   13070,
#   12,
#   18486,
#   13907,
#   133],
#  [3,
#   18320,
#   9849,
#   21778,
#   21781,
#   13072,
#   18876,
#   23577,
#   8140,
#   22002,
#   20836,
#   20208,
#   6912,
#   20208,
#   23493,
#   21785,
#   13904,
#   7886,
#   5155,
#   21781,
#   18876,
#   15671,
#   12674,
#   13072,
#   13906,
#   120,
#   3,
#   13139,
#   19443,
#   133],
#  [4476,
#   20727,
#   10881,
#   21781,
#   11653,
#   19443,
#   21781,
#   15161,
#   3,
#   20242,
#   4476,
#   16033,
#   14247,
#   16429,
#   8199,
#   6232,
#   15716,
#   13649,
#   5155,
#   21781,
#   13072,
#   13904,
#   16608,
#   3,
#   133],
#  [13070,
#   12043,
#   6468,
#   21581,
#   12674,
#   16242,
#   13074,
#   12674,
#   13450,
#   12674,
#   18140,
#   16429,
#   13587,
#   11692,
#   5961,
#   12674,
#   13077,
#   13904,
#   5383,
#   16745,
#   21781,
#   8161,
#   16429,
#   21781,
#   11524,
#   12674,
#   5789,
#   133],
#  [13077,
#   13904,
#   5383,
#   6519,
#   13070,
#   5381,
#   22508,
#   21781,
#   8161,
#   16429,
#   11692,
#   16429,
#   21781,
#   13077,
#   13904,
#   17044,
#   22591,
#   16429,
#   13906,
#   14,
#   18093,
#   15,
#   11653,
#   133],
#  [18093,
#   5155,
#   13074,
#   12,
#   13906,
#   8856,
#   17002,
#   14,
#   13585,
#   15,
#   21781,
#   22382,
#   14734,
#   13077,
#   13904,
#   10372,
#   120,
#   11991,
#   11790,
#   16242,
#   13074,
#   22508,
#   21785,
#   8161,
#   20275,
#   13077,
#   10888,
#   23322,
#   16710,
#   11088,
#   13911,
#   12674,
#   21781,
#   1617,
#   11729,
#   23159,
#   133],
#  [7586,
#   6232,
#   21781,
#   22382,
#   16990,
#   6737,
#   16712,
#   5565,
#   21781,
#   23273,
#   12674,
#   21781,
#   15622,
#   19915,
#   10629,
#   20275,
#   4476,
#   22434,
#   7214,
#   14047,
#   23669,
#   133],
#  [15716,
#   13649,
#   19443,
#   13072,
#   22291,
#   11790,
#   5056,
#   6072,
#   20076,
#   13585,
#   17603,
#   12674,
#   18168,
#   18641,
#   12674,
#   21242,
#   18040,
#   15945,
#   21781,
#   13072,
#   6518,
#   16754,
#   21781,
#   14047,
#   22382,
#   8668,
#   133],
#  [13139,
#   19443,
#   4552,
#   736,
#   13077,
#   13907,
#   23322,
#   13691,
#   16624,
#   23580,
#   12674,
#   21781,
#   5594,
#   133],
#  [6551,
#   13070,
#   5155,
#   22343,
#   15655,
#   4865,
#   5155,
#   13992,
#   21076,
#   5565,
#   21581,
#   12674,
#   16242,
#   13074,
#   12674,
#   18140,
#   16429,
#   21785,
#   16811,
#   13904,
#   18492,
#   133],
#  [4476,
#   22432,
#   4865,
#   10885,
#   12674,
#   20610,
#   22343,
#   18015,
#   13077,
#   13907,
#   11088,
#   17613,
#   5599,
#   6912,
#   5789,
#   22291,
#   133],
#  [132],
#  [19561, 19126, 18400, 20899, 12674, 18227, 21253, 22139, 133],
#  [14814, 1633],
#  [21781,
#   20745,
#   19561,
#   19126,
#   4799,
#   21781,
#   9341,
#   5155,
#   19126,
#   12961,
#   8915,
#   18400,
#   23322,
#   14738,
#   20899,
#   21836,
#   23269,
#   12674,
#   18227,
#   21253,
#   22139,
#   120,
#   8684,
#   12674,
#   21781,
#   13712,
#   19443,
#   133],
#  [3, 21797, 23322, 16150, 7333, 12674, 19561, 19126, 18400, 133],
#  [21781,
#   14916,
#   23194,
#   22883,
#   18227,
#   6054,
#   16429,
#   21253,
#   12300,
#   120,
#   3,
#   16542,
#   8683,
#   19443,
#   133],
#  [21781,
#   20745,
#   19126,
#   23194,
#   18147,
#   5565,
#   2533,
#   292,
#   423,
#   22002,
#   21781,
#   9341,
#   133],
#  [16550,
#   12961,
#   8918,
#   23322,
#   5565,
#   3342,
#   120,
#   2545,
#   17167,
#   120,
#   21864,
#   15564,
#   23322,
#   3363,
#   120,
#   628,
#   17167,
#   5155,
#   20317,
#   15564,
#   23322,
#   3358,
#   120,
#   3419,
#   17167,
#   133],
#  [16560, 11149, 23322, 5565, 20317, 120, 3370, 17167, 133],
#  [132],
#  [13123, 5339, 5358, 12, 10796, 22002, 23328, 5878, 133],
#  [13306, 1633],
#  [13123,
#   11261,
#   16878,
#   17781,
#   23660,
#   5358,
#   17198,
#   16533,
#   21915,
#   22002,
#   10835,
#   16754,
#   13151,
#   21742,
#   22002,
#   21781,
#   23328,
#   5878,
#   120,
#   9895,
#   4476,
#   6702,
#   13126,
#   8391,
#   120,
#   5135,
#   5358,
#   4752,
#   19443,
#   133],
#  [3, 21781, 17891, 13102, 16754, 133],
#  [21781,
#   17781,
#   12,
#   4869,
#   11970,
#   18512,
#   17198,
#   22002,
#   17008,
#   21898,
#   13125,
#   4881,
#   6896,
#   21781,
#   17781,
#   13102,
#   16254,
#   10236,
#   22002,
#   22206,
#   22002,
#   21781,
#   23328,
#   5878,
#   6076,
#   15531,
#   120,
#   3,
#   15815,
#   4569,
#   18432,
#   22019,
#   18961,
#   133],
#  [5358,
#   11790,
#   6072,
#   19618,
#   22002,
#   15160,
#   10927,
#   13125,
#   17827,
#   15377,
#   20104,
#   17176,
#   12674,
#   21781,
#   23328,
#   5878,
#   22126,
#   16429,
#   18330,
#   16533,
#   21915,
#   6896,
#   21781,
#   22859,
#   23194,
#   7331,
#   22002,
#   11263,
#   4792,
#   13123,
#   8874,
#   10796,
#   7611,
#   22002,
#   21781,
#   16878,
#   14128,
#   12,
#   12093,
#   133],
#  [16878,
#   16457,
#   4627,
#   19071,
#   17827,
#   15377,
#   6166,
#   16011,
#   16429,
#   22315,
#   22002,
#   20999,
#   21781,
#   18330,
#   15161,
#   6912,
#   13596,
#   5358,
#   11651,
#   133],
#  [5358,
#   21167,
#   7026,
#   4476,
#   15161,
#   6232,
#   13125,
#   5155,
#   17465,
#   16457,
#   120,
#   16533,
#   7563,
#   4768,
#   120,
#   5565,
#   21781,
#   5019,
#   6700,
#   8424,
#   6232,
#   13396,
#   5155,
#   21781,
#   23328,
#   5878,
#   133],
#  [4569,
#   18432,
#   19443,
#   5358,
#   11790,
#   8725,
#   4799,
#   10837,
#   22002,
#   21781,
#   23328,
#   5878,
#   16533,
#   21915,
#   120,
#   4792,
#   13123,
#   14324,
#   21781,
#   5852,
#   120,
#   6054,
#   12002,
#   11790,
#   4476,
#   6895,
#   19617,
#   12674,
#   11263,
#   5155,
#   23577,
#   16254,
#   6033,
#   11037,
#   22656,
#   15531,
#   133],
#  [132],
#  [5358, 22002, 15160, 17176, 12674, 11263, 4792, 10796, 5852, 133],
#  [13306, 1633],
#  [23660,
#   5358,
#   23436,
#   15160,
#   20104,
#   17176,
#   12674,
#   11263,
#   16533,
#   21915,
#   4792,
#   16880,
#   19443,
#   21781,
#   19071,
#   13125,
#   11524,
#   11790,
#   5932,
#   21781,
#   16878,
#   14128,
#   11088,
#   10837,
#   22002,
#   21781,
#   23328,
#   5878,
#   10881,
#   21526,
#   23493,
#   21781,
#   10927,
#   17827,
#   15377,
#   133],
#  [3,
#   21781,
#   15161,
#   6232,
#   17176,
#   5155,
#   5358,
#   23436,
#   21502,
#   17404,
#   5565,
#   10017,
#   7402,
#   12674,
#   11263,
#   5155,
#   16254,
#   12674,
#   18330,
#   5480,
#   17419,
#   120,
#   3,
#   17176,
#   7,
#   16451,
#   19443,
#   133],
#  [16878,
#   16457,
#   19443,
#   21781,
#   13125,
#   11524,
#   11790,
#   5932,
#   5358,
#   11088,
#   16766,
#   13123,
#   12674,
#   4476,
#   16878,
#   12092,
#   22002,
#   21781,
#   23328,
#   5878,
#   12674,
#   5135,
#   5602,
#   22002,
#   5894,
#   21781,
#   15161,
#   23493,
#   17176,
#   133],
#  [13125,
#   17827,
#   15377,
#   6166,
#   16011,
#   11970,
#   4627,
#   16607,
#   14128,
#   17176,
#   120,
#   23382,
#   12002,
#   8762,
#   12674,
#   15052,
#   9766,
#   120,
#   16429,
#   22315,
#   22002,
#   22521,
#   12243,
#   14343,
#   11524,
#   12,
#   5659,
#   22002,
#   7984,
#   17090,
#   21526,
#   133],
#  [132],
#  [4779, 22435, 9818, 19585, 21517, 11683, 11462, 12309, 133],
#  [12208, 11755],
#  [9521, 1633],
#  [21864,
#   4779,
#   11683,
#   6758,
#   22002,
#   21781,
#   22601,
#   5351,
#   9837,
#   14047,
#   23269,
#   6912,
#   19365,
#   12377,
#   23382,
#   10043,
#   11088,
#   21781,
#   21517,
#   15336,
#   23436,
#   18952,
#   22002,
#   4780,
#   12674,
#   4476,
#   10585,
#   8668,
#   120,
#   21781,
#   4779,
#   9818,
#   12674,
#   4569,
#   9039,
#   19443,
#   16533,
#   21915,
#   133],
#  [3, 16706, 5081, 13102, 12674, 22101, 23493, 21781, 22435, 10901, 15381, 133],
#  [21785,
#   18952,
#   22002,
#   4780,
#   23436,
#   21502,
#   17404,
#   12674,
#   22382,
#   16624,
#   21864,
#   8668,
#   120,
#   3,
#   5135,
#   9818,
#   16455,
#   19443,
#   133],
#  [3,
#   21781,
#   9818,
#   13102,
#   13136,
#   21786,
#   22206,
#   9325,
#   10881,
#   21785,
#   18952,
#   22002,
#   21785,
#   12314,
#   133],
#  [21797, 13102, 16150, 16371, 22002, 21785, 22206, 120, 3, 12002, 4681, 133],
#  [21781,
#   21864,
#   13113,
#   21517,
#   11683,
#   23322,
#   16777,
#   6912,
#   19957,
#   19365,
#   4870,
#   23382,
#   10043,
#   22002,
#   22435,
#   20869,
#   20039,
#   14047,
#   11074,
#   16533,
#   6399,
#   21785,
#   16811,
#   4869,
#   4792,
#   4476,
#   23669,
#   12674,
#   21781,
#   7076,
#   16429,
#   21517,
#   15336,
#   12674,
#   13522,
#   12674,
#   20610,
#   4780,
#   133],
#  [21781,
#   22435,
#   19443,
#   16533,
#   15531,
#   13139,
#   23577,
#   11865,
#   16754,
#   21781,
#   21864,
#   22002,
#   21781,
#   12979,
#   18565,
#   8372,
#   120,
#   17614,
#   14047,
#   22324,
#   133],
#  [13139, 11970, 20275, 6072, 20253, 16533, 21781, 13132, 133],
#  [23355,
#   5500,
#   23361,
#   21781,
#   21864,
#   11683,
#   23577,
#   22206,
#   5758,
#   22002,
#   13522,
#   16624,
#   21781,
#   4779,
#   7062,
#   13494,
#   120,
#   21781,
#   9818,
#   16455,
#   19443,
#   4466,
#   3,
#   21778,
#   11970,
#   16254,
#   6072,
#   8725,
#   120,
#   6896,
#   17614,
#   13522,
#   133,
#   3],
#  [13522, 13102, 21781, 12016, 16429, 21781, 16607, 21517, 15336, 133],
#  [13494,
#   13102,
#   8162,
#   6912,
#   17781,
#   6863,
#   18250,
#   12,
#   11524,
#   120,
#   23362,
#   21517,
#   13102,
#   10629,
#   22002,
#   16800,
#   133],
#  [21781,
#   9818,
#   16455,
#   19443,
#   21781,
#   21864,
#   15191,
#   120,
#   6119,
#   22002,
#   6033,
#   12674,
#   21785,
#   1990,
#   120,
#   23322,
#   8502,
#   12674,
#   4569,
#   9039,
#   133],
#  [12002, 9064, 16254, 9754, 133],
#  [21781,
#   19369,
#   120,
#   23550,
#   10881,
#   21781,
#   4764,
#   10706,
#   12674,
#   21781,
#   19365,
#   18827,
#   16429,
#   21592,
#   120,
#   23322,
#   21506,
#   12376,
#   4792,
#   4476,
#   21517,
#   15308,
#   10627,
#   10886,
#   21785,
#   7103,
#   17414,
#   22002,
#   13992,
#   12674,
#   5639,
#   1627,
#   133],
#  [21517,
#   19443,
#   13151,
#   20111,
#   16429,
#   5111,
#   11088,
#   4939,
#   23194,
#   10145,
#   16429,
#   19365,
#   15334,
#   21296,
#   10881,
#   18250,
#   12,
#   11524,
#   133],
#  [15608, 19443, 21781, 8374, 12, 15897, 23194, 7735, 133],
#  [16317, 9119, 5605, 22002, 11037, 21781, 19957, 10389, 133],
#  [21781,
#   19369,
#   120,
#   23382,
#   19443,
#   21804,
#   16777,
#   21781,
#   11683,
#   122,
#   22382,
#   5412,
#   23493,
#   13506,
#   5666,
#   19059,
#   122,
#   23363,
#   9337,
#   18656,
#   14745,
#   23545,
#   16533,
#   21785,
#   12599,
#   4035,
#   7103,
#   17414,
#   14047,
#   11074,
#   120,
#   14170,
#   21781,
#   22435,
#   7062,
#   4569,
#   9039,
#   10881,
#   12309,
#   16533,
#   21264,
#   133],
#  [132],
#  [13074, 12, 19425, 15163, 19364, 12, 23820, 133],
#  [5789, 1633],
#  [13077,
#   17781,
#   19425,
#   12497,
#   11970,
#   22019,
#   22995,
#   19365,
#   22465,
#   23010,
#   23820,
#   21778,
#   5789,
#   23155,
#   22002,
#   14741,
#   3,
#   11081,
#   5155,
#   8199,
#   3,
#   23493,
#   15608,
#   120,
#   16455,
#   13077,
#   16063,
#   19443,
#   16533,
#   21915,
#   133],
#  [3,
#   17781,
#   19425,
#   12497,
#   21061,
#   9573,
#   21781,
#   15161,
#   13074,
#   12,
#   13593,
#   22002,
#   14741,
#   11081,
#   5155,
#   8199,
#   23493,
#   19364,
#   120,
#   3,
#   21781,
#   16916,
#   19443,
#   133],
#  [21804,
#   19443,
#   23820,
#   22019,
#   19425,
#   6076,
#   12002,
#   14170,
#   5789,
#   16533,
#   23268,
#   21778,
#   12243,
#   14278,
#   8856,
#   17002,
#   5155,
#   21781,
#   19365,
#   9550,
#   14,
#   16957,
#   15,
#   3,
#   5381,
#   6974,
#   10881,
#   5135,
#   12609,
#   14325,
#   16429,
#   21781,
#   9815,
#   3,
#   12652,
#   16533,
#   13074,
#   4792,
#   13151,
#   1614,
#   13030,
#   16429,
#   13911,
#   133],
#  [23820,
#   19443,
#   16533,
#   22324,
#   12002,
#   23577,
#   17785,
#   21781,
#   19365,
#   11524,
#   22002,
#   12097,
#   9884,
#   22425,
#   22139,
#   19510,
#   16533,
#   13074,
#   5155,
#   6331,
#   15608,
#   10881,
#   8817,
#   10069,
#   16429,
#   11487,
#   21941,
#   23493,
#   5789,
#   133],
#  [3,
#   16706,
#   20836,
#   13102,
#   10706,
#   120,
#   15848,
#   23237,
#   5381,
#   6974,
#   16533,
#   14,
#   21781,
#   19365,
#   15,
#   11524,
#   22002,
#   9884,
#   21781,
#   9657,
#   9815,
#   16533,
#   13074,
#   5155,
#   18921,
#   22139,
#   21941,
#   6232,
#   19364,
#   5155,
#   13074,
#   120,
#   3,
#   12002,
#   22019,
#   18806,
#   133],
#  [23820, 22994, 13074, 22376, 12674, 1627, 133],
#  [14047,
#   16420,
#   12002,
#   23194,
#   13050,
#   22002,
#   5606,
#   21781,
#   18593,
#   12086,
#   16533,
#   13074,
#   12,
#   17780,
#   120,
#   23362,
#   10301,
#   19425,
#   12,
#   21729,
#   10881,
#   19957,
#   15588,
#   23680,
#   133],
#  [132],
#  [17785, 9089, 121, 13074, 121, 5635, 2058, 133],
#  [5789, 1633],
#  [21802,
#   5381,
#   20556,
#   16429,
#   21781,
#   14132,
#   21008,
#   12674,
#   21781,
#   16455,
#   13077,
#   17785,
#   16533,
#   21915,
#   133],
#  [18961,
#   11970,
#   16254,
#   22869,
#   21802,
#   21008,
#   5155,
#   9330,
#   16254,
#   23064,
#   10881,
#   21785,
#   4621,
#   133],
#  [21780],
#  [121,
#   13074,
#   12,
#   17781,
#   19425,
#   12497,
#   15163,
#   23493,
#   7298,
#   16429,
#   21781,
#   19365,
#   14278,
#   8856,
#   17002,
#   23010,
#   23820,
#   133],
#  [121,
#   22344,
#   10901,
#   15377,
#   19585,
#   22343,
#   23436,
#   21502,
#   16975,
#   12674,
#   21781,
#   5789,
#   22139,
#   10393,
#   21778,
#   23436,
#   6033,
#   12086,
#   12674,
#   16289,
#   133],
#  [13074],
#  [121,
#   4476,
#   20110,
#   16429,
#   932,
#   22049,
#   16429,
#   19024,
#   5452,
#   12674,
#   22472,
#   18167,
#   17580,
#   12674,
#   21781,
#   11729,
#   133],
#  [132],
#  [17785, 9089, 121, 14156, 121, 5635, 2058, 133],
#  [6099, 1633],
#  [21802,
#   5381,
#   21781,
#   14132,
#   21008,
#   12674,
#   21781,
#   6099,
#   17785,
#   16533,
#   21915,
#   133],
#  [18961,
#   11970,
#   16254,
#   22869,
#   21802,
#   21008,
#   5155,
#   9330,
#   16254,
#   23064,
#   10881,
#   21785,
#   4621,
#   133],
#  [5136],
#  [121, 8016, 13102, 10041, 6232, 12264, 5155, 21781, 11524, 133],
#  [121,
#   17827,
#   15377,
#   11940,
#   4466,
#   13125,
#   21863,
#   9316,
#   16150,
#   19922,
#   17090,
#   133],
#  [5481],
#  [121,
#   16957,
#   20655,
#   6199,
#   4466,
#   13123,
#   13102,
#   17761,
#   10881,
#   23159,
#   4799,
#   21448,
#   5155,
#   14156,
#   133],
#  [121, 16959, 6001, 12674, 6099, 134],
#  [21781, 21864, 14734, 14412, 11991, 6072, 17759, 133],
#  [4908],
#  [121,
#   8141,
#   8400,
#   16429,
#   14088,
#   22969,
#   12703,
#   122,
#   23362,
#   16411,
#   12674,
#   21781,
#   15655,
#   14156,
#   9766,
#   14047,
#   21264,
#   133],
#  [4674],
#  [121, 10664, 15980, 6232, 14156, 5155, 16869, 133],
#  [121,
#   11940,
#   22002,
#   20933,
#   13011,
#   21781,
#   9764,
#   6001,
#   23493,
#   5135,
#   12720,
#   14407,
#   133],
#  [16096, 4923],
#  [121,
#   14937,
#   17038,
#   19988,
#   10293,
#   20584,
#   16754,
#   21781,
#   22970,
#   12674,
#   21264,
#   7,
#   9766,
#   133],
#  [132],
#  [7675, 14422, 5155, 10526, 7187, 6975, 18358, 15444, 133],
#  [7445, 1633],
#  [9619,
#   6975,
#   16533,
#   7675,
#   14422,
#   5155,
#   10526,
#   7187,
#   11162,
#   18359,
#   11088,
#   327,
#   7250,
#   12185,
#   22002,
#   317,
#   14580,
#   120,
#   14428,
#   5141,
#   19443,
#   133],
#  [21781,
#   8141,
#   21093,
#   22042,
#   22002,
#   7156,
#   7187,
#   5155,
#   6070,
#   14922,
#   20157,
#   17971,
#   11156,
#   21296,
#   133],
#  [16732,
#   10881,
#   4476,
#   6836,
#   7188,
#   18802,
#   13102,
#   5056,
#   10236,
#   22002,
#   14208,
#   21296,
#   5155,
#   17971,
#   20556,
#   6828,
#   20753,
#   120,
#   5141,
#   19443,
#   133],
#  [12414,
#   120,
#   22139,
#   23436,
#   14338,
#   6033,
#   14327,
#   5155,
#   17816,
#   8280,
#   9473,
#   16533,
#   10129,
#   22667,
#   4843,
#   16429,
#   21781,
#   18802,
#   133],
#  [7156,
#   14922,
#   5381,
#   5056,
#   10236,
#   22002,
#   6033,
#   18227,
#   4792,
#   21781,
#   18540,
#   5116,
#   16429,
#   10528,
#   7187,
#   22140,
#   21836,
#   23269,
#   120,
#   21804,
#   19443,
#   133],
#  [132],
#  [13710, 19585, 8705, 6902, 22002, 12252, 18161, 18920, 133],
#  [15560, 120, 4925, 133],
#  [1633],
#  [13710,
#   14148,
#   7253,
#   12689,
#   19443,
#   16533,
#   21915,
#   21778,
#   4476,
#   8705,
#   6904,
#   23577,
#   15114,
#   5135,
#   10324,
#   14550,
#   16429,
#   4,
#   567,
#   15347,
#   12674,
#   13151,
#   10723,
#   1648,
#   10711,
#   18193,
#   133],
#  [21781,
#   7875,
#   19443,
#   21778,
#   9573,
#   21781,
#   18193,
#   120,
#   23362,
#   6079,
#   13463,
#   449,
#   120,
#   13139,
#   6563,
#   4,
#   2548,
#   15347,
#   16919,
#   22784,
#   16429,
#   13151,
#   16750,
#   678,
#   17167,
#   19865,
#   16260,
#   9534,
#   1944,
#   133],
#  [21781, 16260, 23322, 6563, 10881, 4, 2600, 15347, 133],
#  [17291,
#   14978,
#   120,
#   7448,
#   10664,
#   16452,
#   16429,
#   21781,
#   17765,
#   5155,
#   7455,
#   7093,
#   7875,
#   120,
#   19443,
#   21781,
#   6904,
#   3,
#   16444,
#   5135,
#   16601,
#   22002,
#   18577,
#   21781,
#   7875,
#   12,
#   23284,
#   5682,
#   12964,
#   8273,
#   5155,
#   12667,
#   11161,
#   7156,
#   10824,
#   5155,
#   9624,
#   133,
#   3],
#  [132],
#  [18853, 4963, 121, 14198, 20860, 20476, 133],
#  [122,
#   14198,
#   5140,
#   6328,
#   5985,
#   20856,
#   20610,
#   16033,
#   9927,
#   21674,
#   8232,
#   23493,
#   5135,
#   16735,
#   18403,
#   120,
#   12243,
#   16451,
#   19443,
#   133],
#  [122,
#   21781,
#   5140,
#   19939,
#   4476,
#   964,
#   17813,
#   21579,
#   16429,
#   4,
#   3140,
#   5155,
#   4476,
#   10723,
#   1630,
#   23669,
#   9624,
#   10073,
#   16429,
#   4,
#   2494,
#   17165,
#   20030,
#   120,
#   12243,
#   16451,
#   19443,
#   133],
#  [122,
#   21781,
#   5140,
#   5056,
#   19939,
#   5135,
#   9624,
#   10073,
#   10881,
#   21781,
#   1648,
#   23669,
#   120,
#   6896,
#   21781,
#   10632,
#   23194,
#   16254,
#   12610,
#   5676,
#   133],
#  [122, 20610, 16033, 9927, 7651, 5565, 2796, 23268, 133],
#  [122, 9605, 5627, 120, 23137, 21052, 6859, 120, 2030],
#  [132],
#  [11251, 8637, 19660, 18162, 16009, 19104, 133],
#  [17300, 1633],
#  [21251, 16429, 8066, 10664, 8637],
#  [14, 12674, 21857, 120, 10178, 17165, 20030, 8637, 15],
#  [20317, 15564, 9892, 18193, 9892],
#  [13438, 2591, 120, 13438, 2591, 120, 13438, 2591, 120, 13438, 2591, 120],
#  [1630, 1627, 1630, 1627],
#  [12714, 20877, 8637, 4466],
#  [22092, 18971, 4, 645, 4, 1057, 4, 3886, 4, 3320],
#  [20520, 18971, 1777, 500, 459, 458],
#  [19932, 18971, 468, 3866, 3764, 3178],
#  [16588, 12714, 4362, 4432, 3610, 3466],
#  [16009, 12714, 4205, 3465, 3566, 2577],
#  [9624, 17165, 20030, 341, 343, 323, 325],
#  [13438, 2591, 120, 1630, 13218, 2591, 120, 1630],
#  [5818, 20068, 8637, 4466],
#  [23550, 7062, 4, 3330, 14, 4, 4264, 15],
#  [7156, 5155, 7156, 10005, 1778, 4383],
#  [22092, 5530, 1142, 3877],
#  [20033, 7, 10003, 3333, 14, 496, 15],
#  [132],
#  [11598, 20507, 11398, 17485, 11599, 14327, 10881, 9764, 133],
#  [5571, 1633],
#  [21781,
#   11598,
#   20506,
#   17002,
#   12,
#   10204,
#   6859,
#   11261,
#   17827,
#   15377,
#   8269,
#   20267,
#   13151,
#   5767,
#   12558,
#   12002,
#   7500,
#   22002,
#   6968,
#   20468,
#   9766,
#   120,
#   13151,
#   11289,
#   19763,
#   8269,
#   20340,
#   22019,
#   18806,
#   16533,
#   21915,
#   133],
#  [17827,
#   15377,
#   8269,
#   20267,
#   23436,
#   14760,
#   5135,
#   16455,
#   5223,
#   4792,
#   4476,
#   6928,
#   15161,
#   14057,
#   16533,
#   21915,
#   120,
#   19443,
#   20340,
#   133],
#  [122, 9107, 13813, 120, 5571, 16065, 77, 2667],
#  [132],
#  [17785, 9089, 121, 10997, 121, 14123, 15532, 5635, 2058, 133],
#  [16948, 1633],
#  [21802,
#   5381,
#   14132,
#   21008,
#   12674,
#   21915,
#   12,
#   4794,
#   8570,
#   14123,
#   15532,
#   120,
#   8641,
#   5635,
#   2110,
#   133],
#  [11089, 16855],
#  [122,
#   4788,
#   19793,
#   22002,
#   18751,
#   16624,
#   16394,
#   23545,
#   5155,
#   18864,
#   19074,
#   19581,
#   17827,
#   15377,
#   4926,
#   13467,
#   12,
#   17987,
#   5381,
#   12923,
#   5480,
#   12464,
#   21072,
#   9963,
#   3262,
#   8661,
#   12674,
#   16948,
#   7526,
#   5155,
#   23268,
#   18326,
#   5623,
#   4089,
#   21437,
#   133],
#  [122,
#   10800,
#   8259,
#   15894,
#   15671,
#   5224,
#   9884,
#   16429,
#   22302,
#   4792,
#   14047,
#   16105,
#   12,
#   5599,
#   133],
#  [6890, 16858],
#  [122,
#   20194,
#   16429,
#   5843,
#   12,
#   11061,
#   10375,
#   17505,
#   22667,
#   20130,
#   12790,
#   8391,
#   120,
#   23493,
#   11061,
#   14850,
#   22514,
#   6912,
#   14578,
#   8296,
#   7893,
#   5155,
#   10392,
#   22002,
#   13594,
#   4558,
#   16429,
#   22236,
#   133],
#  [122,
#   19763,
#   11289,
#   16429,
#   21781,
#   21202,
#   22139,
#   22591,
#   5565,
#   10997,
#   21672,
#   4998,
#   21781,
#   9774,
#   5381,
#   12674,
#   17404,
#   10881,
#   20503,
#   22637,
#   12674,
#   21781,
#   16068,
#   10585,
#   23276,
#   133],
#  [122, 16948, 16065, 81, 449, 3076, 1993, 3487, 4180],
#  [132],
#  [23297, 18779, 22002, 14323, 12071, 16477, 16739, 121, 20887, 133],
#  [16678, 1633],
#  [21864,
#   17473,
#   23209,
#   12863,
#   23309,
#   16533,
#   21781,
#   12071,
#   16482,
#   16430,
#   15283,
#   23436,
#   6033,
#   18771,
#   16754,
#   21781,
#   16068,
#   15561,
#   120,
#   16591,
#   8870,
#   16232,
#   20888,
#   16511,
#   5480,
#   14,
#   20887,
#   15,
#   19443,
#   16533,
#   21915,
#   133],
#  [21781,
#   17473,
#   23309,
#   11991,
#   4614,
#   10881,
#   4476,
#   9116,
#   16429,
#   2549,
#   5935,
#   17165,
#   8661,
#   14,
#   6612,
#   15,
#   12674,
#   12071,
#   16739,
#   22002,
#   19264,
#   2087,
#   6612,
#   120,
#   4608,
#   22002,
#   21781,
#   7875,
#   12,
#   20889,
#   23275,
#   16061,
#   133],
#  [21781,
#   23309,
#   23436,
#   6033,
#   18790,
#   5155,
#   11588,
#   23436,
#   6033,
#   18107,
#   13011,
#   21781,
#   18861,
#   21898,
#   16542,
#   16429,
#   21781,
#   23309,
#   22002,
#   5695,
#   17474,
#   17893,
#   12674,
#   21781,
#   11161,
#   120,
#   13139,
#   19443,
#   133],
#  [122, 16678, 16065, 98, 2058, 3076, 3421, 3058],
#  [132],
#  [10686, 5344, 22139, 21326, 2534, 6281, 14927, 121, 15938, 133],
#  [12104, 1633],
#  [10682,
#   12,
#   22139,
#   21326,
#   19242,
#   22002,
#   2535,
#   6281,
#   14927,
#   12674,
#   5344,
#   11088,
#   2517,
#   6281,
#   12674,
#   14875,
#   120,
#   21781,
#   15893,
#   8522,
#   6399,
#   14,
#   15938,
#   15,
#   19443,
#   12674,
#   4476,
#   20877,
#   16533,
#   21915,
#   133],
#  [21781,
#   22784,
#   16429,
#   10286,
#   10544,
#   16542,
#   17167,
#   23677,
#   12674,
#   5344,
#   5155,
#   21781,
#   22784,
#   16429,
#   12650,
#   10544,
#   22382,
#   17167,
#   120,
#   15938,
#   19443,
#   133],
#  [22139, 5818, 14, 15347, 14927, 15, 4466],
#  [5344, 7, 4418, 14875, 7, 4418, 13219, 7, 4418, 13219, 7, 4407],
#  [12650, 643, 644, 3100, 3027],
#  [10286, 1145, 1141, 3555, 3556],
#  [5818, 71, 70, 49, 50],
#  [21781,
#   13237,
#   1627,
#   12644,
#   10632,
#   23194,
#   18983,
#   11088,
#   2856,
#   15347,
#   14927,
#   5155,
#   21781,
#   10281,
#   10632,
#   11088,
#   3531,
#   15347,
#   14927,
#   133],
#  [21781,
#   5878,
#   16429,
#   10682,
#   9617,
#   10074,
#   21781,
#   5344,
#   22139,
#   21326,
#   5565,
#   2501,
#   6281,
#   14927,
#   23493,
#   10286,
#   17951,
#   5565,
#   1174,
#   6281,
#   5155,
#   12650,
#   5565,
#   860,
#   6281,
#   133],
#  [21781,
#   15938,
#   12,
#   16455,
#   15563,
#   22139,
#   20886,
#   5381,
#   13954,
#   6093,
#   9534,
#   22002,
#   7333,
#   12674,
#   8522,
#   17895,
#   23355,
#   10682,
#   13368,
#   21781,
#   10109,
#   22591,
#   5565,
#   21781,
#   20855,
#   16429,
#   1627,
#   133],
#  [122, 12104, 16065, 85, 121, 293, 121, 3854, 3421, 2183],
#  [132],
#  [9582, 20869, 18314, 21568, 19465, 17813, 22002, 4461, 133],
#  [5126, 1633],
#  [21781,
#   10660,
#   15381,
#   18313,
#   21781,
#   17813,
#   10881,
#   21568,
#   19467,
#   16429,
#   21781,
#   9582,
#   11524,
#   12,
#   16033,
#   3410,
#   17167,
#   6475,
#   9534,
#   19893,
#   1945,
#   22002,
#   4461,
#   11088,
#   4460,
#   133],
#  [21568,
#   19467,
#   6079,
#   16533,
#   15531,
#   5155,
#   5381,
#   6097,
#   12086,
#   8570,
#   11088,
#   426,
#   11438,
#   22002,
#   1250,
#   11438,
#   22656,
#   11156,
#   16266,
#   133],
#  [21781,
#   15381,
#   11790,
#   18313,
#   1855,
#   6281,
#   11707,
#   11088,
#   19467,
#   16429,
#   21781,
#   16033,
#   6475,
#   6912,
#   21781,
#   7649,
#   16429,
#   22139,
#   16533,
#   23268,
#   133],
#  [122, 5126, 16065, 78, 1893, 3446, 3441],
#  [132],
#  [11326, 10441, 15381, 21692, 8104, 22002, 5695, 6724, 15788, 133],
#  [6485, 1633],
#  [11332,
#   12,
#   4834,
#   15381,
#   21221,
#   16533,
#   23268,
#   21778,
#   8104,
#   5695,
#   9642,
#   15125,
#   11088,
#   6724,
#   20066,
#   22656,
#   19663,
#   9006,
#   23361,
#   14695,
#   8329,
#   9182,
#   7015,
#   6033,
#   22193,
#   22002,
#   21781,
#   5198,
#   133],
#  [3,
#   22656,
#   21836,
#   13102,
#   7612,
#   22667,
#   6912,
#   21781,
#   10109,
#   22591,
#   12,
#   19661,
#   16900,
#   122,
#   5155,
#   23237,
#   11991,
#   5500,
#   21836,
#   22002,
#   6033,
#   9368,
#   5480,
#   18226,
#   5480,
#   17613,
#   122,
#   14,
#   8104,
#   15,
#   20157,
#   12558,
#   5565,
#   4998,
#   17613,
#   11398,
#   17739,
#   22002,
#   20067,
#   11088,
#   16693,
#   8295,
#   120,
#   3,
#   15381,
#   16455,
#   23323,
#   23861,
#   22019,
#   23788,
#   21685,
#   133],
#  [3,
#   12516,
#   9316,
#   16254,
#   23153,
#   22002,
#   19581,
#   21778,
#   21797,
#   13102,
#   4476,
#   7972,
#   8601,
#   10881,
#   8104,
#   120,
#   3,
#   12002,
#   4681,
#   133,
#   3],
#  [21797,
#   5381,
#   22053,
#   14854,
#   12298,
#   12674,
#   23345,
#   23237,
#   13773,
#   120,
#   5155,
#   21802,
#   15777,
#   6033,
#   10646,
#   22883,
#   18226,
#   133,
#   3],
#  [6485,
#   11970,
#   14163,
#   9714,
#   22002,
#   9956,
#   8103,
#   18014,
#   22070,
#   21781,
#   14407,
#   16429,
#   17844,
#   12674,
#   8685,
#   23493,
#   21781,
#   14695,
#   8329,
#   8391,
#   120,
#   23362,
#   10038,
#   12674,
#   14875,
#   23355,
#   6723,
#   4640,
#   12450,
#   8280,
#   8147,
#   4476,
#   20265,
#   12594,
#   6912,
#   9642,
#   8119,
#   6070,
#   133],
#  [21781,
#   10109,
#   7839,
#   4828,
#   21836,
#   15561,
#   22002,
#   18939,
#   4476,
#   17986,
#   22002,
#   5852,
#   21781,
#   22721,
#   16429,
#   21351,
#   20066,
#   21992,
#   4792,
#   20556,
#   10093,
#   22888,
#   10260,
#   18218,
#   23361,
#   13139,
#   23194,
#   13475,
#   133],
#  [10093,
#   10441,
#   7840,
#   11022,
#   10725,
#   11790,
#   17989,
#   5890,
#   20066,
#   6631,
#   120,
#   20714,
#   5155,
#   20698,
#   8220,
#   11088,
#   21781,
#   12447,
#   5155,
#   5197,
#   10864,
#   7296,
#   4792,
#   18808,
#   11088,
#   6723,
#   5155,
#   10997,
#   21778,
#   22508,
#   13934,
#   7981,
#   20066,
#   8280,
#   8147,
#   6586,
#   20730,
#   9874,
#   14,
#   6786,
#   15,
#   122,
#   14695,
#   8329,
#   9182,
#   133],
#  [6896,
#   20556,
#   15184,
#   16429,
#   21781,
#   10093,
#   12,
#   20840,
#   22888,
#   7847,
#   18218,
#   23361,
#   21781,
#   4657,
#   23194,
#   15959,
#   11399,
#   21781,
#   20401,
#   19109,
#   22002,
#   12447,
#   12021,
#   133],
#  [21781,
#   18216,
#   13102,
#   6097,
#   21123,
#   19885,
#   6912,
#   22382,
#   10093,
#   19661,
#   7848,
#   133],
#  [20066,
#   11991,
#   14497,
#   6072,
#   13777,
#   22002,
#   8147,
#   19692,
#   120,
#   4476,
#   20265,
#   6630,
#   9182,
#   22002,
#   6786,
#   23362,
#   13102,
#   6119,
#   22002,
#   11991,
#   6072,
#   22178,
#   22002,
#   7187,
#   21898,
#   10525,
#   8116,
#   5197,
#   23201,
#   133],
#  [6724, 16457, 19581, 20066, 15125, 13102, 17179, 19433, 22002, 9641, 133],
#  [23788,
#   19443,
#   11332,
#   12647,
#   3186,
#   20066,
#   11088,
#   6723,
#   14047,
#   23669,
#   120,
#   15952,
#   11823,
#   16429,
#   22092,
#   12650,
#   133],
#  [13139,
#   6758,
#   12674,
#   2921,
#   22049,
#   16429,
#   6724,
#   15788,
#   120,
#   20556,
#   634,
#   17167,
#   16429,
#   16758,
#   12650,
#   133],
#  [4792,
#   21781,
#   6724,
#   11524,
#   4715,
#   4476,
#   17613,
#   14384,
#   6232,
#   14695,
#   8329,
#   9182,
#   5155,
#   13151,
#   10469,
#   12447,
#   10004,
#   120,
#   21781,
#   10093,
#   12652,
#   4476,
#   23561,
#   5852,
#   16533,
#   6724,
#   6070,
#   10286,
#   133],
#  [10093,
#   14129,
#   4828,
#   5565,
#   4476,
#   21254,
#   12674,
#   13463,
#   22002,
#   4476,
#   17942,
#   14325,
#   16429,
#   21781,
#   5852,
#   5480,
#   6723,
#   21509,
#   16927,
#   15123,
#   22002,
#   10007,
#   21781,
#   9182,
#   133],
#  [132],
#  [11473, 121, 19677, 5565, 23558, 19913, 16429, 11473, 133],
#  [4902, 120, 16473, 1633],
#  [19677, 11088, 21781, 4, 1841],
#  [15347, 15956, 23558, 19913, 16429, 11473, 4792, 21781, 10711, 19265],
#  [21915, 5565, 21781, 3878, 23657, 120, 16919, 3958, 10702, 6924, 8310],
#  [14, 17443, 22428, 22616, 20875, 15, 4466],
#  [3823, 17054, 11536, 120, 6285, 15057, 120, 12169, 21543, 14, 13242, 15],
#  [3850, 20954, 21067],
#  [3859, 13476, 14224, 120, 14913, 6751],
#  [3958, 21960, 12145, 120, 9540, 23129, 120, 8656, 14566, 120, 5158, 10936],
#  [14,
#   21392,
#   15,
#   120,
#   16084,
#   10403,
#   14,
#   6723,
#   15,
#   120,
#   13362,
#   8191,
#   120,
#   20954,
#   13390,
#   120,
#   17289],
#  [15270, 120, 11610, 16228, 14, 5648, 15],
#  [3975, 10030, 9804, 14, 20604, 4786, 15, 120, 19682, 12273],
#  [3985, 7579, 19242, 120, 14538, 19157, 120, 11031, 11151, 120, 21376, 21111],
#  [14,
#   11332,
#   15,
#   120,
#   4968,
#   7224,
#   14,
#   11332,
#   15,
#   120,
#   11820,
#   21367,
#   120,
#   22029,
#   14198],
#  [3997, 8554, 23278, 120, 6619, 6784, 120, 8344, 16972, 14, 5648, 15, 120],
#  [20957, 11383, 14, 5648, 15, 120, 8223, 17067, 120, 8344, 20808, 120, 14913],
#  [16353, 120, 11031, 8304],
#  [4009, 17054, 20844, 120, 8268, 19163, 14, 13143, 15],
#  [4021,
#   13335,
#   11158,
#   120,
#   19557,
#   12174,
#   14,
#   13242,
#   15,
#   120,
#   23440,
#   23530,
#   120,
#   20100],
#  [14962, 14, 13242, 15],
#  [4035, 19682, 15073],
#  [4042, 23231, 23337, 14, 20604, 4786, 15, 120, 20954, 19632],
#  [4062, 22029, 23222],
#  [4180, 19807, 16493, 14, 13242, 15],
#  [132],
#  [20500, 121, 11430, 6311, 6042, 1805, 10348, 22780, 133],
#  [6311, 1633],
#  [11430,
#   6311,
#   14,
#   19205,
#   15,
#   6042,
#   1805,
#   14,
#   11834,
#   522,
#   15,
#   10348,
#   22780,
#   14,
#   14792,
#   15,
#   12674,
#   21785,
#   8487,
#   23468,
#   8487,
#   15001,
#   120,
#   19744,
#   14183,
#   16429,
#   21781,
#   17746,
#   19265,
#   120,
#   16533,
#   21915,
#   133],
#  [19676, 4466],
#  [11430,
#   6311,
#   121,
#   12579,
#   14105,
#   14,
#   2653,
#   15,
#   120,
#   10095,
#   23020,
#   14,
#   4226,
#   15],
#  [10348, 13928, 22780, 121, 11367, 4821, 14, 2195, 15],
#  [5608, 4466, 4089],
#  [11430,
#   6311,
#   23527,
#   2948,
#   16533,
#   4814,
#   5155,
#   18181,
#   10881,
#   21781,
#   10711,
#   19265,
#   16429,
#   21781,
#   8487,
#   23468,
#   8487,
#   133],
#  [18960],
#  [132],
#  [12361, 18261, 121, 17396, 9902, 2207, 23120, 10881, 22162, 17766, 133],
#  [23716, 120, 9927, 1633],
#  [20298,
#   14913,
#   17766,
#   13993,
#   12243,
#   10711,
#   11653,
#   16542,
#   22920,
#   12674,
#   2196,
#   23680,
#   5480,
#   4476,
#   22162,
#   23355,
#   12243,
#   22057,
#   20763,
#   17396,
#   120,
#   4476,
#   740,
#   7319,
#   120,
#   23527,
#   21781,
#   16320,
#   20823,
#   16533,
#   21915,
#   133],
#  [21781,
#   21889,
#   120,
#   16997,
#   6912,
#   22886,
#   11312,
#   9539,
#   120,
#   20471,
#   4476,
#   20141,
#   12003,
#   22866,
#   12674,
#   21781,
#   14047,
#   21069,
#   22002,
#   8891,
#   10130,
#   14,
#   1305,
#   15,
#   120,
#   22161,
#   6912,
#   12125,
#   7033,
#   5155,
#   19042,
#   6912,
#   7510,
#   19375,
#   133],
#  [12156,
#   11473,
#   19242,
#   14,
#   835,
#   15,
#   120,
#   14047,
#   23669,
#   12,
#   17861,
#   8673,
#   13923,
#   7,
#   4512,
#   23467,
#   5565,
#   14507,
#   120,
#   10678,
#   21819,
#   120,
#   4476,
#   11156,
#   16542,
#   5155,
#   4476,
#   18193,
#   14214,
#   5711,
#   23493,
#   21781,
#   3915,
#   10492,
#   15359,
#   11211,
#   12674,
#   10980,
#   133],
#  [17396,
#   120,
#   4476,
#   19291,
#   5487,
#   23467,
#   12674,
#   13463,
#   120,
#   15052,
#   16295,
#   6033,
#   4861,
#   5565,
#   21836,
#   19727,
#   12,
#   4512,
#   120,
#   10108,
#   12,
#   22057,
#   20761,
#   18254,
#   133],
#  [17766,
#   120,
#   18716,
#   22002,
#   11439,
#   13011,
#   21781,
#   23467,
#   12,
#   9878,
#   22656,
#   21781,
#   18917,
#   16429,
#   21781,
#   17304,
#   23194,
#   5222,
#   120,
#   19443,
#   4466,
#   3,
#   22373,
#   23680,
#   5155,
#   12516,
#   11991,
#   16027,
#   6072,
#   21797,
#   20485,
#   12516,
#   21853,
#   12516,
#   11790,
#   6229,
#   23120,
#   4476,
#   6312,
#   14510,
#   133,
#   3],
#  [12002,
#   4681,
#   4466,
#   3,
#   13139,
#   12,
#   22883,
#   19423,
#   22002,
#   6042,
#   12125,
#   7033,
#   6054,
#   12516,
#   5074,
#   11454,
#   22002,
#   12243,
#   8645,
#   133,
#   3],
#  [14336,
#   17766,
#   120,
#   13176,
#   6200,
#   120,
#   22162,
#   16429,
#   15359,
#   11211,
#   120,
#   11790,
#   11481,
#   13011,
#   21915,
#   12,
#   18254,
#   12674,
#   19721,
#   16429,
#   4476,
#   10711,
#   11653,
#   16542,
#   21189,
#   4792,
#   14854,
#   23680,
#   5435,
#   21781,
#   22057,
#   16429,
#   12243,
#   17922,
#   133],
#  [6200,
#   19443,
#   4466,
#   3,
#   12519,
#   9145,
#   6896,
#   12516,
#   9316,
#   15804,
#   10531,
#   21230,
#   133],
#  [12002,
#   14,
#   15359,
#   11211,
#   15,
#   23194,
#   11462,
#   5480,
#   23297,
#   5480,
#   5274,
#   16429,
#   21786,
#   16542,
#   5155,
#   4476,
#   11823,
#   11154,
#   14,
#   2568,
#   15238,
#   15,
#   16712,
#   6896,
#   12002,
#   13471,
#   9064,
#   15804,
#   18224,
#   133,
#   3],
#  [132],
#  [12361, 18261, 121, 16320, 20823, 18920, 133],
#  [23716, 120, 9927, 1633],
#  [18917,
#   16429,
#   21781,
#   16320,
#   20823,
#   120,
#   4476,
#   11653,
#   16542,
#   18254,
#   10881,
#   22404,
#   5155,
#   22699,
#   120,
#   19337,
#   16754,
#   10738,
#   11154,
#   14,
#   449,
#   13750,
#   15,
#   16533,
#   21915,
# ...
#   23716,
#   23653,
#   12674,
#   21781,
#   5097,
#   14136,
#   9637,
#   9286,
#   133],
#  [132],
#  [5959, 121, 14750, 14136, 20841, 4792, 23268, 12, 11211, 133],
#  [16033, 23716, 1633],
#  [14750, 14136, 5959],
#  [20841, 4792, 11211, 17441, 16533, 23268, 14, 21477, 22508, 23527, 120],
#  [14552, 120, 23469, 17168, 5155, 11211, 6093, 15, 4466],
#  [5097, 14136],
#  [9638, 9286],
#  [23082, 13923, 17086, 11268],
#  [16033, 23716, 3985, 3487, 268, 121],
#  [5849, 3837, 3585, 241, 3309],
#  [6548, 3768, 3786, 218, 634],
#  [22073, 3585, 3859, 197, 1214],
#  [9011, 3117, 4198, 146, 2315, 628],
#  [7255, 9286],
#  [7625, 4035, 3452, 276, 121],
#  [7445, 3859, 3598, 244, 3872, 628],
#  [15385, 3768, 3768, 219, 932, 628],
#  [15356, 3706, 3850, 208, 1299, 628],
#  [13530, 7560, 3585, 3958, 193, 1426, 628],
#  [23330, 9286],
#  [21764, 3997, 3506, 267, 121],
#  [19737, 3786, 3728, 223, 4088],
#  [16361, 3750, 3837, 215, 932],
#  [6967, 3585, 3850, 199, 1139, 628],
#  [21915, 120, 5639, 2058, 19617],
#  [16361, 5565, 6548],
#  [19737, 5565, 5849],
#  [6967, 5565, 16033, 23716],
#  [22073, 5565, 7445],
#  [9011, 5565, 13530, 7560],
#  [21764, 5565, 15385],
#  [15893, 14136],
#  [9638, 9286],
#  [23082, 13923, 17086, 11268],
#  [5579, 4062, 3167, 287, 121],
#  [15569, 3837, 3585, 241, 932],
#  [16033, 23716, 3598, 3859, 200, 1993, 628],
#  [10817, 3585, 3859, 197, 2058],
#  [17290, 3469, 4021, 163, 2315],
#  [7255, 9286],
#  [12402, 3850, 3598, 240, 121],
#  [20795, 14562, 3837, 3598, 237, 628],
#  [7445, 3768, 3750, 220, 2913],
#  [7537, 3750, 3750, 219, 2913, 628],
#  [17394, 3487, 3997, 168, 1139, 628],
#  [23330, 9286],
#  [19505, 9068, 3958, 3598, 248, 121],
#  [14544, 5180, 3823, 3706, 230, 1749, 628],
#  [7785, 3799, 3750, 223, 2913],
#  [19505, 11005, 3506, 3958, 179, 1054, 628],
#  [21915, 120, 5639, 2058, 19617],
#  [20795, 14562, 5565, 7785],
#  [7537, 5565, 5579],
#  [17394, 5565, 12402],
#  [17290, 5565, 14544, 5180],
#  [15569, 5565, 19505, 11005],
#  [132],
#  [5959, 121, 14750, 14136, 18920, 23268, 133],
#  [16033, 23716, 1633],
#  [18920, 16429, 14750, 14136],
#  [5959, 11211, 17441, 16533, 23268, 14, 12309, 21631, 12674, 7068, 15, 4466],
#  [5097, 14136],
#  [6967, 3872, 16033, 23716, 449],
#  [9011, 3872, 7445, 2913],
#  [15356, 634, 15385, 3872],
#  [6548, 3615, 16361, 2913],
#  [5849, 634, 19737, 3309],
#  [21764, 634, 7625, 4088, 14, 12674, 634, 15],
#  [22073, 3615, 13530, 7560, 1749],
#  [15893, 14136],
#  [7445, 4088, 10817, 2419],
#  [19505, 11005, 932, 16033, 23716, 815],
#  [5579, 2913, 7537, 2419],
#  [17394, 3309, 12402, 1749],
#  [7785, 634, 20795, 14562, 1749],
#  [17290, 3615, 14544, 5180, 293],
#  [19505, 9068, 3872, 15569, 1749],
#  [132],
#  [5959, 121, 11606, 12317, 12674, 813, 14326, 21764, 17026, 12755, 133],
#  [7625, 1633],
#  [19372,
#   11606,
#   12,
#   22395,
#   12317,
#   12674,
#   21781,
#   22057,
#   16429,
#   21781,
#   813,
#   12875,
#   18324,
#   21781,
#   21764,
#   18360,
#   22002,
#   4476,
#   683,
#   22920,
#   16754,
#   21781,
#   7625,
#   12755,
#   23268,
#   12674,
#   21781,
#   19299,
#   11209,
#   16429,
#   4476,
#   21868,
#   19913,
#   6232,
#   9286,
#   14129,
#   133],
#  [23493,
#   16542,
#   16712,
#   120,
#   11606,
#   12252,
#   4476,
#   522,
#   17384,
#   11088,
#   13443,
#   21606,
#   14,
#   2974,
#   15,
#   16754,
#   21781,
#   19065,
#   10552,
#   10881,
#   12243,
#   1298,
#   12309,
#   19337,
#   133],
#  [3,
#   13139,
#   23194,
#   5135,
#   16434,
#   17384,
#   5155,
#   12516,
#   13471,
#   22258,
#   22002,
#   11338,
#   4476,
#   11487,
#   21410,
#   16533,
#   13139,
#   5155,
#   18147,
#   13139,
#   12674,
#   17438,
#   120,
#   3,
#   11606,
#   19443,
#   133,
#   3],
#  [21836, 23194, 4476, 6259, 11209, 133],
#  [21781, 8426, 23194, 6093, 12213, 5155, 13139, 23194, 12948, 133, 3],
#  [21781,
#   20153,
#   6758,
#   12309,
#   13156,
#   19182,
#   120,
#   23382,
#   11790,
#   12243,
#   19744,
#   9396,
#   16429,
#   21781,
#   11209,
#   120,
#   11401,
#   12213,
#   3076,
#   21836,
#   19727,
#   120,
#   3058,
#   5480,
#   4476,
#   7174,
#   133],
#  [12002,
#   13368,
#   15271,
#   7711,
#   120,
#   13363,
#   6143,
#   5155,
#   21748,
#   13613,
#   5480,
#   21781,
#   16568,
#   7175,
#   23493,
#   3024,
#   9401,
#   12674,
#   4476,
#   19727,
#   133],
#  [21781,
#   18360,
#   11991,
#   23527,
#   634,
#   16429,
#   21785,
#   14047,
#   932,
#   11211,
#   5155,
#   20317,
#   16429,
#   16120,
#   15162,
#   4799,
#   21781,
#   12755,
#   21836,
#   19727,
#   133],
#  [21781,
#   5097,
#   14136,
#   23330,
#   14129,
#   11991,
#   23527,
#   9723,
#   16429,
#   1214,
#   11211,
#   5565,
#   13184,
#   10604,
#   120,
#   13369,
#   21781,
#   23653,
#   5480,
#   21781,
#   16568,
#   21633,
#   23493,
#   4476,
#   23469,
#   18540,
#   5565,
#   21781,
#   4485,
#   7255,
#   14129,
#   7,
#   12309,
#   133],
#  [7625, 14552, 10881, 13471, 21781, 19744, 21962, 12674, 20317, 11211, 133],
#  [21781,
#   12755,
#   19871,
#   21781,
#   11209,
#   13011,
#   10312,
#   12876,
#   12674,
#   21781,
#   16132,
#   16533,
#   13617,
#   14473,
#   12,
#   22395,
#   20283,
#   133],
#  [9670,
#   23055,
#   14,
#   521,
#   15,
#   6357,
#   12243,
#   10711,
#   19567,
#   16601,
#   6896,
#   11512,
#   21781,
#   23451,
#   120,
#   5036,
#   21864,
#   12258,
#   23493,
#   22382,
#   23136,
#   5155,
#   21864,
#   21073,
#   12674,
#   449,
#   1889,
#   19673,
#   12876,
#   133],
#  [8689, 16888, 12252, 12243, 2590, 12317, 10881, 21781, 18360, 133],
#  [12674,
#   5849,
#   120,
#   6953,
#   19098,
#   11790,
#   10963,
#   12258,
#   5155,
#   20469,
#   4476,
#   10617,
#   21932,
#   23493,
#   4476,
#   20543,
#   12317,
#   5155,
#   6412,
#   6483,
#   4681,
#   4476,
#   21880,
#   20153,
#   12674,
#   21781,
#   19967,
#   22002,
#   17663,
#   21781,
#   21319,
#   16661,
#   22002,
#   4476,
#   681,
#   22920,
#   16754,
#   21781,
#   19737,
#   14905,
#   133],
#  [21781,
#   14905,
#   19672,
#   10963,
#   19350,
#   12674,
#   21781,
#   22057,
#   16429,
#   21781,
#   10615,
#   22002,
#   21932,
#   21781,
#   11209,
#   3362,
#   6896,
#   19098,
#   14163,
#   16430,
#   21781,
#   6559,
#   16429,
#   21781,
#   12875,
#   23493,
#   12243,
#   2057,
#   12317,
#   16430,
#   20857,
#   20950,
#   12254,
#   14,
#   960,
#   15,
#   133],
#  [6483,
#   12,
#   6342,
#   23194,
#   21781,
#   10711,
#   21962,
#   18355,
#   13365,
#   120,
#   14047,
#   19727,
#   12,
#   8535,
#   23725,
#   23467,
#   120,
#   5035,
#   4476,
#   19337,
#   12674,
#   10738,
#   18706,
#   5311,
#   20275,
#   7817,
#   16430,
#   21781,
#   9137,
#   14407,
#   16533,
#   5639,
#   3615,
#   133],
#  [6483,
#   11970,
#   1993,
#   18430,
#   5155,
#   1214,
#   19350,
#   12674,
#   12243,
#   14047,
#   1893,
#   11211,
#   133],
#  [5849,
#   11970,
#   23527,
#   19957,
#   16429,
#   16120,
#   5155,
#   1299,
#   16429,
#   13151,
#   14047,
#   2058,
#   5155,
#   8524,
#   21781,
#   23653,
#   7,
#   14124,
#   12674,
#   21781,
#   4485,
#   9637,
#   22002,
#   10738,
#   11211,
#   133],
#  [19682, 10020, 14, 4104, 15, 13937, 22002, 12243, 21819, 21019, 23451, 133],
#  [4967,
#   19182,
#   11790,
#   22382,
#   12319,
#   5155,
#   10963,
#   18430,
#   10881,
#   21781,
#   14905,
#   120,
#   23382,
#   11991,
#   9499,
#   21864,
#   12674,
#   4476,
#   19286,
#   5155,
#   815,
#   16429,
#   1214,
#   133],
#  [12002,
#   6052,
#   21781,
#   10615,
#   20152,
#   12674,
#   14752,
#   12251,
#   22002,
#   12252,
#   2548,
#   12319,
#   12674,
#   4476,
#   19727,
#   5155,
#   21781,
#   10711,
#   20275,
#   19098,
#   12252,
#   2680,
#   12674,
#   1617,
#   133],
#  [7510, 12288, 12252, 12243, 2109, 12317, 10881, 5849, 133],
#  [12674,
#   16033,
#   23716,
#   120,
#   13252,
#   9059,
#   19607,
#   634,
#   12258,
#   16754,
#   3615,
#   629,
#   12876,
#   12674,
#   12243,
#   14752,
#   8709,
#   5155,
#   7460,
#   8656,
#   6137,
#   4476,
#   12317,
#   11088,
#   9608,
#   20208,
#   16429,
#   21781,
#   17430,
#   5480,
#   21781,
#   6967,
#   5185,
#   8762,
#   21781,
#   23653,
#   3894,
#   133],
#  [9059,
#   5035,
#   4476,
#   12317,
#   22002,
#   8935,
#   13313,
#   16533,
#   12243,
#   10711,
#   14752,
#   17384,
#   6896,
#   19948,
#   9412,
#   133],
#  [12002,
#   23194,
#   21781,
#   2314,
#   17386,
#   22722,
#   6912,
#   21781,
#   5185,
#   21836,
#   19727,
#   120,
#   22408,
#   4476,
#   14752,
#   18540,
#   133],
#  [13338,
#   13638,
#   14,
#   4305,
#   15,
#   22054,
#   21781,
#   14550,
#   5480,
#   21781,
#   23653,
#   14552,
#   21785,
#   16132,
#   12674,
#   1139,
#   11211,
#   133],
#  [21804, 21030, 815, 5965, 133],
#  [6967,
#   17441,
#   23502,
#   12972,
#   14807,
#   13362,
#   15099,
#   120,
#   23382,
#   23194,
#   4715,
#   22002,
#   4476,
#   16033,
#   23716,
#   12370,
#   23493,
#   4476,
#   6378,
#   7660,
#   12674,
#   12243,
#   19064,
#   6963,
#   133],
#  [12674,
#   6548,
#   120,
#   15318,
#   20845,
#   12,
#   5967,
#   22395,
#   20283,
#   20469,
#   5135,
#   9733,
#   21932,
#   5155,
#   11261,
#   21781,
#   18565,
#   20620,
#   21785,
#   21819,
#   21019,
#   23451,
#   120,
#   3660,
#   16754,
#   21781,
#   16361,
#   5578,
#   133],
#  [20845,
#   16816,
#   4476,
#   155,
#   7094,
#   6000,
#   5682,
#   23493,
#   21781,
#   5966,
#   14448,
#   14,
#   2659,
#   15,
#   133],
#  [6548,
#   12,
#   15458,
#   22816,
#   23319,
#   2486,
#   23493,
#   4476,
#   23131,
#   120,
#   20988,
#   12309,
#   10881,
#   16542,
#   16429,
#   12243,
#   21864,
#   19350,
#   19672,
#   5155,
#   7752,
#   12243,
#   917,
#   18430,
#   133],
#  [19682,
#   6753,
#   12318,
#   5155,
#   9502,
#   12674,
#   22382,
#   19350,
#   10881,
#   21781,
#   5578,
#   120,
#   23382,
#   11991,
#   14552,
#   19957,
#   16429,
#   21785,
#   14047,
#   16120,
#   11211,
#   133],
#  [12674,
#   9011,
#   120,
#   6619,
#   5644,
#   12,
#   21880,
#   12317,
#   7066,
#   4476,
#   10972,
#   9732,
#   5155,
#   14324,
#   21781,
#   21943,
#   22002,
#   4476,
#   3915,
#   22920,
#   16754,
#   21781,
#   18586,
#   7445,
#   23372,
#   20620,
#   133],
#  [21781,
#   21943,
#   11991,
#   23527,
#   8044,
#   11211,
#   4792,
#   9500,
#   9723,
#   12674,
#   4476,
#   19286,
#   120,
#   6896,
#   11991,
#   23527,
#   16120,
#   16429,
#   21785,
#   14047,
#   932,
#   5565,
#   12309,
#   133],
#  [21781,
#   23372,
#   20620,
#   11991,
#   14552,
#   20317,
#   16429,
#   21785,
#   14047,
#   9723,
#   11211,
#   133],
#  [12674,
#   13530,
#   7560,
#   120,
#   13426,
#   11764,
#   22090,
#   4476,
#   7909,
#   20319,
#   22002,
#   23451,
#   10881,
#   21781,
#   10711,
#   21962,
#   12674,
#   16754,
#   4476,
#   15561,
#   5155,
#   14580,
#   12243,
#   14138,
#   10006,
#   5480,
#   21781,
#   22073,
#   6386,
#   13262,
#   23527,
#   21785,
#   10980,
#   21019,
#   120,
#   3650,
#   16754,
#   21781,
#   19292,
#   133],
#  [11764,
#   14,
#   683,
#   15,
#   23527,
#   10881,
#   21781,
#   10711,
#   21962,
#   20275,
#   13450,
#   1299,
#   120,
#   4476,
#   20635,
#   16429,
#   20317,
#   20860,
#   133],
#  [12002,
#   5035,
#   22382,
#   19350,
#   122,
#   16542,
#   9622,
#   122,
#   5155,
#   14581,
#   12243,
#   10006,
#   22002,
#   1888,
#   133],
#  [5565,
#   15385,
#   120,
#   13362,
#   13193,
#   12,
#   21880,
#   12317,
#   120,
#   12243,
#   2273,
#   120,
#   7066,
#   4476,
#   10747,
#   9732,
#   12875,
#   21778,
#   18324,
#   21781,
#   15356,
#   6694,
#   22002,
#   4476,
#   682,
#   22920,
#   16754,
#   21781,
#   22379,
#   133],
#  [13193,
#   4681,
#   5135,
#   18430,
#   20283,
#   12674,
#   21781,
#   16132,
#   5155,
#   11790,
#   10963,
#   18430,
#   133],
#  [13405, 22768, 12252, 12243, 2057, 12317, 10881, 15356, 133],
#  [132],
#  [20500, 121, 7717, 9396, 9625, 18063, 2939, 23451, 133],
#  [5126, 1633],
#  [17291,
#   7717,
#   19672,
#   22376,
#   12674,
#   21781,
#   19744,
#   11823,
#   22002,
#   20769,
#   18063,
#   9739,
#   22002,
#   4476,
#   2939,
#   5711,
#   23451,
#   16754,
#   15956,
#   16109,
#   12674,
#   21781,
#   9582,
#   10711,
#   9286,
#   16533,
#   21915,
#   133],
#  [12002,
#   19672,
#   11088,
#   7649,
#   18358,
#   12674,
#   21781,
#   3527,
#   15396,
#   5155,
#   11088,
#   4476,
#   6249,
#   13665,
#   1054,
#   15397,
#   14057,
#   133],
#  [5462,
#   16313,
#   5155,
#   14604,
#   16118,
#   120,
#   9582,
#   22057,
#   19675,
#   14047,
#   19727,
#   120,
#   23322,
#   18063,
#   12,
#   16693,
#   14932,
#   133],
#  [4888,
#   5126,
#   16578,
#   21785,
#   21995,
#   8768,
#   23493,
#   4476,
#   521,
#   23451,
#   16754,
#   15819,
#   6677,
#   16533,
#   23268,
#   133],
#  [132],
#  [20500, 121, 9582, 10711, 9286, 21251, 133],
#  [5126, 1633],
#  [21251, 16429, 21915, 12, 16568],
#  [9582, 10711, 9286, 15001, 4466],
#  [15956,
#   16109,
#   449,
#   14,
#   22789,
#   10336,
#   1298,
#   15,
#   18063,
#   9739,
#   2913,
#   14,
#   16313,
#   929,
#   120],
#  [16118, 3098, 120, 7717, 3527, 120, 3849, 15, 133],
#  [11834, 532, 133],
#  [5608, 4089],
#  [132],
#  [20500, 121, 9582, 10711, 9286, 18917, 133],
#  [5126, 1633],
#  [18917, 16429, 4476, 9582, 10711],
#  [9286, 15001, 16533, 21915, 4466],
#  [15956, 16109, 449, 18063, 9739, 2913],
#  [132],
#  [20500, 121, 20046, 13782, 5758, 12674, 21413, 20776, 133],
#  [11299, 1633],
#  [11194,
#   21074,
#   4728,
#   13782,
#   120,
#   19675,
#   16429,
#   2245,
#   11448,
#   12674,
#   3140,
#   12982,
#   120,
#   11970,
#   6072,
#   18504,
#   6912,
#   21417,
#   10881,
#   21781,
#   23558,
#   8487,
#   18182,
#   4799,
#   5723,
#   12674,
#   5815,
#   16533,
#   5639,
#   2591,
#   133],
#  [13782,
#   23194,
#   16773,
#   6912,
#   5472,
#   13400,
#   10881,
#   21781,
#   10109,
#   7316,
#   10659,
#   9617,
#   21836,
#   23669,
#   133],
#  [6896,
#   16033,
#   7695,
#   19199,
#   11084,
#   13102,
#   7615,
#   4476,
#   13782,
#   10427,
#   5155,
#   12709,
#   12213,
#   12674,
#   12243,
#   1507,
#   20776,
#   16533,
#   21915,
#   133],
#  [21417,
#   10389,
#   22002,
#   17940,
#   6235,
#   21781,
#   16580,
#   11653,
#   17283,
#   12674,
#   10099,
#   4418,
#   133],
#  [20776, 4466],
#  [11445,
#   121,
#   14881,
#   17006,
#   14,
#   6947,
#   15,
#   120,
#   17005,
#   23854,
#   14,
#   11581,
#   15,
#   133],
#  [8773,
#   121,
#   20936,
#   12109,
#   14,
#   11849,
#   15,
#   120,
#   14870,
#   12390,
#   14,
#   10139,
#   15,
#   120,
#   23753,
#   18212,
#   14,
#   20296,
#   15,
#   120,
#   18338,
#   22825,
#   14,
#   6947,
#   15,
#   18380,
#   23398,
#   14,
#   20296,
#   15,
#   133],
#  [15301,
#   121,
#   4970,
#   7818,
#   14,
#   11581,
#   15,
#   120,
#   5267,
#   10058,
#   14,
#   11581,
#   15,
#   120,
#   19740,
#   10978,
#   14,
#   21142,
#   15,
#   120,
#   7517,
#   16475,
#   14,
#   14082,
#   15,
#   120,
#   17041,
#   21427,
#   14,
#   20296,
#   15,
#   120,
#   8651,
#   19935,
#   14,
#   19928,
#   15,
#   120,
#   7549,
#   19989,
#   14,
#   12957,
#   15320,
#   15,
#   15756,
#   23646,
#   14,
#   11581,
#   15,
#   133],
#  [21075,
#   121,
#   13884,
#   22346,
#   14,
#   11581,
#   15,
#   120,
#   4728,
#   13782,
#   14,
#   11194,
#   15,
#   120,
#   7517,
#   6489,
#   14,
#   20296,
#   15,
#   120,
#   20936,
#   7349,
#   14,
#   6534,
#   9391,
#   15,
#   133],
#  [132],
#  [5578,
#   121,
#   13139,
#   12,
#   4476,
#   18540,
#   121,
#   3025,
#   6074,
#   16533,
#   21781,
#   12395,
#   133],
#  [6779, 1633],
#  [20675,
#   5565,
#   11074,
#   12,
#   6779,
#   11565,
#   17861,
#   15161,
#   11991,
#   5135,
#   10312,
#   12695,
#   22002,
#   7405,
#   16533,
#   21781,
#   5576,
#   22002,
#   23558,
#   18540,
#   17183,
#   122,
#   4476,
#   11037,
#   11411,
#   16429,
#   6073,
#   133],
#  [4476,
#   6113,
#   6695,
#   11970,
#   16444,
#   22002,
#   17072,
#   10881,
#   4476,
#   11037,
#   19265,
#   16429,
#   9483,
#   10881,
#   4998,
#   16429,
#   21781,
#   3025,
#   8426,
#   12558,
#   4476,
#   23558,
#   18540,
#   11458,
#   5565,
#   21781,
#   15161,
#   120,
#   16646,
#   19443,
#   16533,
#   21915,
#   133],
#  [13139,
#   8280,
#   6033,
#   16542,
#   16429,
#   21781,
#   15622,
#   10250,
#   19269,
#   16429,
#   9483,
#   10135,
#   133],
#  [21781, 15161, 13102, 20529, 16712, 5054, 133],
#  [22382,
#   23558,
#   18545,
#   5381,
#   12674,
#   19915,
#   8601,
#   16429,
#   6097,
#   6738,
#   5565,
#   21781,
#   15161,
#   122,
#   21781,
#   23526,
#   12,
#   451,
#   15238,
#   5155,
#   21781,
#   15191,
#   12,
#   2420,
#   15238,
#   133],
#  [132],
#  [11473, 121, 11326, 16577, 10711, 19265, 19677, 133],
#  [21142, 120, 11332, 1633],
#  [14132, 10711, 19265],
#  [19677, 12674, 21781, 11326, 16577, 11473, 7316, 16533, 21915, 14, 6723],
#  [22616, 20875, 15, 4466],
#  [3750, 17054, 6736],
#  [3768, 18424, 19363],
#  [3786,
#   8651,
#   13167,
#   19363,
#   120,
#   15261,
#   7008,
#   14,
#   16033,
#   23789,
#   15,
#   120,
#   12525],
#  [23539, 120, 6196, 14007, 14, 11332, 15, 120, 19222, 18280, 120, 15023],
#  [14018, 14, 21392, 15, 120, 23231, 19079, 14, 5648, 15],
#  [3799,
#   9615,
#   8619,
#   14,
#   13080,
#   15,
#   120,
#   17165,
#   16338,
#   14,
#   21392,
#   15,
#   120,
#   19363,
#   7602,
#   120],
#  [14913, 19183, 120, 18940, 11492, 14, 20604, 4786, 15, 120, 7108, 21266],
#  [3823, 20939, 10604, 120, 17054, 14092, 120, 12525, 18157, 120, 15050, 5188],
#  [14, 21392, 15, 120, 15325, 22337, 120, 7512, 7287, 14, 10997, 15, 120],
#  [8941, 20465, 14, 13080, 15, 120, 8651, 7144, 120, 14165, 23340, 120, 11610],
#  [7307, 14, 5648, 15, 120, 15313, 5179, 14950, 14, 20633, 15, 120],
#  [21839, 6319, 14, 8877, 15, 120, 10564, 19162, 14, 20633, 15, 120, 8940],
#  [8196],
#  [3837, 13287, 11999, 120, 16849, 11953, 14, 13080, 15, 120, 15261],
#  [23288,
#   120,
#   21839,
#   11460,
#   14,
#   11332,
#   15,
#   120,
#   17054,
#   15083,
#   14,
#   13080,
#   15,
#   120],
#  [11239, 16666, 120, 13406, 7035, 14, 20633, 15, 120, 15261, 13394],
#  [14, 21392, 15, 120, 17054, 9613, 120, 8651, 23439, 120, 5172, 7792, 120],
#  [13387, 14486, 120, 13405, 19121, 14, 20633, 15, 120, 19154, 13556],
#  [14,
#   21392,
#   15,
#   120,
#   14883,
#   23445,
#   120,
#   17111,
#   14383,
#   14,
#   20633,
#   15,
#   120,
#   13212],
#  [20688,
#   120,
#   21748,
#   17813,
#   14,
#   5648,
#   15,
#   120,
#   13426,
#   7114,
#   17361,
#   14,
#   20633,
#   15,
#   120],
#  [14913, 15651],
#  [132],
#  [20500, 121, 22443, 19000, 21864, 8295, 10881, 10393, 17438, 133],
#  ...]

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from torch.utils.data import TensorDataset, DataLoader
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence,pad_packed_sequence

# %%
#dataloader only accepct array, indexical_x_train is list of list
def list_to_array(list_data):
    data = copy.deepcopy(list_data)
    for i in range(len(data)):
        data[i] = torch.from_numpy(np.array(data[i]))
    return data

# %%
indexical_x_train = list_to_array(indexical_x_train)

# %%
indexical_y_train = list_to_array(indexical_y_train)

# %%
from torch.utils.data import Dataset, DataLoader
## refer to pytorch tutorials on how to inherit from Dataset class


def pad_collate(batch):
    (xx, yy) = zip(*batch)
    x_lens = [len(x) for x in xx]
    y_lens = [len(y) for y in yy]

    xx_pad = pad_sequence(xx, batch_first=True, padding_value=0)
    yy_pad = pad_sequence(yy, batch_first=True, padding_value=0)

    return xx_pad, yy_pad, x_lens, y_lens

dataset = list(zip(indexical_x_train, indexical_y_train))
data_loader = DataLoader(dataset=dataset, batch_size=2, shuffle=False, collate_fn=pad_collate)

# %%
word_pad_index = word_to_index['<pad>']
tag_pad_index = tag_to_index['<pad>']

# %%
class BiLSTMPOSTagger(nn.Module):
    def __init__(self, 
                 input_dim, 
                 embedding_dim, 
                 hidden_dim, 
                 output_dim, 
                 n_layers, 
                 bidirectional, 
                 dropout, 
                 pad_idx):
        
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, embedding_dim, padding_idx = pad_idx)
        
        self.lstm = nn.LSTM(embedding_dim, 
                            hidden_dim, 
                            num_layers = n_layers, 
                            bidirectional = bidirectional,
                            dropout = dropout if n_layers > 1 else 0)
        
        self.fc = nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.elu = nn.ELU()
        
    def forward(self, x, batched= True):
        if batched :
            x_padded = x[0]
            #x_padded = x_padded.cuda()
            tags =x[1]
            #tags = tags.cuda()
            x_lens = x[2]

            
            y_lens = x[3]
    
            #pass text through embedding layer
            x_embed = self.dropout(self.embedding(x_padded))

            x_packed = pack_padded_sequence(x_embed, x_lens, batch_first=True, enforce_sorted=False)
            #pass embeddings into LSTM
            output_packed, (hidden, cell) = self.lstm(x_packed)
            output_padded, output_lengths = pad_packed_sequence(output_packed, batch_first=True)
            #we use our outputs to make a prediction of what the tag should be
            outputs = self.elu(output_padded)
            outputs = self.fc(self.dropout(outputs))
        else:
             #pass text through embedding layer
            embedded = self.dropout(self.embedding(x))
            #pass embeddings into LSTM
            outputs, (hidden, cell) = self.lstm(embedded) 
            #we use our outputs to make a prediction of what the tag should be
            outputs = self.elu(outputs)
            outputs = self.fc(self.dropout(outputs))
    
        
        return outputs

# %%
type(word_pad_index)
# Out:
# int

# %%
INPUT_DIM = len(word_to_index)
EMBEDDING_DIM = 100
HIDDEN_DIM = 256
OUTPUT_DIM = 128
N_LAYERS = 1
BIDIRECTIONAL = True
DROPOUT = 0.33
PAD_IDX = word_pad_index

model = BiLSTMPOSTagger(INPUT_DIM, 
                        EMBEDDING_DIM, 
                        HIDDEN_DIM, 
                        OUTPUT_DIM, 
                        N_LAYERS, 
                        BIDIRECTIONAL, 
                        DROPOUT, 
                        PAD_IDX)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.normal_(param.data, mean = 0, std = 0.1)

# %%
model.apply(init_weights)
# Out:
# BiLSTMPOSTagger(
#   (embedding): Embedding(23867, 100, padding_idx=0)
#   (lstm): LSTM(100, 256, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=128, bias=True)
#   (dropout): Dropout(p=0.33, inplace=False)
#   (elu): ELU(alpha=1.0)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,185,548 trainable parameters

# %%
model.embedding.weight.data[PAD_IDX] = torch.zeros(EMBEDDING_DIM)
glove1 = torch.from_numpy(glove)
model.embedding.weight.data.copy_(glove1)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.3847,  0.4935,  0.4910,  ...,  0.0263,  0.3905,  0.5222],
#         ...,
#         [ 0.5985, -0.3346,  0.6709,  ..., -0.0541, -0.0713, -0.1815],
#         [ 0.2933, -0.5548, -0.1047,  ...,  0.3955, -0.1746, -0.1650],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]])

# %%
### define optimizer fuction 
optimizer = SGD(model.parameters(), lr=0.05, momentum=0.9)

# %%
### define loss function 
TAG_PAD_IDX = tag_to_index['<pad>']

criterion = nn.CrossEntropyLoss(ignore_index = TAG_PAD_IDX)

# %%
### train the model 
def train(model, data_loader, optimizer, criterion, tag_pad_idx):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.train()
    for x in data_loader:
       # x = x.cuda()
        tags = x[1]
        #tags = tags.cuda()
        optimizer.zero_grad()
        predictions = model(x)
        predictions = predictions.view(-1, predictions.shape[-1])
        tags = tags.view(-1)
        tags = tags.type(torch.LongTensor) 
        #tags = tags.cuda()
        loss = criterion(predictions, tags)
                
        acc = categorical_accuracy(predictions, tags, tag_pad_idx)
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    return epoch_loss / len(data_loader),epoch_acc / len(data_loader)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs
def categorical_accuracy(preds, y, tag_pad_idx):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    non_pad_elements = (y != tag_pad_idx).nonzero()
    correct = max_preds[non_pad_elements].squeeze(1).eq(y[non_pad_elements])
    return correct.sum() / y[non_pad_elements].shape[0]

# %%
device = torch.device("cpu")
model.to(device)
#device = torch.device('cuda:0')
#model.to(device)
# Out:
# BiLSTMPOSTagger(
#   (embedding): Embedding(23867, 100, padding_idx=0)
#   (lstm): LSTM(100, 256, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=128, bias=True)
#   (dropout): Dropout(p=0.33, inplace=False)
#   (elu): ELU(alpha=1.0)
# )

# %%
# N_EPOCHS = 50

# best_train_loss = float('inf')

# for epoch in range(N_EPOCHS):

#     start_time = time.time()
    
#     train_loss, train_acc = train(model, data_loader, optimizer, criterion, TAG_PAD_IDX)
#     #valid_loss, valid_acc = evaluate(model, corpus.val_iter, criterion, TAG_PAD_IDX)
    
#     end_time = time.time()

#     epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
#     if train_loss < best_train_loss:
#         best_train_loss = train_loss
#         torch.save(model.state_dict(), 'tut1-model.pt')
    
#     print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
#     print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
#     #print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 4m 49s
# 	Train Loss: 0.262 | Train Acc: 92.67%
# Epoch: 02 | Epoch Time: 6m 23s
# 	Train Loss: 0.138 | Train Acc: 95.95%
# Epoch: 03 | Epoch Time: 7m 47s
# 	Train Loss: 0.103 | Train Acc: 96.87%
# Epoch: 04 | Epoch Time: 7m 44s
# 	Train Loss: 0.084 | Train Acc: 97.49%
# Epoch: 05 | Epoch Time: 6m 6s
# 	Train Loss: 0.069 | Train Acc: 97.90%
# Epoch: 06 | Epoch Time: 6m 17s
# 	Train Loss: 0.061 | Train Acc: 98.16%
# Epoch: 07 | Epoch Time: 7m 46s
# 	Train Loss: 0.055 | Train Acc: 98.27%
# Epoch: 08 | Epoch Time: 6m 45s
# 	Train Loss: 0.047 | Train Acc: 98.51%
# Epoch: 09 | Epoch Time: 5m 59s
# 	Train Loss: 0.042 | Train Acc: 98.67%
# Epoch: 10 | Epoch Time: 5m 31s
# 	Train Loss: 0.039 | Train Acc: 98.80%
# Epoch: 11 | Epoch Time: 6m 23s
# 	Train Loss: 0.035 | Train Acc: 98.90%
# Epoch: 12 | Epoch Time: 6m 54s
# 	Train Loss: 0.032 | Train Acc: 98.98%
# Epoch: 13 | Epoch Time: 6m 0s
# 	Train Loss: 0.030 | Train Acc: 99.04%
# Epoch: 14 | Epoch Time: 5m 27s
# 	Train Loss: 0.028 | Train Acc: 99.07%
# Epoch: 15 | Epoch Time: 5m 25s
# 	Train Loss: 0.026 | Train Acc: 99.17%
# Epoch: 16 | Epoch Time: 5m 16s
# 	Train Loss: 0.024 | Train Acc: 99.20%
# Epoch: 17 | Epoch Time: 5m 11s
# 	Train Loss: 0.022 | Train Acc: 99.28%
# Epoch: 18 | Epoch Time: 239m 36s
# 	Train Loss: 0.022 | Train Acc: 99.28%
# Epoch: 19 | Epoch Time: 7m 16s
# 	Train Loss: 0.021 | Train Acc: 99.31%
# Epoch: 20 | Epoch Time: 6m 24s
# 	Train Loss: 0.020 | Train Acc: 99.37%
# Epoch: 21 | Epoch Time: 33m 26s
# 	Train Loss: 0.019 | Train Acc: 99.39%
# Epoch: 22 | Epoch Time: 390m 48s
# 	Train Loss: 0.016 | Train Acc: 99.45%
# Epoch: 23 | Epoch Time: 6m 56s
# 	Train Loss: 0.016 | Train Acc: 99.45%
# Epoch: 24 | Epoch Time: 113m 24s
# 	Train Loss: 0.016 | Train Acc: 99.45%
# Epoch: 25 | Epoch Time: 5m 52s
# 	Train Loss: 0.015 | Train Acc: 99.50%
# Epoch: 26 | Epoch Time: 5m 20s
# 	Train Loss: 0.014 | Train Acc: 99.53%
# Epoch: 27 | Epoch Time: 5m 40s
# 	Train Loss: 0.015 | Train Acc: 99.50%
# Epoch: 28 | Epoch Time: 5m 41s
# 	Train Loss: 0.014 | Train Acc: 99.55%
# Epoch: 29 | Epoch Time: 6m 2s
# 	Train Loss: 0.013 | Train Acc: 99.56%
# Epoch: 30 | Epoch Time: 5m 17s
# 	Train Loss: 0.012 | Train Acc: 99.60%
# Epoch: 31 | Epoch Time: 9m 8s
# 	Train Loss: 0.012 | Train Acc: 99.60%
# Epoch: 32 | Epoch Time: 5m 21s
# 	Train Loss: 0.012 | Train Acc: 99.62%
# Epoch: 33 | Epoch Time: 5m 16s
# 	Train Loss: 0.011 | Train Acc: 99.64%
# Epoch: 34 | Epoch Time: 9m 45s
# 	Train Loss: 0.011 | Train Acc: 99.65%
# Epoch: 35 | Epoch Time: 5m 37s
# 	Train Loss: 0.011 | Train Acc: 99.64%
# Epoch: 36 | Epoch Time: 34m 10s
# 	Train Loss: 0.010 | Train Acc: 99.66%
# Epoch: 37 | Epoch Time: 81m 36s
# 	Train Loss: 0.009 | Train Acc: 99.69%
# Epoch: 38 | Epoch Time: 7m 13s
# 	Train Loss: 0.010 | Train Acc: 99.68%
# Epoch: 39 | Epoch Time: 6m 44s
# 	Train Loss: 0.009 | Train Acc: 99.69%
# Epoch: 40 | Epoch Time: 6m 40s
# 	Train Loss: 0.010 | Train Acc: 99.68%
# Epoch: 41 | Epoch Time: 6m 33s
# 	Train Loss: 0.008 | Train Acc: 99.71%
# Epoch: 42 | Epoch Time: 6m 18s
# 	Train Loss: 0.008 | Train Acc: 99.73%
# Epoch: 43 | Epoch Time: 6m 10s
# 	Train Loss: 0.008 | Train Acc: 99.72%
# Epoch: 44 | Epoch Time: 6m 8s
# 	Train Loss: 0.008 | Train Acc: 99.73%
# Epoch: 45 | Epoch Time: 6m 14s
# 	Train Loss: 0.008 | Train Acc: 99.74%
# Epoch: 46 | Epoch Time: 6m 0s
# 	Train Loss: 0.007 | Train Acc: 99.76%
# Epoch: 47 | Epoch Time: 6m 8s
# 	Train Loss: 0.007 | Train Acc: 99.76%
# Epoch: 48 | Epoch Time: 6m 15s
# 	Train Loss: 0.007 | Train Acc: 99.76%
# Epoch: 49 | Epoch Time: 6m 56s
# 	Train Loss: 0.007 | Train Acc: 99.76%
# Epoch: 50 | Epoch Time: 6m 11s
# 	Train Loss: 0.007 | Train Acc: 99.76%

# %%
def finder(x):
    token = []
    for w in x:
        if w in word_to_index:
            vec =word_to_index[w]
        else:
            vec = word_to_index["<unk>"]
            
        token.append(vec)
            
    return token 

model.load_state_dict(torch.load('blstm2_revised.pt', map_location=torch.device('cpu')))
def tag_sentence(model, sentence, w_to_ix, t_to_ix):
    
    model.eval()
  
    numericalized_tokens = finder(sentence)
    ## convert it into tensor 
    token_tensor = torch.LongTensor(numericalized_tokens)
    
    token_tensor = token_tensor.unsqueeze(-1)
     # use the model to predict     
    predictions = model(token_tensor, batched=False)
    
    top_predictions = predictions.argmax(-1)
    
    predicted_tags = [ix_to_t[t.item()] for t in top_predictions]
    
    return predicted_tags

# %%
def converter(data):
    train_word = []
    train_tag = []
    i = 0
    for index, word,tag in data:
        if index == 1:
            temp1 = []
            temp2 = []
            temp1.append(word)
            temp2.append(tag)
            
        else:
            temp1.append(word)
            temp2.append(tag)
        if ( (i+1 < len(data)) and data[i+1][0] == 1 ) or (i == len(data)-1):
            train_word.append(temp1)
            train_tag.append(temp2)
        i += 1
    return train_word, train_tag

# %%
dev_file = pd.read_csv('dev', quoting=csv.QUOTE_NONE, sep=" ", names= ['index', 'word', 'tag'])

dev_array = dev_file.to_numpy()

dev_word, dev_tag = converter(dev_array)

# %%
def tag_sentence(model, sentence, word_to_index, tag_to_index):
    
    model.eval()
  
    numericalized_tokens = finder(sentence)
    ## convert it into tensor 
    token_tensor = torch.LongTensor(numericalized_tokens)
    
    token_tensor = token_tensor.unsqueeze(-1)
     # use the model to predict     
    predictions = model(token_tensor, batched=False)
    
    top_predictions = predictions.argmax(-1)
    
    predicted_tags = [index_to_tag[t.item()] for t in top_predictions]
    
    return predicted_tags
